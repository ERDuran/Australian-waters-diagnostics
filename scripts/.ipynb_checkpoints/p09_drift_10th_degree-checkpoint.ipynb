# %%
# %pylab inline

import cosima_cookbook as cc
import matplotlib.pyplot as plt # to generate plots
import xarray as xr
import pandas as pd
import scipy.interpolate
import scipy.ndimage
from scipy import stats
from tqdm import tqdm_notebook
import IPython.display
import cmocean as cm
from scipy.io import loadmat
from dask.distributed import Client
import cartopy.crs as ccrs
import cartopy.feature as cft
import matplotlib.ticker as mticker
from glob import glob as gb
import sys, os
sys.path.append(os.path.join(os.getcwd(), '..'))  # so we can import ../exptdata
import exptdata
print('Available exptdata keys: ', [k for k in exptdata.exptdict.keys()])

from mpl_toolkits.axes_grid1.axes_divider import make_axes_locatable
def arange(start,end,stride=1):
    return np.arange(start,end+0.00000001,stride)
# !pwd
# Out:
# Populating the interactive namespace from numpy and matplotlib
# netcdf_index loaded.
# Available exptdata keys:  ['1deg', '025deg', '01deg']
# /bin/sh: module: line 1: syntax error: unexpected end of file
# /bin/sh: error importing function definition for `BASH_FUNC_module'
# /home/561/erd561/ACCESS-OM2-1-025-010deg-report/figures/Australia

# %%
input_path = '/g/data/ua8/JRA55-do/v1-3/'

years = list(range(1993, 2018))

output_path = '/g/data/e14/erd561/JRA55-do/v1-3/'

pls_in = sorted(os.listdir(input_path))

file_var = ['u_10', 'v_10', 't_10', 'rain', 'slp']
var = ['uas_10m', 'vas_10m', 'tas_10m', 'prrn', 'psl']

lonW = '90.0'
lonE = '180.0'
latS = '-70.0'
latN = '20.0'

for f,v in zip(file_var, var):
    for y_num in years:
        y = str(y_num)
        
        file_name = \
        [file 
         for file in pls_in 
         if '.' + y + '.' in file 
         and f in file][0]
        
        command = 'ncra -d longitude,' + lonW + ',' + lonE + \
                ' -d latitude,' + latS + ',' + latN + ' -v ' \
                + v + ' ' + input_path + file_name + ' ' + \
                 output_path + file_name
        
        print('$ ' + command) 
        pls_out = os.listdir(output_path)
        if file_name in pls_out:
            print('It is already there! \n')
        else:
            os.system(command)
            print('Done. \n')
# Out:
# $ ncra -d longitude,90.0,180.0 -d latitude,-70.0,20.0 -v uas_10m /g/data/ua8/JRA55-do/v1-3/u_10.1993.18Oct2017.nc /g/data/e14/erd561/JRA55-do/v1-3/u_10.1993.18Oct2017.nc
# It is already there!
#
# $ ncra -d longitude,90.0,180.0 -d latitude,-70.0,20.0 -v uas_10m /g/data/ua8/JRA55-do/v1-3/u_10.1994.18Oct2017.nc /g/data/e14/erd561/JRA55-do/v1-3/u_10.1994.18Oct2017.nc
# It is already there!
#
# $ ncra -d longitude,90.0,180.0 -d latitude,-70.0,20.0 -v uas_10m /g/data/ua8/JRA55-do/v1-3/u_10.1995.18Oct2017.nc /g/data/e14/erd561/JRA55-do/v1-3/u_10.1995.18Oct2017.nc
# It is already there!
#
# $ ncra -d longitude,90.0,180.0 -d latitude,-70.0,20.0 -v uas_10m /g/data/ua8/JRA55-do/v1-3/u_10.1996.18Oct2017.nc /g/data/e14/erd561/JRA55-do/v1-3/u_10.1996.18Oct2017.nc
# It is already there!
#
# $ ncra -d longitude,90.0,180.0 -d latitude,-70.0,20.0 -v uas_10m /g/data/ua8/JRA55-do/v1-3/u_10.1997.18Oct2017.nc /g/data/e14/erd561/JRA55-do/v1-3/u_10.1997.18Oct2017.nc
# It is already there!
#
# $ ncra -d longitude,90.0,180.0 -d latitude,-70.0,20.0 -v uas_10m /g/data/ua8/JRA55-do/v1-3/u_10.1998.18Oct2017.nc /g/data/e14/erd561/JRA55-do/v1-3/u_10.1998.18Oct2017.nc
# It is already there!
#
# $ ncra -d longitude,90.0,180.0 -d latitude,-70.0,20.0 -v uas_10m /g/data/ua8/JRA55-do/v1-3/u_10.1999.18Oct2017.nc /g/data/e14/erd561/JRA55-do/v1-3/u_10.1999.18Oct2017.nc
# It is already there!
#
# $ ncra -d longitude,90.0,180.0 -d latitude,-70.0,20.0 -v uas_10m /g/data/ua8/JRA55-do/v1-3/u_10.2000.18Oct2017.nc /g/data/e14/erd561/JRA55-do/v1-3/u_10.2000.18Oct2017.nc
# It is already there!
#
# $ ncra -d longitude,90.0,180.0 -d latitude,-70.0,20.0 -v uas_10m /g/data/ua8/JRA55-do/v1-3/u_10.2001.18Oct2017.nc /g/data/e14/erd561/JRA55-do/v1-3/u_10.2001.18Oct2017.nc
# It is already there!
#
# $ ncra -d longitude,90.0,180.0 -d latitude,-70.0,20.0 -v uas_10m /g/data/ua8/JRA55-do/v1-3/u_10.2002.18Oct2017.nc /g/data/e14/erd561/JRA55-do/v1-3/u_10.2002.18Oct2017.nc
# It is already there!
#
# $ ncra -d longitude,90.0,180.0 -d latitude,-70.0,20.0 -v uas_10m /g/data/ua8/JRA55-do/v1-3/u_10.2003.18Oct2017.nc /g/data/e14/erd561/JRA55-do/v1-3/u_10.2003.18Oct2017.nc
# It is already there!
#
# $ ncra -d longitude,90.0,180.0 -d latitude,-70.0,20.0 -v uas_10m /g/data/ua8/JRA55-do/v1-3/u_10.2004.18Oct2017.nc /g/data/e14/erd561/JRA55-do/v1-3/u_10.2004.18Oct2017.nc
# It is already there!
#
# $ ncra -d longitude,90.0,180.0 -d latitude,-70.0,20.0 -v uas_10m /g/data/ua8/JRA55-do/v1-3/u_10.2005.18Oct2017.nc /g/data/e14/erd561/JRA55-do/v1-3/u_10.2005.18Oct2017.nc
# It is already there!
#
# $ ncra -d longitude,90.0,180.0 -d latitude,-70.0,20.0 -v uas_10m /g/data/ua8/JRA55-do/v1-3/u_10.2006.18Oct2017.nc /g/data/e14/erd561/JRA55-do/v1-3/u_10.2006.18Oct2017.nc
# It is already there!
#
# $ ncra -d longitude,90.0,180.0 -d latitude,-70.0,20.0 -v uas_10m /g/data/ua8/JRA55-do/v1-3/u_10.2007.18Oct2017.nc /g/data/e14/erd561/JRA55-do/v1-3/u_10.2007.18Oct2017.nc
# It is already there!
#
# $ ncra -d longitude,90.0,180.0 -d latitude,-70.0,20.0 -v uas_10m /g/data/ua8/JRA55-do/v1-3/u_10.2008.18Oct2017.nc /g/data/e14/erd561/JRA55-do/v1-3/u_10.2008.18Oct2017.nc
# It is already there!
#
# $ ncra -d longitude,90.0,180.0 -d latitude,-70.0,20.0 -v uas_10m /g/data/ua8/JRA55-do/v1-3/u_10.2009.18Oct2017.nc /g/data/e14/erd561/JRA55-do/v1-3/u_10.2009.18Oct2017.nc
# It is already there!
#
# $ ncra -d longitude,90.0,180.0 -d latitude,-70.0,20.0 -v uas_10m /g/data/ua8/JRA55-do/v1-3/u_10.2010.18Oct2017.nc /g/data/e14/erd561/JRA55-do/v1-3/u_10.2010.18Oct2017.nc
# It is already there!
#
# $ ncra -d longitude,90.0,180.0 -d latitude,-70.0,20.0 -v uas_10m /g/data/ua8/JRA55-do/v1-3/u_10.2011.18Oct2017.nc /g/data/e14/erd561/JRA55-do/v1-3/u_10.2011.18Oct2017.nc
# It is already there!
#
# $ ncra -d longitude,90.0,180.0 -d latitude,-70.0,20.0 -v uas_10m /g/data/ua8/JRA55-do/v1-3/u_10.2012.18Oct2017.nc /g/data/e14/erd561/JRA55-do/v1-3/u_10.2012.18Oct2017.nc
# It is already there!
#
# $ ncra -d longitude,90.0,180.0 -d latitude,-70.0,20.0 -v uas_10m /g/data/ua8/JRA55-do/v1-3/u_10.2013.18Oct2017.nc /g/data/e14/erd561/JRA55-do/v1-3/u_10.2013.18Oct2017.nc
# It is already there!
#
# $ ncra -d longitude,90.0,180.0 -d latitude,-70.0,20.0 -v uas_10m /g/data/ua8/JRA55-do/v1-3/u_10.2014.18Oct2017.nc /g/data/e14/erd561/JRA55-do/v1-3/u_10.2014.18Oct2017.nc
# It is already there!
#
# $ ncra -d longitude,90.0,180.0 -d latitude,-70.0,20.0 -v uas_10m /g/data/ua8/JRA55-do/v1-3/u_10.2015.18Oct2017.nc /g/data/e14/erd561/JRA55-do/v1-3/u_10.2015.18Oct2017.nc
# It is already there!
#
# $ ncra -d longitude,90.0,180.0 -d latitude,-70.0,20.0 -v uas_10m /g/data/ua8/JRA55-do/v1-3/u_10.2016.18Oct2017.nc /g/data/e14/erd561/JRA55-do/v1-3/u_10.2016.18Oct2017.nc
# It is already there!
#
# $ ncra -d longitude,90.0,180.0 -d latitude,-70.0,20.0 -v uas_10m /g/data/ua8/JRA55-do/v1-3/u_10.2017.14Jan2018.nc /g/data/e14/erd561/JRA55-do/v1-3/u_10.2017.14Jan2018.nc
# It is already there!
#
# $ ncra -d longitude,90.0,180.0 -d latitude,-70.0,20.0 -v vas_10m /g/data/ua8/JRA55-do/v1-3/v_10.1993.18Oct2017.nc /g/data/e14/erd561/JRA55-do/v1-3/v_10.1993.18Oct2017.nc
# It is already there!
#
# $ ncra -d longitude,90.0,180.0 -d latitude,-70.0,20.0 -v vas_10m /g/data/ua8/JRA55-do/v1-3/v_10.1994.18Oct2017.nc /g/data/e14/erd561/JRA55-do/v1-3/v_10.1994.18Oct2017.nc
# It is already there!
#
# $ ncra -d longitude,90.0,180.0 -d latitude,-70.0,20.0 -v vas_10m /g/data/ua8/JRA55-do/v1-3/v_10.1995.18Oct2017.nc /g/data/e14/erd561/JRA55-do/v1-3/v_10.1995.18Oct2017.nc
# It is already there!
#
# $ ncra -d longitude,90.0,180.0 -d latitude,-70.0,20.0 -v vas_10m /g/data/ua8/JRA55-do/v1-3/v_10.1996.18Oct2017.nc /g/data/e14/erd561/JRA55-do/v1-3/v_10.1996.18Oct2017.nc
# It is already there!
#
# $ ncra -d longitude,90.0,180.0 -d latitude,-70.0,20.0 -v vas_10m /g/data/ua8/JRA55-do/v1-3/v_10.1997.18Oct2017.nc /g/data/e14/erd561/JRA55-do/v1-3/v_10.1997.18Oct2017.nc
# It is already there!
#
# $ ncra -d longitude,90.0,180.0 -d latitude,-70.0,20.0 -v vas_10m /g/data/ua8/JRA55-do/v1-3/v_10.1998.18Oct2017.nc /g/data/e14/erd561/JRA55-do/v1-3/v_10.1998.18Oct2017.nc
# It is already there!
#
# $ ncra -d longitude,90.0,180.0 -d latitude,-70.0,20.0 -v vas_10m /g/data/ua8/JRA55-do/v1-3/v_10.1999.18Oct2017.nc /g/data/e14/erd561/JRA55-do/v1-3/v_10.1999.18Oct2017.nc
# It is already there!
#
# $ ncra -d longitude,90.0,180.0 -d latitude,-70.0,20.0 -v vas_10m /g/data/ua8/JRA55-do/v1-3/v_10.2000.18Oct2017.nc /g/data/e14/erd561/JRA55-do/v1-3/v_10.2000.18Oct2017.nc
# It is already there!
#
# $ ncra -d longitude,90.0,180.0 -d latitude,-70.0,20.0 -v vas_10m /g/data/ua8/JRA55-do/v1-3/v_10.2001.18Oct2017.nc /g/data/e14/erd561/JRA55-do/v1-3/v_10.2001.18Oct2017.nc
# It is already there!
#
# $ ncra -d longitude,90.0,180.0 -d latitude,-70.0,20.0 -v vas_10m /g/data/ua8/JRA55-do/v1-3/v_10.2002.18Oct2017.nc /g/data/e14/erd561/JRA55-do/v1-3/v_10.2002.18Oct2017.nc
# It is already there!
#
# $ ncra -d longitude,90.0,180.0 -d latitude,-70.0,20.0 -v vas_10m /g/data/ua8/JRA55-do/v1-3/v_10.2003.18Oct2017.nc /g/data/e14/erd561/JRA55-do/v1-3/v_10.2003.18Oct2017.nc
# It is already there!
#
# $ ncra -d longitude,90.0,180.0 -d latitude,-70.0,20.0 -v vas_10m /g/data/ua8/JRA55-do/v1-3/v_10.2004.18Oct2017.nc /g/data/e14/erd561/JRA55-do/v1-3/v_10.2004.18Oct2017.nc
# It is already there!
#
# $ ncra -d longitude,90.0,180.0 -d latitude,-70.0,20.0 -v vas_10m /g/data/ua8/JRA55-do/v1-3/v_10.2005.18Oct2017.nc /g/data/e14/erd561/JRA55-do/v1-3/v_10.2005.18Oct2017.nc
# It is already there!
#
# $ ncra -d longitude,90.0,180.0 -d latitude,-70.0,20.0 -v vas_10m /g/data/ua8/JRA55-do/v1-3/v_10.2006.18Oct2017.nc /g/data/e14/erd561/JRA55-do/v1-3/v_10.2006.18Oct2017.nc
# It is already there!
#
# $ ncra -d longitude,90.0,180.0 -d latitude,-70.0,20.0 -v vas_10m /g/data/ua8/JRA55-do/v1-3/v_10.2007.18Oct2017.nc /g/data/e14/erd561/JRA55-do/v1-3/v_10.2007.18Oct2017.nc
# It is already there!
#
# $ ncra -d longitude,90.0,180.0 -d latitude,-70.0,20.0 -v vas_10m /g/data/ua8/JRA55-do/v1-3/v_10.2008.18Oct2017.nc /g/data/e14/erd561/JRA55-do/v1-3/v_10.2008.18Oct2017.nc
# It is already there!
#
# $ ncra -d longitude,90.0,180.0 -d latitude,-70.0,20.0 -v vas_10m /g/data/ua8/JRA55-do/v1-3/v_10.2009.18Oct2017.nc /g/data/e14/erd561/JRA55-do/v1-3/v_10.2009.18Oct2017.nc
# It is already there!
#
# $ ncra -d longitude,90.0,180.0 -d latitude,-70.0,20.0 -v vas_10m /g/data/ua8/JRA55-do/v1-3/v_10.2010.18Oct2017.nc /g/data/e14/erd561/JRA55-do/v1-3/v_10.2010.18Oct2017.nc
# It is already there!
#
# $ ncra -d longitude,90.0,180.0 -d latitude,-70.0,20.0 -v vas_10m /g/data/ua8/JRA55-do/v1-3/v_10.2011.18Oct2017.nc /g/data/e14/erd561/JRA55-do/v1-3/v_10.2011.18Oct2017.nc
# It is already there!
#
# $ ncra -d longitude,90.0,180.0 -d latitude,-70.0,20.0 -v vas_10m /g/data/ua8/JRA55-do/v1-3/v_10.2012.18Oct2017.nc /g/data/e14/erd561/JRA55-do/v1-3/v_10.2012.18Oct2017.nc
# It is already there!
#
# $ ncra -d longitude,90.0,180.0 -d latitude,-70.0,20.0 -v vas_10m /g/data/ua8/JRA55-do/v1-3/v_10.2013.18Oct2017.nc /g/data/e14/erd561/JRA55-do/v1-3/v_10.2013.18Oct2017.nc
# It is already there!
#
# $ ncra -d longitude,90.0,180.0 -d latitude,-70.0,20.0 -v vas_10m /g/data/ua8/JRA55-do/v1-3/v_10.2014.18Oct2017.nc /g/data/e14/erd561/JRA55-do/v1-3/v_10.2014.18Oct2017.nc
# It is already there!
#
# $ ncra -d longitude,90.0,180.0 -d latitude,-70.0,20.0 -v vas_10m /g/data/ua8/JRA55-do/v1-3/v_10.2015.18Oct2017.nc /g/data/e14/erd561/JRA55-do/v1-3/v_10.2015.18Oct2017.nc
# It is already there!
#
# $ ncra -d longitude,90.0,180.0 -d latitude,-70.0,20.0 -v vas_10m /g/data/ua8/JRA55-do/v1-3/v_10.2016.18Oct2017.nc /g/data/e14/erd561/JRA55-do/v1-3/v_10.2016.18Oct2017.nc
# It is already there!
#
# $ ncra -d longitude,90.0,180.0 -d latitude,-70.0,20.0 -v vas_10m /g/data/ua8/JRA55-do/v1-3/v_10.2017.14Jan2018.nc /g/data/e14/erd561/JRA55-do/v1-3/v_10.2017.14Jan2018.nc
# It is already there!
#
# $ ncra -d longitude,90.0,180.0 -d latitude,-70.0,20.0 -v tas_10m /g/data/ua8/JRA55-do/v1-3/t_10.1993.18Oct2017.nc /g/data/e14/erd561/JRA55-do/v1-3/t_10.1993.18Oct2017.nc
# It is already there!
#
# $ ncra -d longitude,90.0,180.0 -d latitude,-70.0,20.0 -v tas_10m /g/data/ua8/JRA55-do/v1-3/t_10.1994.18Oct2017.nc /g/data/e14/erd561/JRA55-do/v1-3/t_10.1994.18Oct2017.nc
# It is already there!
#
# $ ncra -d longitude,90.0,180.0 -d latitude,-70.0,20.0 -v tas_10m /g/data/ua8/JRA55-do/v1-3/t_10.1995.18Oct2017.nc /g/data/e14/erd561/JRA55-do/v1-3/t_10.1995.18Oct2017.nc
# It is already there!
#
# $ ncra -d longitude,90.0,180.0 -d latitude,-70.0,20.0 -v tas_10m /g/data/ua8/JRA55-do/v1-3/t_10.1996.18Oct2017.nc /g/data/e14/erd561/JRA55-do/v1-3/t_10.1996.18Oct2017.nc
# It is already there!
#
# $ ncra -d longitude,90.0,180.0 -d latitude,-70.0,20.0 -v tas_10m /g/data/ua8/JRA55-do/v1-3/t_10.1997.18Oct2017.nc /g/data/e14/erd561/JRA55-do/v1-3/t_10.1997.18Oct2017.nc
# It is already there!
#
# $ ncra -d longitude,90.0,180.0 -d latitude,-70.0,20.0 -v tas_10m /g/data/ua8/JRA55-do/v1-3/t_10.1998.18Oct2017.nc /g/data/e14/erd561/JRA55-do/v1-3/t_10.1998.18Oct2017.nc
# It is already there!
#
# $ ncra -d longitude,90.0,180.0 -d latitude,-70.0,20.0 -v tas_10m /g/data/ua8/JRA55-do/v1-3/t_10.1999.18Oct2017.nc /g/data/e14/erd561/JRA55-do/v1-3/t_10.1999.18Oct2017.nc
# It is already there!
#
# $ ncra -d longitude,90.0,180.0 -d latitude,-70.0,20.0 -v tas_10m /g/data/ua8/JRA55-do/v1-3/t_10.2000.18Oct2017.nc /g/data/e14/erd561/JRA55-do/v1-3/t_10.2000.18Oct2017.nc
# It is already there!
#
# $ ncra -d longitude,90.0,180.0 -d latitude,-70.0,20.0 -v tas_10m /g/data/ua8/JRA55-do/v1-3/t_10.2001.18Oct2017.nc /g/data/e14/erd561/JRA55-do/v1-3/t_10.2001.18Oct2017.nc
# It is already there!
#
# $ ncra -d longitude,90.0,180.0 -d latitude,-70.0,20.0 -v tas_10m /g/data/ua8/JRA55-do/v1-3/t_10.2002.18Oct2017.nc /g/data/e14/erd561/JRA55-do/v1-3/t_10.2002.18Oct2017.nc
# It is already there!
#
# $ ncra -d longitude,90.0,180.0 -d latitude,-70.0,20.0 -v tas_10m /g/data/ua8/JRA55-do/v1-3/t_10.2003.18Oct2017.nc /g/data/e14/erd561/JRA55-do/v1-3/t_10.2003.18Oct2017.nc
# It is already there!
#
# $ ncra -d longitude,90.0,180.0 -d latitude,-70.0,20.0 -v tas_10m /g/data/ua8/JRA55-do/v1-3/t_10.2004.18Oct2017.nc /g/data/e14/erd561/JRA55-do/v1-3/t_10.2004.18Oct2017.nc
# It is already there!
#
# $ ncra -d longitude,90.0,180.0 -d latitude,-70.0,20.0 -v tas_10m /g/data/ua8/JRA55-do/v1-3/t_10.2005.18Oct2017.nc /g/data/e14/erd561/JRA55-do/v1-3/t_10.2005.18Oct2017.nc
# It is already there!
#
# $ ncra -d longitude,90.0,180.0 -d latitude,-70.0,20.0 -v tas_10m /g/data/ua8/JRA55-do/v1-3/t_10.2006.18Oct2017.nc /g/data/e14/erd561/JRA55-do/v1-3/t_10.2006.18Oct2017.nc
# It is already there!
#
# $ ncra -d longitude,90.0,180.0 -d latitude,-70.0,20.0 -v tas_10m /g/data/ua8/JRA55-do/v1-3/t_10.2007.18Oct2017.nc /g/data/e14/erd561/JRA55-do/v1-3/t_10.2007.18Oct2017.nc
# It is already there!
#
# $ ncra -d longitude,90.0,180.0 -d latitude,-70.0,20.0 -v tas_10m /g/data/ua8/JRA55-do/v1-3/t_10.2008.18Oct2017.nc /g/data/e14/erd561/JRA55-do/v1-3/t_10.2008.18Oct2017.nc
# It is already there!
#
# $ ncra -d longitude,90.0,180.0 -d latitude,-70.0,20.0 -v tas_10m /g/data/ua8/JRA55-do/v1-3/t_10.2009.18Oct2017.nc /g/data/e14/erd561/JRA55-do/v1-3/t_10.2009.18Oct2017.nc
# It is already there!
#
# $ ncra -d longitude,90.0,180.0 -d latitude,-70.0,20.0 -v tas_10m /g/data/ua8/JRA55-do/v1-3/t_10.2010.18Oct2017.nc /g/data/e14/erd561/JRA55-do/v1-3/t_10.2010.18Oct2017.nc
# It is already there!
#
# $ ncra -d longitude,90.0,180.0 -d latitude,-70.0,20.0 -v tas_10m /g/data/ua8/JRA55-do/v1-3/t_10.2011.18Oct2017.nc /g/data/e14/erd561/JRA55-do/v1-3/t_10.2011.18Oct2017.nc
# It is already there!
#
# $ ncra -d longitude,90.0,180.0 -d latitude,-70.0,20.0 -v tas_10m /g/data/ua8/JRA55-do/v1-3/t_10.2012.18Oct2017.nc /g/data/e14/erd561/JRA55-do/v1-3/t_10.2012.18Oct2017.nc
# It is already there!
#
# $ ncra -d longitude,90.0,180.0 -d latitude,-70.0,20.0 -v tas_10m /g/data/ua8/JRA55-do/v1-3/t_10.2013.18Oct2017.nc /g/data/e14/erd561/JRA55-do/v1-3/t_10.2013.18Oct2017.nc
# It is already there!
#
# $ ncra -d longitude,90.0,180.0 -d latitude,-70.0,20.0 -v tas_10m /g/data/ua8/JRA55-do/v1-3/t_10.2014.18Oct2017.nc /g/data/e14/erd561/JRA55-do/v1-3/t_10.2014.18Oct2017.nc
# It is already there!
#
# $ ncra -d longitude,90.0,180.0 -d latitude,-70.0,20.0 -v tas_10m /g/data/ua8/JRA55-do/v1-3/t_10.2015.18Oct2017.nc /g/data/e14/erd561/JRA55-do/v1-3/t_10.2015.18Oct2017.nc
# It is already there!
#
# $ ncra -d longitude,90.0,180.0 -d latitude,-70.0,20.0 -v tas_10m /g/data/ua8/JRA55-do/v1-3/t_10.2016.18Oct2017.nc /g/data/e14/erd561/JRA55-do/v1-3/t_10.2016.18Oct2017.nc
# It is already there!
#
# $ ncra -d longitude,90.0,180.0 -d latitude,-70.0,20.0 -v tas_10m /g/data/ua8/JRA55-do/v1-3/t_10.2017.14Jan2018.nc /g/data/e14/erd561/JRA55-do/v1-3/t_10.2017.14Jan2018.nc
# It is already there!
#
# $ ncra -d longitude,90.0,180.0 -d latitude,-70.0,20.0 -v prrn /g/data/ua8/JRA55-do/v1-3/rain.1993.18Oct2017.nc /g/data/e14/erd561/JRA55-do/v1-3/rain.1993.18Oct2017.nc
# It is already there!
#
# $ ncra -d longitude,90.0,180.0 -d latitude,-70.0,20.0 -v prrn /g/data/ua8/JRA55-do/v1-3/rain.1994.18Oct2017.nc /g/data/e14/erd561/JRA55-do/v1-3/rain.1994.18Oct2017.nc
# It is already there!
#
# $ ncra -d longitude,90.0,180.0 -d latitude,-70.0,20.0 -v prrn /g/data/ua8/JRA55-do/v1-3/rain.1995.18Oct2017.nc /g/data/e14/erd561/JRA55-do/v1-3/rain.1995.18Oct2017.nc
# It is already there!
#
# $ ncra -d longitude,90.0,180.0 -d latitude,-70.0,20.0 -v prrn /g/data/ua8/JRA55-do/v1-3/rain.1996.18Oct2017.nc /g/data/e14/erd561/JRA55-do/v1-3/rain.1996.18Oct2017.nc
# It is already there!
#
# $ ncra -d longitude,90.0,180.0 -d latitude,-70.0,20.0 -v prrn /g/data/ua8/JRA55-do/v1-3/rain.1997.18Oct2017.nc /g/data/e14/erd561/JRA55-do/v1-3/rain.1997.18Oct2017.nc
# It is already there!
#
# $ ncra -d longitude,90.0,180.0 -d latitude,-70.0,20.0 -v prrn /g/data/ua8/JRA55-do/v1-3/rain.1998.18Oct2017.nc /g/data/e14/erd561/JRA55-do/v1-3/rain.1998.18Oct2017.nc
# It is already there!
#
# $ ncra -d longitude,90.0,180.0 -d latitude,-70.0,20.0 -v prrn /g/data/ua8/JRA55-do/v1-3/rain.1999.18Oct2017.nc /g/data/e14/erd561/JRA55-do/v1-3/rain.1999.18Oct2017.nc
# It is already there!
#
# $ ncra -d longitude,90.0,180.0 -d latitude,-70.0,20.0 -v prrn /g/data/ua8/JRA55-do/v1-3/rain.2000.18Oct2017.nc /g/data/e14/erd561/JRA55-do/v1-3/rain.2000.18Oct2017.nc
# It is already there!
#
# $ ncra -d longitude,90.0,180.0 -d latitude,-70.0,20.0 -v prrn /g/data/ua8/JRA55-do/v1-3/rain.2001.18Oct2017.nc /g/data/e14/erd561/JRA55-do/v1-3/rain.2001.18Oct2017.nc
# It is already there!
#
# $ ncra -d longitude,90.0,180.0 -d latitude,-70.0,20.0 -v prrn /g/data/ua8/JRA55-do/v1-3/rain.2002.18Oct2017.nc /g/data/e14/erd561/JRA55-do/v1-3/rain.2002.18Oct2017.nc
# It is already there!
#
# $ ncra -d longitude,90.0,180.0 -d latitude,-70.0,20.0 -v prrn /g/data/ua8/JRA55-do/v1-3/rain.2003.18Oct2017.nc /g/data/e14/erd561/JRA55-do/v1-3/rain.2003.18Oct2017.nc
# It is already there!
#
# $ ncra -d longitude,90.0,180.0 -d latitude,-70.0,20.0 -v prrn /g/data/ua8/JRA55-do/v1-3/rain.2004.18Oct2017.nc /g/data/e14/erd561/JRA55-do/v1-3/rain.2004.18Oct2017.nc
# It is already there!
#
# $ ncra -d longitude,90.0,180.0 -d latitude,-70.0,20.0 -v prrn /g/data/ua8/JRA55-do/v1-3/rain.2005.18Oct2017.nc /g/data/e14/erd561/JRA55-do/v1-3/rain.2005.18Oct2017.nc
# It is already there!
#
# $ ncra -d longitude,90.0,180.0 -d latitude,-70.0,20.0 -v prrn /g/data/ua8/JRA55-do/v1-3/rain.2006.18Oct2017.nc /g/data/e14/erd561/JRA55-do/v1-3/rain.2006.18Oct2017.nc
# It is already there!
#
# $ ncra -d longitude,90.0,180.0 -d latitude,-70.0,20.0 -v prrn /g/data/ua8/JRA55-do/v1-3/rain.2007.18Oct2017.nc /g/data/e14/erd561/JRA55-do/v1-3/rain.2007.18Oct2017.nc
# It is already there!
#
# $ ncra -d longitude,90.0,180.0 -d latitude,-70.0,20.0 -v prrn /g/data/ua8/JRA55-do/v1-3/rain.2008.18Oct2017.nc /g/data/e14/erd561/JRA55-do/v1-3/rain.2008.18Oct2017.nc
# It is already there!
#
# $ ncra -d longitude,90.0,180.0 -d latitude,-70.0,20.0 -v prrn /g/data/ua8/JRA55-do/v1-3/rain.2009.18Oct2017.nc /g/data/e14/erd561/JRA55-do/v1-3/rain.2009.18Oct2017.nc
# It is already there!
#
# $ ncra -d longitude,90.0,180.0 -d latitude,-70.0,20.0 -v prrn /g/data/ua8/JRA55-do/v1-3/rain.2010.18Oct2017.nc /g/data/e14/erd561/JRA55-do/v1-3/rain.2010.18Oct2017.nc
# It is already there!
#
# $ ncra -d longitude,90.0,180.0 -d latitude,-70.0,20.0 -v prrn /g/data/ua8/JRA55-do/v1-3/rain.2011.18Oct2017.nc /g/data/e14/erd561/JRA55-do/v1-3/rain.2011.18Oct2017.nc
# It is already there!
#
# $ ncra -d longitude,90.0,180.0 -d latitude,-70.0,20.0 -v prrn /g/data/ua8/JRA55-do/v1-3/rain.2012.18Oct2017.nc /g/data/e14/erd561/JRA55-do/v1-3/rain.2012.18Oct2017.nc
# It is already there!
#
# $ ncra -d longitude,90.0,180.0 -d latitude,-70.0,20.0 -v prrn /g/data/ua8/JRA55-do/v1-3/rain.2013.18Oct2017.nc /g/data/e14/erd561/JRA55-do/v1-3/rain.2013.18Oct2017.nc
# It is already there!
#
# $ ncra -d longitude,90.0,180.0 -d latitude,-70.0,20.0 -v prrn /g/data/ua8/JRA55-do/v1-3/rain.2014.18Oct2017.nc /g/data/e14/erd561/JRA55-do/v1-3/rain.2014.18Oct2017.nc
# It is already there!
#
# $ ncra -d longitude,90.0,180.0 -d latitude,-70.0,20.0 -v prrn /g/data/ua8/JRA55-do/v1-3/rain.2015.18Oct2017.nc /g/data/e14/erd561/JRA55-do/v1-3/rain.2015.18Oct2017.nc
# It is already there!
#
# $ ncra -d longitude,90.0,180.0 -d latitude,-70.0,20.0 -v prrn /g/data/ua8/JRA55-do/v1-3/rain.2016.18Oct2017.nc /g/data/e14/erd561/JRA55-do/v1-3/rain.2016.18Oct2017.nc
# It is already there!
#
# $ ncra -d longitude,90.0,180.0 -d latitude,-70.0,20.0 -v prrn /g/data/ua8/JRA55-do/v1-3/rain.2017.14Jan2018.nc /g/data/e14/erd561/JRA55-do/v1-3/rain.2017.14Jan2018.nc
# It is already there!
#
# $ ncra -d longitude,90.0,180.0 -d latitude,-70.0,20.0 -v psl /g/data/ua8/JRA55-do/v1-3/slp.1993.18Aug2017.nc /g/data/e14/erd561/JRA55-do/v1-3/slp.1993.18Aug2017.nc
# It is already there!
#
# $ ncra -d longitude,90.0,180.0 -d latitude,-70.0,20.0 -v psl /g/data/ua8/JRA55-do/v1-3/slp.1994.18Aug2017.nc /g/data/e14/erd561/JRA55-do/v1-3/slp.1994.18Aug2017.nc
# It is already there!
#
# $ ncra -d longitude,90.0,180.0 -d latitude,-70.0,20.0 -v psl /g/data/ua8/JRA55-do/v1-3/slp.1995.18Aug2017.nc /g/data/e14/erd561/JRA55-do/v1-3/slp.1995.18Aug2017.nc
# It is already there!
#
# $ ncra -d longitude,90.0,180.0 -d latitude,-70.0,20.0 -v psl /g/data/ua8/JRA55-do/v1-3/slp.1996.18Aug2017.nc /g/data/e14/erd561/JRA55-do/v1-3/slp.1996.18Aug2017.nc
# It is already there!
#
# $ ncra -d longitude,90.0,180.0 -d latitude,-70.0,20.0 -v psl /g/data/ua8/JRA55-do/v1-3/slp.1997.18Aug2017.nc /g/data/e14/erd561/JRA55-do/v1-3/slp.1997.18Aug2017.nc
# It is already there!
#
# $ ncra -d longitude,90.0,180.0 -d latitude,-70.0,20.0 -v psl /g/data/ua8/JRA55-do/v1-3/slp.1998.18Aug2017.nc /g/data/e14/erd561/JRA55-do/v1-3/slp.1998.18Aug2017.nc
# It is already there!
#
# $ ncra -d longitude,90.0,180.0 -d latitude,-70.0,20.0 -v psl /g/data/ua8/JRA55-do/v1-3/slp.1999.18Aug2017.nc /g/data/e14/erd561/JRA55-do/v1-3/slp.1999.18Aug2017.nc
# It is already there!
#
# $ ncra -d longitude,90.0,180.0 -d latitude,-70.0,20.0 -v psl /g/data/ua8/JRA55-do/v1-3/slp.2000.18Aug2017.nc /g/data/e14/erd561/JRA55-do/v1-3/slp.2000.18Aug2017.nc
# It is already there!
#
# $ ncra -d longitude,90.0,180.0 -d latitude,-70.0,20.0 -v psl /g/data/ua8/JRA55-do/v1-3/slp.2001.18Aug2017.nc /g/data/e14/erd561/JRA55-do/v1-3/slp.2001.18Aug2017.nc
# It is already there!
#
# $ ncra -d longitude,90.0,180.0 -d latitude,-70.0,20.0 -v psl /g/data/ua8/JRA55-do/v1-3/slp.2002.18Aug2017.nc /g/data/e14/erd561/JRA55-do/v1-3/slp.2002.18Aug2017.nc
# It is already there!
#
# $ ncra -d longitude,90.0,180.0 -d latitude,-70.0,20.0 -v psl /g/data/ua8/JRA55-do/v1-3/slp.2003.18Aug2017.nc /g/data/e14/erd561/JRA55-do/v1-3/slp.2003.18Aug2017.nc
# It is already there!
#
# $ ncra -d longitude,90.0,180.0 -d latitude,-70.0,20.0 -v psl /g/data/ua8/JRA55-do/v1-3/slp.2004.18Aug2017.nc /g/data/e14/erd561/JRA55-do/v1-3/slp.2004.18Aug2017.nc
# It is already there!
#
# $ ncra -d longitude,90.0,180.0 -d latitude,-70.0,20.0 -v psl /g/data/ua8/JRA55-do/v1-3/slp.2005.18Aug2017.nc /g/data/e14/erd561/JRA55-do/v1-3/slp.2005.18Aug2017.nc
# It is already there!
#
# $ ncra -d longitude,90.0,180.0 -d latitude,-70.0,20.0 -v psl /g/data/ua8/JRA55-do/v1-3/slp.2006.18Aug2017.nc /g/data/e14/erd561/JRA55-do/v1-3/slp.2006.18Aug2017.nc
# It is already there!
#
# $ ncra -d longitude,90.0,180.0 -d latitude,-70.0,20.0 -v psl /g/data/ua8/JRA55-do/v1-3/slp.2007.18Aug2017.nc /g/data/e14/erd561/JRA55-do/v1-3/slp.2007.18Aug2017.nc
# It is already there!
#
# $ ncra -d longitude,90.0,180.0 -d latitude,-70.0,20.0 -v psl /g/data/ua8/JRA55-do/v1-3/slp.2008.18Aug2017.nc /g/data/e14/erd561/JRA55-do/v1-3/slp.2008.18Aug2017.nc
# It is already there!
#
# $ ncra -d longitude,90.0,180.0 -d latitude,-70.0,20.0 -v psl /g/data/ua8/JRA55-do/v1-3/slp.2009.18Aug2017.nc /g/data/e14/erd561/JRA55-do/v1-3/slp.2009.18Aug2017.nc
# It is already there!
#
# $ ncra -d longitude,90.0,180.0 -d latitude,-70.0,20.0 -v psl /g/data/ua8/JRA55-do/v1-3/slp.2010.18Aug2017.nc /g/data/e14/erd561/JRA55-do/v1-3/slp.2010.18Aug2017.nc
# It is already there!
#
# $ ncra -d longitude,90.0,180.0 -d latitude,-70.0,20.0 -v psl /g/data/ua8/JRA55-do/v1-3/slp.2011.18Aug2017.nc /g/data/e14/erd561/JRA55-do/v1-3/slp.2011.18Aug2017.nc
# It is already there!
#
# $ ncra -d longitude,90.0,180.0 -d latitude,-70.0,20.0 -v psl /g/data/ua8/JRA55-do/v1-3/slp.2012.18Aug2017.nc /g/data/e14/erd561/JRA55-do/v1-3/slp.2012.18Aug2017.nc
# It is already there!
#
# $ ncra -d longitude,90.0,180.0 -d latitude,-70.0,20.0 -v psl /g/data/ua8/JRA55-do/v1-3/slp.2013.18Aug2017.nc /g/data/e14/erd561/JRA55-do/v1-3/slp.2013.18Aug2017.nc
# It is already there!
#
# $ ncra -d longitude,90.0,180.0 -d latitude,-70.0,20.0 -v psl /g/data/ua8/JRA55-do/v1-3/slp.2014.18Aug2017.nc /g/data/e14/erd561/JRA55-do/v1-3/slp.2014.18Aug2017.nc
# It is already there!
#
# $ ncra -d longitude,90.0,180.0 -d latitude,-70.0,20.0 -v psl /g/data/ua8/JRA55-do/v1-3/slp.2015.18Aug2017.nc /g/data/e14/erd561/JRA55-do/v1-3/slp.2015.18Aug2017.nc
# It is already there!
#
# $ ncra -d longitude,90.0,180.0 -d latitude,-70.0,20.0 -v psl /g/data/ua8/JRA55-do/v1-3/slp.2016.18Aug2017.nc /g/data/e14/erd561/JRA55-do/v1-3/slp.2016.18Aug2017.nc
# It is already there!
#
# $ ncra -d longitude,90.0,180.0 -d latitude,-70.0,20.0 -v psl /g/data/ua8/JRA55-do/v1-3/slp.2017.14Jan2018.nc /g/data/e14/erd561/JRA55-do/v1-3/slp.2017.14Jan2018.nc
# It is already there!

# %%
# %%javascript
# IPython.notebook.kernel.execute('nb_name = ' + '"' + IPython.notebook.notebook_name + '"')

# %%
# use common start and end dates for all runs
tstart = exptdata.clim_tstart
tend = exptdata.clim_tend

firstyear = pd.to_datetime(tstart).year  # assumes tstart is 1 January!
lastyear = pd.to_datetime(tend).year-1  # assumes tend is 1 January!
yearrange = str(firstyear)+'-'+str(lastyear)
print(yearrange)
print('tstart = ', tstart)
print('tend = ', tend)

output_dir = '/home/561/erd561/figures/Australia/'
fig_name = nb_name[:-6]
fig_dir = output_dir + fig_name

output_ls = os.listdir(output_dir)
if fig_name not in output_ls:
    os.mkdir(fig_dir)
# Out:
# 1993-2017
# tstart =  1993-01-01 00:00:00
# tend =  2018-01-01 00:00:00

# %%
# %%time

from dask.distributed import Client
c = Client()
print(c)
# Out:
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-18.10/lib/python3.6/site-packages/distributed/bokeh/core.py:57: UserWarning:
# Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the diagnostics dashboard on a random port instead.
#   warnings.warn('\n' + msg)
# <Client: scheduler='tcp://127.0.0.1:43734' processes=8 cores=8>
# CPU times: user 650 ms, sys: 142 ms, total: 792 ms
# Wall time: 5.58 s

# %%
# %%time
latS = -70
latN = 20
lonW = 90-360
lonE = 180-360
ekey='01deg'
expt = exptdata.exptdict[ekey]['expt']
time_units = exptdata.exptdict[ekey]['time_units']
n_files = exptdata.exptdict[ekey]['n_files']
offset = exptdata.exptdict[ekey]['offset']
print(expt)
print(time_units)
print(n_files)
print(offset)

output_path = '/g/data/e14/erd561/01deg_jra55v13_iaf/'
pls_out = os.listdir(output_path)

for y in years:
    output_name = 'eta_'+str(y)+'.nc'
    print(output_name+'...')
    
    if output_name in pls_out:
        print('It is already there! \n')
    else:
        eta_t_01_now = cc.get_nc_variable(expt,'ocean_daily.nc','eta_t',
                                          time_units=time_units,n=n_files,offset=offset).\
                                            sel(time=slice(str(y)+'-01-01 00:00:00',str(y+1)+'-01-01 00:00:00')).\
                                            sel(yt_ocean=slice(latS,latN)).\
                                            sel(xt_ocean=slice(lonW,lonE)).\
                                            mean(dim='time')
        eta_t_01_now.load()
        eta_t_01_now.to_netcdf(path=output_path+output_name)
        print('Done. \n')
# Out:
# 01deg_jra55v13_iaf
# days since 0001-01-01
# None
# None
# eta_1993.nc...
# It is already there!
#
# eta_1994.nc...
# It is already there!
#
# eta_1995.nc...
# It is already there!
#
# eta_1996.nc...
# It is already there!
#
# eta_1997.nc...
# It is already there!
#
# eta_1998.nc...
# It is already there!
#
# eta_1999.nc...
# It is already there!
#
# eta_2000.nc...
# It is already there!
#
# eta_2001.nc...
# It is already there!
#
# eta_2002.nc...
# It is already there!
#
# eta_2003.nc...
# It is already there!
#
# eta_2004.nc...
# It is already there!
#
# eta_2005.nc...
# It is already there!
#
# eta_2006.nc...
# It is already there!
#
# eta_2007.nc...
# It is already there!
#
# eta_2008.nc...
# It is already there!
#
# eta_2009.nc...
# It is already there!
#
# eta_2010.nc...
# It is already there!
#
# eta_2011.nc...
# It is already there!
#
# eta_2012.nc...
# It is already there!
#
# eta_2013.nc...
# It is already there!
#
# eta_2014.nc...
# It is already there!
#
# eta_2015.nc...
# It is already there!
#
# eta_2016.nc...
# It is already there!
#
# eta_2017.nc...
# It is already there!
#
# CPU times: user 6 ms, sys: 6 ms, total: 12 ms
# Wall time: 10.5 ms

# %% [markdown]
# **The function below** calculates the quasi-barotropic streamfunction for each simulation. In each case, we read in only the last IAF cycle, then we average over the standard time period.

# %%
# %%time
latS = -70
latN = 20
lonW = 90-360
lonE = 180-360
ekey='01deg'
expt = exptdata.exptdict[ekey]['expt']
time_units = exptdata.exptdict[ekey]['time_units']
n_files = exptdata.exptdict[ekey]['n_files']
offset = exptdata.exptdict[ekey]['offset']
print(expt)
print(time_units)
print(n_files)
print(offset)
temp_01_month = cc.get_nc_variable(expt,'ocean.nc','temp',time_units=time_units,n=n_files,offset=offset).\
                            sel(time=slice(exptdata.clim_tstart,exptdata.clim_tend)).\
                            sel(yt_ocean=slice(latS,latN)).\
                            sel(xt_ocean=slice(lonW,lonE)).\
                            sel(st_ocean=0,method='nearest')

temp_01_month.load()
print(temp_01_month)
# Out:
# 01deg_jra55v13_iaf
# days since 0001-01-01
# None
# None
# Using database sqlite:////g/data3/hh5/tmp/cosima/cosima-cookbook/cosima-cookbook.db
# <xarray.DataArray 'temp' (time: 300, yt_ocean: 1186, xt_ocean: 900)>
# array([[[      nan,       nan, ..., 273.2834 , 273.28915],
#         [      nan,       nan, ..., 273.3283 , 273.32913],
#         ...,
#         [297.29062, 297.22516, ..., 296.99734, 296.98264],
#         [297.23898, 297.2167 , ..., 296.98074, 296.95886]],
#
#        [[      nan,       nan, ..., 272.81653, 272.78738],
#         [      nan,       nan, ..., 272.85275, 272.8095 ],
#         ...,
#         [297.4436 , 297.21423, ..., 296.58884, 296.58023],
#         [297.4397 , 297.22632, ..., 296.57843, 296.56793]],
#
#        ...,
#
#        [[      nan,       nan, ..., 271.3473 , 271.3471 ],
#         [      nan,       nan, ..., 271.34662, 271.34634],
#         ...,
#         [301.4287 , 301.43378, ..., 300.3649 , 300.37512],
#         [301.376  , 301.3831 , ..., 300.3404 , 300.3514 ]],
#
#        [[      nan,       nan, ..., 271.50793, 271.5068 ],
#         [      nan,       nan, ..., 271.50647, 271.50592],
#         ...,
#         [299.68155, 299.70157, ..., 299.76794, 299.8079 ],
#         [299.6742 , 299.69937, ..., 299.79724, 299.83835]]], dtype=float32)
# Coordinates:
#     st_ocean  float64 0.5413
#   * xt_ocean  (xt_ocean) float64 -269.9 -269.8 -269.7 ... -180.2 -180.1 -180.0
#   * yt_ocean  (yt_ocean) float64 -70.0 -69.96 -69.92 ... 19.75 19.84 19.94
#   * time      (time) datetime64[ns] 1993-01-14T12:00:00 ... 2017-12-14T12:00:00
# Attributes:
#     long_name:      Potential temperature
#     units:          degrees K
#     valid_range:    [-10. 500.]
#     cell_methods:   time: mean
#     time_avg_info:  average_T1,average_T2,average_DT
#     coordinates:    geolon_t geolat_t
#     standard_name:  sea_water_potential_temperature
# CPU times: user 59.7 s, sys: 22 s, total: 1min 21s
# Wall time: 1min 51s

# %%
# %%time
latS = -70
latN = 20
lonW = 90-360
lonE = 180-360
ekey='01deg'
expt = exptdata.exptdict[ekey]['expt']
time_units = exptdata.exptdict[ekey]['time_units']
n_files = exptdata.exptdict[ekey]['n_files']
offset = exptdata.exptdict[ekey]['offset']
print(expt)
print(time_units)
print(n_files)
print(offset)
net_sfc_heating_01_month = cc.get_nc_variable(expt,'ocean_month.nc','net_sfc_heating',
                                              time_units=time_units,n=n_files,offset=offset).\
                            sel(time=slice(exptdata.clim_tstart,exptdata.clim_tend)).\
                            sel(yt_ocean=slice(latS,latN)).\
                            sel(xt_ocean=slice(lonW,lonE))

net_sfc_heating_01_month.load()
print(net_sfc_heating_01_month)
# Out:
# 01deg_jra55v13_iaf
# days since 0001-01-01
# None
# None
# Using database sqlite:////g/data3/hh5/tmp/cosima/cosima-cookbook/cosima-cookbook.db
# <xarray.DataArray 'net_sfc_heating' (time: 300, yt_ocean: 1186, xt_ocean: 900)>
# array([[[        nan,         nan, ...,   73.95019 ,   73.664635],
#         [        nan,         nan, ...,   74.20993 ,   74.13813 ],
#         ...,
#         [ -59.74891 ,  -59.834522, ..., -119.41805 , -119.12735 ],
#         [ -58.49758 ,  -59.650253, ..., -119.3002  , -118.6057  ]],
#
#        [[        nan,         nan, ...,    0.417274,    1.799418],
#         [        nan,         nan, ...,    0.480736,    2.270612],
#         ...,
#         [  35.487507,   41.167496, ...,   40.059914,   39.96129 ],
#         [  35.74279 ,   41.112057, ...,   40.411568,   40.378933]],
#
#        ...,
#
#        [[        nan,         nan, ...,  -10.777585,  -10.811475],
#         [        nan,         nan, ...,  -10.425101,  -10.414084],
#         ...,
#         [ -88.918655,  -87.57773 , ...,  -75.20655 ,  -75.508705],
#         [ -87.751656,  -86.51318 , ...,  -74.22955 ,  -74.57782 ]],
#
#        [[        nan,         nan, ...,   14.38251 ,   14.294111],
#         [        nan,         nan, ...,   14.61615 ,   14.501623],
#         ...,
#         [-101.630066, -100.998985, ..., -172.14192 , -175.06602 ],
#         [-101.78682 , -101.48961 , ..., -175.36461 , -178.22807 ]]],
#       dtype=float32)
# Coordinates:
#   * yt_ocean  (yt_ocean) float64 -70.0 -69.96 -69.92 ... 19.75 19.84 19.94
#   * xt_ocean  (xt_ocean) float64 -269.9 -269.8 -269.7 ... -180.2 -180.1 -180.0
#   * time      (time) datetime64[ns] 1993-01-14T12:00:00 ... 2017-12-14T12:00:00
# Attributes:
#     long_name:      surface ocean heat flux coming through coupler and mass t...
#     units:          Watts/m^2
#     valid_range:    [-10000.  10000.]
#     cell_methods:   time: mean
#     time_avg_info:  average_T1,average_T2,average_DT
#     coordinates:    geolon_t geolat_t
# CPU times: user 38.4 s, sys: 17.6 s, total: 56 s
# Wall time: 1min 18s

# %%
# %%time
latS = -80
latN = 20
lonW = 90-360
lonE = 180-360
ekey='01deg'
expt = exptdata.exptdict[ekey]['expt']
time_units = exptdata.exptdict[ekey]['time_units']
n_files = exptdata.exptdict[ekey]['n_files']
offset = exptdata.exptdict[ekey]['offset']
print(expt)
print(time_units)
print(n_files)
print(offset)
tx_trans_int_z_01_month = \
cc.get_nc_variable(expt,'ocean_month.nc','tx_trans_int_z',time_units=time_units,n=n_files,offset=offset).\
                            sel(time=slice(exptdata.clim_tstart,exptdata.clim_tend)).\
                            sel(yt_ocean=slice(latS,latN)).\
                            sel(xu_ocean=slice(lonW,lonE))

tx_trans_int_z_01_month.load()
print(tx_trans_int_z_01_month)

tx_trans_int_z_01 = tx_trans_int_z_01_month.groupby('time.year').mean('time', skipna=True)
print(tx_trans_int_z_01)

tx_trans_int_z_01_cumsum_yt_ocean = tx_trans_int_z_01.cumsum('yt_ocean')
print(tx_trans_int_z_01_cumsum_yt_ocean)

tx_trans_int_z_01_cumsum_yt_ocean_Sv = tx_trans_int_z_01_cumsum_yt_ocean/1e6/1036
print(tx_trans_int_z_01_cumsum_yt_ocean_Sv)

S_Africa_mean_trans_cumsum_yt_ocean = \
cc.get_nc_variable(expt,'ocean_month.nc','tx_trans_int_z',time_units=time_units,n=n_files,offset=offset).\
                            sel(time=slice(exptdata.clim_tstart,exptdata.clim_tend)).\
                            sel(yt_ocean=slice(-80,20)).\
                            sel(xu_ocean=0, method='nearest').\
                            mean(dim='time').\
                            cumsum(dim='yt_ocean')

S_Africa_mean_trans_cumsum_yt_ocean.load()
print(S_Africa_mean_trans_cumsum_yt_ocean)

S_Africa_mean_trans_Sv = S_Africa_mean_trans_cumsum_yt_ocean.sel(yt_ocean=20,method='nearest')/1e6/1036
print(S_Africa_mean_trans_Sv)

gyre_psi = -tx_trans_int_z_01_cumsum_yt_ocean_Sv + S_Africa_mean_trans_Sv
gyre_psi = gyre_psi.where((np.isfinite(tx_trans_int_z_01.sel(year=1993))), np.nan)
print(gyre_psi)
# Out:
# 01deg_jra55v13_iaf
# days since 0001-01-01
# None
# None
# Using database sqlite:////g/data3/hh5/tmp/cosima/cosima-cookbook/cosima-cookbook.db
# <xarray.DataArray 'tx_trans_int_z' (time: 300, yt_ocean: 1422, xu_ocean: 900)>
# array([[[          nan,           nan, ...,           nan,           nan],
#         [          nan,           nan, ...,           nan,           nan],
#         ...,
#         [ 1.002303e+09,  9.808709e+08, ..., -2.955912e+08, -3.110470e+08],
#         [ 9.055537e+08,  8.178639e+08, ..., -1.935897e+08, -1.869565e+08]],
#
#        [[          nan,           nan, ...,           nan,           nan],
#         [          nan,           nan, ...,           nan,           nan],
#         ...,
#         [-2.716170e+08, -3.530489e+08, ..., -1.382664e+08, -1.573675e+08],
#         [-2.211324e+08, -2.516969e+08, ..., -7.907192e+07, -7.468176e+07]],
#
#        ...,
#
#        [[          nan,           nan, ...,           nan,           nan],
#         [          nan,           nan, ...,           nan,           nan],
#         ...,
#         [ 1.804317e+08,  2.473191e+08, ...,  5.120025e+06,  2.853695e+07],
#         [ 2.134827e+08,  2.552260e+08, ..., -2.411145e+08, -2.074115e+08]],
#
#        [[          nan,           nan, ...,           nan,           nan],
#         [          nan,           nan, ...,           nan,           nan],
#         ...,
#         [ 1.920677e+08,  2.051564e+08, ...,  2.883028e+08,  2.970020e+08],
#         [ 1.751639e+08,  1.438553e+08, ...,  1.213767e+08,  1.551021e+08]]],
#       dtype=float32)
# Coordinates:
#   * yt_ocean  (yt_ocean) float64 -79.97 -79.93 -79.88 ... 19.75 19.84 19.94
#   * xu_ocean  (xu_ocean) float64 -270.0 -269.9 -269.8 ... -180.3 -180.2 -180.1
#   * time      (time) datetime64[ns] 1993-01-14T12:00:00 ... 2017-12-14T12:00:00
# Attributes:
#     long_name:      T-cell i-mass transport vertically summed
#     units:          kg/s
#     valid_range:    [-1.e+20  1.e+20]
#     cell_methods:   time: mean
#     time_avg_info:  average_T1,average_T2,average_DT
#     coordinates:    geolon_c geolat_t
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-18.10/lib/python3.6/site-packages/xarray/core/nanops.py:161: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis=axis, dtype=dtype)
# <xarray.DataArray 'tx_trans_int_z' (year: 25, yt_ocean: 1422, xu_ocean: 900)>
# array([[[          nan,           nan, ...,           nan,           nan],
#         [          nan,           nan, ...,           nan,           nan],
#         ...,
#         [ 9.133071e+07,  8.744392e+07, ..., -3.591640e+08, -3.952564e+08],
#         [ 6.212730e+07,  3.938682e+07, ..., -3.847262e+08, -4.029349e+08]],
#
#        [[          nan,           nan, ...,           nan,           nan],
#         [          nan,           nan, ...,           nan,           nan],
#         ...,
#         [ 8.921763e+06,  2.962935e+07, ...,  5.983166e+07,  7.410160e+07],
#         [ 2.823953e+06, -2.708065e+06, ...,  4.543419e+07,  5.540056e+07]],
#
#        ...,
#
#        [[          nan,           nan, ...,           nan,           nan],
#         [          nan,           nan, ...,           nan,           nan],
#         ...,
#         [ 9.590940e+07,  8.956228e+07, ...,  2.004658e+08,  1.623845e+08],
#         [ 7.483169e+07,  3.959176e+07, ...,  1.871767e+08,  1.643687e+08]],
#
#        [[          nan,           nan, ...,           nan,           nan],
#         [          nan,           nan, ...,           nan,           nan],
#         ...,
#         [-1.547749e+08, -1.152636e+08, ...,  1.661295e+08,  1.412780e+08],
#         [-1.793806e+08, -1.598759e+08, ...,  8.441069e+07,  7.251121e+07]]],
#       dtype=float32)
# Coordinates:
#   * yt_ocean  (yt_ocean) float64 -79.97 -79.93 -79.88 ... 19.75 19.84 19.94
#   * xu_ocean  (xu_ocean) float64 -270.0 -269.9 -269.8 ... -180.3 -180.2 -180.1
#   * year      (year) int64 1993 1994 1995 1996 1997 ... 2013 2014 2015 2016 2017
# <xarray.DataArray 'tx_trans_int_z' (year: 25, yt_ocean: 1422, xu_ocean: 900)>
# array([[[0.000000e+00, 0.000000e+00, ..., 0.000000e+00, 0.000000e+00],
#         [0.000000e+00, 0.000000e+00, ..., 0.000000e+00, 0.000000e+00],
#         ...,
#         [1.421704e+11, 1.422290e+11, ..., 1.277524e+11, 1.277061e+11],
#         [1.422325e+11, 1.422684e+11, ..., 1.273677e+11, 1.273032e+11]],
#
#        [[0.000000e+00, 0.000000e+00, ..., 0.000000e+00, 0.000000e+00],
#         [0.000000e+00, 0.000000e+00, ..., 0.000000e+00, 0.000000e+00],
#         ...,
#         [1.395737e+11, 1.396002e+11, ..., 1.280979e+11, 1.281228e+11],
#         [1.395765e+11, 1.395975e+11, ..., 1.281433e+11, 1.281782e+11]],
#
#        ...,
#
#        [[0.000000e+00, 0.000000e+00, ..., 0.000000e+00, 0.000000e+00],
#         [0.000000e+00, 0.000000e+00, ..., 0.000000e+00, 0.000000e+00],
#         ...,
#         [1.419974e+11, 1.420825e+11, ..., 1.294711e+11, 1.292848e+11],
#         [1.420722e+11, 1.421221e+11, ..., 1.296583e+11, 1.294492e+11]],
#
#        [[0.000000e+00, 0.000000e+00, ..., 0.000000e+00, 0.000000e+00],
#         [0.000000e+00, 0.000000e+00, ..., 0.000000e+00, 0.000000e+00],
#         ...,
#         [1.420932e+11, 1.420417e+11, ..., 1.263077e+11, 1.262480e+11],
#         [1.419138e+11, 1.418819e+11, ..., 1.263921e+11, 1.263205e+11]]],
#       dtype=float32)
# Coordinates:
#   * yt_ocean  (yt_ocean) float64 -79.97 -79.93 -79.88 ... 19.75 19.84 19.94
#   * xu_ocean  (xu_ocean) float64 -270.0 -269.9 -269.8 ... -180.3 -180.2 -180.1
#   * year      (year) int64 1993 1994 1995 1996 1997 ... 2013 2014 2015 2016 2017
# <xarray.DataArray 'tx_trans_int_z' (year: 25, yt_ocean: 1422, xu_ocean: 900)>
# array([[[  0.      ,   0.      , ...,   0.      ,   0.      ],
#         [  0.      ,   0.      , ...,   0.      ,   0.      ],
#         ...,
#         [137.2301  , 137.28667 , ..., 123.31313 , 123.26846 ],
#         [137.29007 , 137.32468 , ..., 122.94177 , 122.87953 ]],
#
#        [[  0.      ,   0.      , ...,   0.      ,   0.      ],
#         [  0.      ,   0.      , ...,   0.      ,   0.      ],
#         ...,
#         [134.72362 , 134.74924 , ..., 123.64661 , 123.670654],
#         [134.72633 , 134.74663 , ..., 123.69046 , 123.72414 ]],
#
#        ...,
#
#        [[  0.      ,   0.      , ...,   0.      ,   0.      ],
#         [  0.      ,   0.      , ...,   0.      ,   0.      ],
#         ...,
#         [137.06311 , 137.14525 , ..., 124.97212 , 124.79229 ],
#         [137.13533 , 137.18347 , ..., 125.152794, 124.95094 ]],
#
#        [[  0.      ,   0.      , ...,   0.      ,   0.      ],
#         [  0.      ,   0.      , ...,   0.      ,   0.      ],
#         ...,
#         [137.15558 , 137.10593 , ..., 121.918594, 121.86102 ],
#         [136.98242 , 136.9516  , ..., 122.00008 , 121.931015]]], dtype=float32)
# Coordinates:
#   * yt_ocean  (yt_ocean) float64 -79.97 -79.93 -79.88 ... 19.75 19.84 19.94
#   * xu_ocean  (xu_ocean) float64 -270.0 -269.9 -269.8 ... -180.3 -180.2 -180.1
#   * year      (year) int64 1993 1994 1995 1996 1997 ... 2013 2014 2015 2016 2017
# Using database sqlite:////g/data3/hh5/tmp/cosima/cosima-cookbook/cosima-cookbook.db
# <xarray.DataArray 'tx_trans_int_z' (yt_ocean: 1422)>
# array([0.000000e+00, 0.000000e+00, 0.000000e+00, ..., 1.420114e+11,
#        1.420114e+11, 1.420114e+11], dtype=float32)
# Coordinates:
#   * yt_ocean  (yt_ocean) float64 -79.97 -79.93 -79.88 ... 19.75 19.84 19.94
#     xu_ocean  float64 -4.843e-12
# <xarray.DataArray 'tx_trans_int_z' ()>
# array(137.076609)
# Coordinates:
#     yt_ocean  float64 19.94
#     xu_ocean  float64 -4.843e-12
# <xarray.DataArray 'tx_trans_int_z' (year: 25, yt_ocean: 1422, xu_ocean: 900)>
# array([[[          nan,           nan, ...,           nan,           nan],
#         [          nan,           nan, ...,           nan,           nan],
#         ...,
#         [-1.534931e-01, -2.100574e-01, ...,  1.376348e+01,  1.380815e+01],
#         [-2.134601e-01, -2.480670e-01, ...,  1.413484e+01,  1.419708e+01]],
#
#        [[          nan,           nan, ...,           nan,           nan],
#         [          nan,           nan, ...,           nan,           nan],
#         ...,
#         [ 2.352992e+00,  2.327372e+00, ...,  1.343000e+01,  1.340596e+01],
#         [ 2.350276e+00,  2.329982e+00, ...,  1.338615e+01,  1.335247e+01]],
#
#        ...,
#
#        [[          nan,           nan, ...,           nan,           nan],
#         [          nan,           nan, ...,           nan,           nan],
#         ...,
#         [ 1.349913e-02, -6.863893e-02, ...,  1.210449e+01,  1.228432e+01],
#         [-5.872072e-02, -1.068622e-01, ...,  1.192382e+01,  1.212567e+01]],
#
#        [[          nan,           nan, ...,           nan,           nan],
#         [          nan,           nan, ...,           nan,           nan],
#         ...,
#         [-7.896913e-02, -2.931703e-02, ...,  1.515802e+01,  1.521559e+01],
#         [ 9.418761e-02,  1.250104e-01, ...,  1.507653e+01,  1.514559e+01]]])
# Coordinates:
#   * yt_ocean  (yt_ocean) float64 -79.97 -79.93 -79.88 ... 19.75 19.84 19.94
#   * xu_ocean  (xu_ocean) float64 -270.0 -269.9 -269.8 ... -180.3 -180.2 -180.1
#   * year      (year) int64 1993 1994 1995 1996 1997 ... 2013 2014 2015 2016 2017
# CPU times: user 1min 12s, sys: 42.5 s, total: 1min 55s
# Wall time: 2min 19s

# %%
# %%time
output_path_list = sorted(gb(output_path+'*'))
eta_t = xr.open_mfdataset(output_path_list, concat_dim='year').eta_t
eta_t = eta_t.assign_coords(year=years)
eta_t.load()
print(eta_t)
# Out:
# <xarray.DataArray 'eta_t' (year: 25, yt_ocean: 1186, xt_ocean: 900)>
# array([[[      nan,       nan, ..., -1.553424, -1.553023],
#         [      nan,       nan, ..., -1.554771, -1.5544  ],
#         ...,
#         [ 0.436164,  0.436063, ...,  0.623157,  0.622838],
#         [ 0.438985,  0.438865, ...,  0.624114,  0.623857]],
#
#        [[      nan,       nan, ..., -1.538167, -1.537931],
#         [      nan,       nan, ..., -1.539503, -1.539326],
#         ...,
#         [ 0.397539,  0.398372, ...,  0.62935 ,  0.628091],
#         [ 0.404109,  0.404905, ...,  0.626661,  0.625244]],
#
#        ...,
#
#        [[      nan,       nan, ..., -1.573167, -1.572852],
#         [      nan,       nan, ..., -1.574003, -1.573632],
#         ...,
#         [ 0.512353,  0.512327, ...,  0.621191,  0.621616],
#         [ 0.513968,  0.514305, ...,  0.61878 ,  0.618931]],
#
#        [[      nan,       nan, ..., -1.59154 , -1.591264],
#         [      nan,       nan, ..., -1.593481, -1.593206],
#         ...,
#         [ 0.46673 ,  0.467606, ...,  0.691458,  0.69038 ],
#         [ 0.470006,  0.471097, ...,  0.688921,  0.687901]]], dtype=float32)
# Coordinates:
#   * yt_ocean  (yt_ocean) float64 -70.0 -69.96 -69.92 ... 19.75 19.84 19.94
#   * xt_ocean  (xt_ocean) float64 -269.9 -269.8 -269.7 ... -180.2 -180.1 -180.0
#   * year      (year) int64 1993 1994 1995 1996 1997 ... 2013 2014 2015 2016 2017
# CPU times: user 798 ms, sys: 283 ms, total: 1.08 s
# Wall time: 2.61 s

# %%
# %%time
latS = -70
latN = 20
lonW = 90-360
lonE = 180-360
ekey='01deg'
expt = exptdata.exptdict[ekey]['expt']
time_units = exptdata.exptdict[ekey]['time_units']
n_files = exptdata.exptdict[ekey]['n_files']
offset = exptdata.exptdict[ekey]['offset']
print(expt)
print(time_units)
print(n_files)
print(offset)
mld_01_month = cc.get_nc_variable(expt,'ocean_month.nc','mld',
                                              time_units=time_units,n=n_files,offset=offset).\
                            sel(time=slice(exptdata.clim_tstart,exptdata.clim_tend)).\
                            sel(yt_ocean=slice(latS,latN)).\
                            sel(xt_ocean=slice(lonW,lonE))

mld_01_month.load()
print(mld_01_month)
# Out:
# 01deg_jra55v13_iaf
# days since 0001-01-01
# None
# None
# Using database sqlite:////g/data3/hh5/tmp/cosima/cosima-cookbook/cosima-cookbook.db
# <xarray.DataArray 'mld' (time: 300, yt_ocean: 1186, xt_ocean: 900)>
# array([[[       nan,        nan, ...,  16.403822,  16.320055],
#         [       nan,        nan, ...,  16.462784,  16.492558],
#         ...,
#         [ 10.464656,   9.010514, ..., 106.89153 , 107.41149 ],
#         [  9.286617,   8.731842, ..., 108.44562 , 110.54151 ]],
#
#        [[       nan,        nan, ...,  29.401455,  28.464378],
#         [       nan,        nan, ...,  29.27034 ,  28.892942],
#         ...,
#         [  8.95786 ,   8.029479, ...,  58.49945 ,  55.43883 ],
#         [  8.799442,   8.463483, ...,  58.282867,  53.85008 ]],
#
#        ...,
#
#        [[       nan,        nan, ..., 115.88109 , 116.774414],
#         [       nan,        nan, ..., 112.58973 , 113.47757 ],
#         ...,
#         [ 20.84877 ,  20.648075, ...,  52.272945,  50.952976],
#         [ 20.696047,  20.470877, ...,  53.274918,  51.459564]],
#
#        [[       nan,        nan, ...,  26.780828,  27.01832 ],
#         [       nan,        nan, ...,  26.97912 ,  27.018658],
#         ...,
#         [ 18.205881,  17.846607, ...,  92.12464 ,  90.167046],
#         [ 18.913395,  18.448687, ...,  91.379585,  88.91814 ]]], dtype=float32)
# Coordinates:
#   * yt_ocean  (yt_ocean) float64 -70.0 -69.96 -69.92 ... 19.75 19.84 19.94
#   * xt_ocean  (xt_ocean) float64 -269.9 -269.8 -269.7 ... -180.2 -180.1 -180.0
#   * time      (time) datetime64[ns] 1993-01-14T12:00:00 ... 2017-12-14T12:00:00
# Attributes:
#     long_name:      mixed layer depth determined by density criteria
#     units:          m
#     valid_range:    [      0. 1000000.]
#     cell_methods:   time: mean
#     time_avg_info:  average_T1,average_T2,average_DT
#     coordinates:    geolon_t geolat_t
#     standard_name:  ocean_mixed_layer_thickness_defined_by_sigma_t
# CPU times: user 37.6 s, sys: 18.4 s, total: 56 s
# Wall time: 1min 11s

# %%
# %%time

latS = -70
latN = 20
lonW = 90-360
lonE = 180-360

var = 't_10'

all_files = sorted(gb('/g/data/e14/erd561/JRA55-do/v1-3/' + var + '.*.*.nc'))

t_10_all = xr.open_mfdataset(all_files).tas_10m  

t_10_all.load()
print(t_10_all)
# Out:
# <xarray.DataArray 'tas_10m' (time: 25, latitude: 161, longitude: 161)>
# array([[[257.59256, 257.59256, ..., 261.04608, 261.0913 ],
#         [258.21426, 258.21426, ..., 261.91476, 261.95865],
#         ...,
#         [300.1658 , 300.0461 , ..., 298.61917, 298.60165],
#         [300.0957 , 299.94522, ..., 298.50906, 298.4882 ]],
#
#        [[257.59256, 257.59256, ..., 260.8303 , 260.9211 ],
#         [258.21426, 258.21426, ..., 261.6275 , 261.7099 ],
#         ...,
#         [300.1004 , 299.9799 , ..., 298.9499 , 298.93292],
#         [300.02817, 299.87994, ..., 298.78818, 298.7662 ]],
#
#        ...,
#
#        [[257.59256, 257.59256, ..., 261.55838, 261.60956],
#         [258.21426, 258.21426, ..., 262.459  , 262.50974],
#         ...,
#         [300.8656 , 300.7565 , ..., 299.3125 , 299.2859 ],
#         [300.7536 , 300.61136, ..., 299.20712, 299.17462]],
#
#        [[257.59256, 257.59274, ..., 261.58215, 261.62183],
#         [258.21426, 258.21426, ..., 262.3877 , 262.42746],
#         ...,
#         [300.7819 , 300.69586, ..., 299.80405, 299.76782],
#         [300.68692, 300.5882 , ..., 299.672  , 299.638  ]]], dtype=float32)
# Coordinates:
#   * latitude   (latitude) float64 -69.92 -69.36 -68.8 ... 18.81 19.38 19.94
#   * longitude  (longitude) float64 90.0 90.56 91.12 91.69 ... 178.9 179.4 180.0
#   * time       (time) datetime64[ns] 1993-07-02T10:30:00 ... 2017-07-02T10:30:00
# Attributes:
#     units:          K
#     long_name:      Near-Surface Air Temperature at the 10 meter height
#     standard_name:  air_temperature
# CPU times: user 570 ms, sys: 97 ms, total: 667 ms
# Wall time: 1.17 s

# %%
# %%time

latS = -70
latN = 20
lonW = 90-360
lonE = 180-360

var = 'u_10'

all_files = sorted(gb('/g/data/e14/erd561/JRA55-do/v1-3/' + var + '.*.*.nc'))

u_10_all = xr.open_mfdataset(all_files).uas_10m   

u_10_all.load()
print(u_10_all)
# Out:
# <xarray.DataArray 'uas_10m' (time: 25, latitude: 161, longitude: 161)>
# array([[[-8.959103e+00, -9.185435e+00, ...,  3.678540e-01,  4.142455e-01],
#         [-9.538368e+00, -9.677067e+00, ...,  4.786964e-01,  5.926184e-01],
#         ...,
#         [ 1.544562e+00,  1.404381e+00, ..., -6.589673e+00, -6.613897e+00],
#         [ 1.447655e+00,  1.335200e+00, ..., -6.337334e+00, -6.354620e+00]],
#
#        [[-9.071602e+00, -9.295076e+00, ...,  8.775599e-03,  7.148299e-02],
#         [-9.747133e+00, -9.883302e+00, ...,  4.506692e-02,  1.761953e-01],
#         ...,
#         [ 1.602340e+00,  1.513393e+00, ..., -5.539237e+00, -5.557720e+00],
#         [ 1.451117e+00,  1.400476e+00, ..., -5.394783e+00, -5.400683e+00]],
#
#        ...,
#
#        [[-9.606175e+00, -9.829502e+00, ..., -2.832742e-01, -2.066557e-01],
#         [-1.021535e+01, -1.036444e+01, ..., -1.285230e-01, -2.850509e-03],
#         ...,
#         [ 1.460648e+00,  1.336522e+00, ..., -6.674020e+00, -6.686288e+00],
#         [ 1.267538e+00,  1.188947e+00, ..., -6.444159e+00, -6.439908e+00]],
#
#        [[-9.508239e+00, -9.714146e+00, ...,  7.360081e-02,  1.436461e-01],
#         [-1.007446e+01, -1.020228e+01, ...,  2.490653e-01,  3.800198e-01],
#         ...,
#         [ 1.238661e+00,  1.096876e+00, ..., -5.875345e+00, -5.921516e+00],
#         [ 1.122548e+00,  1.032702e+00, ..., -5.616139e+00, -5.646033e+00]]],
#       dtype=float32)
# Coordinates:
#   * latitude   (latitude) float64 -69.92 -69.36 -68.8 ... 18.81 19.38 19.94
#   * longitude  (longitude) float64 90.0 90.56 91.12 91.69 ... 178.9 179.4 180.0
#   * time       (time) datetime64[ns] 1993-07-02T10:30:00 ... 2017-07-02T10:30:00
# Attributes:
#     units:          m/s
#     long_name:      Eastward Near-Surface Wind
#     standard_name:  eastward_wind
# CPU times: user 658 ms, sys: 103 ms, total: 761 ms
# Wall time: 1.36 s

# %%
# %%time

latS = -70
latN = 20
lonW = 90-360
lonE = 180-360

var = 'slp'

all_files = sorted(gb('/g/data/e14/erd561/JRA55-do/v1-3/' + var + '.*.*.nc'))

slp_all = xr.open_mfdataset(all_files).psl   

slp_all.load()
print(slp_all)
# Out:
# <xarray.DataArray 'psl' (time: 25, latitude: 161, longitude: 161)>
# array([[[100370.85 , 100418.88 , ...,  98174.53 ,  98160.84 ],
#         [ 99975.1  , 100025.98 , ...,  98155.1  ,  98143.68 ],
#         ...,
#         [100929.24 , 100936.516, ..., 101529.75 , 101530.77 ],
#         [100916.19 , 100928.375, ..., 101560.234, 101561.16 ]],
#
#        [[100794.22 , 100846.02 , ...,  98565.18 ,  98549.02 ],
#         [100395.57 , 100451.195, ...,  98538.62 ,  98525.49 ],
#         ...,
#         [100875.32 , 100881.625, ..., 101386.04 , 101388.02 ],
#         [100863.1  , 100874.42 , ..., 101413.34 , 101415.22 ]],
#
#        ...,
#
#        [[100576.68 , 100628.62 , ...,  98472.32 ,  98462.13 ],
#         [100171.3  , 100225.41 , ...,  98447.71 ,  98439.99 ],
#         ...,
#         [100865.99 , 100872.75 , ..., 101555.99 , 101557.305],
#         [100855.79 , 100867.16 , ..., 101589.05 , 101590.37 ]],
#
#        [[100696.5  , 100750.35 , ...,  98341.695,  98329.35 ],
#         [100295.79 , 100352.05 , ...,  98323.99 ,  98313.96 ],
#         ...,
#         [100864.22 , 100870.016, ..., 101475.13 , 101478.734],
#         [100855.22 , 100865.41 , ..., 101502.22 , 101505.76 ]]], dtype=float32)
# Coordinates:
#   * latitude   (latitude) float64 -69.92 -69.36 -68.8 ... 18.81 19.38 19.94
#   * longitude  (longitude) float64 90.0 90.56 91.12 91.69 ... 178.9 179.4 180.0
#   * time       (time) datetime64[ns] 1993-07-02T10:30:00 ... 2017-07-02T10:30:00
# Attributes:
#     units:          Pa
#     long_name:      Sea Level Pressure
#     standard_name:  air_pressure_at_sea_level
# CPU times: user 566 ms, sys: 106 ms, total: 672 ms
# Wall time: 1.39 s

# %%
# %%time

latS = -70
latN = 20
lonW = 90-360
lonE = 180-360

var = 'v_10'

all_files = sorted(gb('/g/data/e14/erd561/JRA55-do/v1-3/' + var + '.*.*.nc'))

v_10_all = xr.open_mfdataset(all_files).vas_10m

v_10_all.load()
print(v_10_all)
# Out:
# <xarray.DataArray 'vas_10m' (time: 25, latitude: 161, longitude: 161)>
# array([[[ 3.651821,  3.731537, ...,  2.870504,  2.662094],
#         [ 4.940031,  4.981736, ...,  2.286523,  2.109486],
#         ...,
#         [ 1.568398,  1.361881, ..., -1.972805, -2.036986],
#         [ 1.728541,  1.521613, ..., -1.89851 , -1.947677]],
#
#        [[ 3.773924,  3.868824, ...,  3.466481,  3.235808],
#         [ 5.172908,  5.231553, ...,  2.751938,  2.538381],
#         ...,
#         [ 1.203737,  0.97777 , ..., -1.60026 , -1.62277 ],
#         [ 1.358551,  1.114633, ..., -1.575462, -1.59291 ]],
#
#        ...,
#
#        [[ 3.872682,  3.990711, ...,  2.516684,  2.330794],
#         [ 5.171262,  5.256763, ...,  1.874432,  1.706751],
#         ...,
#         [ 1.491145,  1.366104, ..., -2.210477, -2.231614],
#         [ 1.557764,  1.433358, ..., -2.154506, -2.16432 ]],
#
#        [[ 3.246724,  3.365044, ...,  2.682318,  2.491387],
#         [ 4.464511,  4.554462, ...,  2.103313,  1.935813],
#         ...,
#         [ 1.250876,  1.145742, ..., -1.083849, -1.128436],
#         [ 1.334309,  1.219432, ..., -1.048612, -1.082105]]], dtype=float32)
# Coordinates:
#   * latitude   (latitude) float64 -69.92 -69.36 -68.8 ... 18.81 19.38 19.94
#   * longitude  (longitude) float64 90.0 90.56 91.12 91.69 ... 178.9 179.4 180.0
#   * time       (time) datetime64[ns] 1993-07-02T10:30:00 ... 2017-07-02T10:30:00
# Attributes:
#     units:          m/s
#     long_name:      Northward Near-Surface Wind
#     standard_name:  northward_wind
# CPU times: user 579 ms, sys: 103 ms, total: 682 ms
# Wall time: 1.02 s

# %%
temp = temp_01_month.groupby('time.year').mean('time', skipna=True)
print(temp)
temp_mean = temp.mean(dim='year')
print(temp_mean)
temp_anom = temp - temp_mean

net_sfc_heating = net_sfc_heating_01_month.groupby('time.year').mean('time', skipna=True)
print(net_sfc_heating)
net_sfc_heating_mean = net_sfc_heating.mean(dim='year')
print(net_sfc_heating_mean)
net_sfc_heating_anom = net_sfc_heating - net_sfc_heating_mean

gyre_psi_mean = gyre_psi.mean(dim='year')
print(gyre_psi_mean)
gyre_psi_anom = gyre_psi - gyre_psi_mean

eta_t_mean = eta_t.mean(dim='year')
print(eta_t_mean)
eta_t_anom = eta_t - eta_t_mean

mld = mld_01_month.groupby('time.year').mean('time', skipna=True)
print(mld)
mld_mean = mld.mean(dim='year')
print(mld_mean)
mld_anom = mld - mld_mean

t_10 = t_10_all.groupby('time.year').mean('time', skipna=True)
print(t_10)
t_10_mean = t_10.mean(dim='year')
print(t_10_mean)
t_10_anom = t_10 - t_10_mean

u_10 = u_10_all.groupby('time.year').mean('time', skipna=True)
print(u_10)
u_10_mean = u_10.mean(dim='year')
print(u_10_mean)
u_10_anom = u_10 - u_10_mean

v_10 = v_10_all.groupby('time.year').mean('time', skipna=True)
print(v_10)
v_10_mean = v_10.mean(dim='year')
print(v_10_mean)
v_10_anom = v_10 - v_10_mean

slp = slp_all.groupby('time.year').mean('time', skipna=True)
print(slp)
slp_mean = slp.mean(dim='year')
print(slp_mean)
slp_anom = slp - slp_mean
# Out:
# <xarray.DataArray 'temp' (year: 25, yt_ocean: 1186, xt_ocean: 900)>
# array([[[      nan,       nan, ..., 271.7264 , 271.72592],
#         [      nan,       nan, ..., 271.73196, 271.729  ],
#         ...,
#         [300.60236, 300.52548, ..., 298.90384, 298.90314],
#         [300.45926, 300.41058, ..., 298.88864, 298.88593]],
#
#        [[      nan,       nan, ..., 271.43204, 271.43036],
#         [      nan,       nan, ..., 271.4318 , 271.4304 ],
#         ...,
#         [300.4228 , 300.37872, ..., 299.55075, 299.54694],
#         [300.26535, 300.2357 , ..., 299.51984, 299.51306]],
#
#        ...,
#
#        [[      nan,       nan, ..., 271.5356 , 271.53067],
#         [      nan,       nan, ..., 271.53622, 271.5279 ],
#         ...,
#         [301.27817, 301.25903, ..., 299.60626, 299.61057],
#         [301.22958, 301.19168, ..., 299.58273, 299.58508]],
#
#        [[      nan,       nan, ..., 271.75876, 271.75757],
#         [      nan,       nan, ..., 271.75613, 271.75504],
#         ...,
#         [301.19467, 301.19592, ..., 300.1926 , 300.19357],
#         [301.18066, 301.1768 , ..., 300.1882 , 300.19052]]], dtype=float32)
# Coordinates:
#     st_ocean  float64 0.5413
#   * xt_ocean  (xt_ocean) float64 -269.9 -269.8 -269.7 ... -180.2 -180.1 -180.0
#   * yt_ocean  (yt_ocean) float64 -70.0 -69.96 -69.92 ... 19.75 19.84 19.94
#   * year      (year) int64 1993 1994 1995 1996 1997 ... 2013 2014 2015 2016 2017
# <xarray.DataArray 'temp' (yt_ocean: 1186, xt_ocean: 900)>
# array([[      nan,       nan,       nan, ..., 271.70212, 271.69974, 271.69757],
#        [      nan,       nan,       nan, ..., 271.70096, 271.6984 , 271.69574],
#        [      nan,       nan,       nan, ..., 271.69974, 271.6973 , 271.69473],
#        ...,
#        [300.77835, 300.75525, 300.72784, ..., 299.65915, 299.6533 , 299.64798],
#        [300.729  , 300.70157, 300.6761 , ..., 299.64407, 299.63885, 299.6336 ],
#        [300.6681 , 300.64743, 300.6297 , ..., 299.63086, 299.62537, 299.61905]],
#       dtype=float32)
# Coordinates:
#     st_ocean  float64 0.5413
#   * xt_ocean  (xt_ocean) float64 -269.9 -269.8 -269.7 ... -180.2 -180.1 -180.0
#   * yt_ocean  (yt_ocean) float64 -70.0 -69.96 -69.92 ... 19.75 19.84 19.94
# <xarray.DataArray 'net_sfc_heating' (year: 25, yt_ocean: 1186, xt_ocean: 900)>
# array([[[          nan,           nan, ..., -4.108405e+01, -4.135307e+01],
#         [          nan,           nan, ..., -4.037080e+01, -4.031923e+01],
#         ...,
#         [ 7.890045e+00,  1.038843e+01, ...,  4.012794e-01, -2.993838e-02],
#         [ 1.464849e+01,  1.586624e+01, ...,  1.065904e+00,  7.570254e-01]],
#
#        [[          nan,           nan, ..., -3.366484e+01, -3.380465e+01],
#         [          nan,           nan, ..., -3.309704e+01, -3.321457e+01],
#         ...,
#         [ 4.857133e+00,  6.004656e+00, ..., -3.240154e+00, -3.385993e+00],
#         [ 1.208308e+01,  1.247882e+01, ..., -2.425825e+00, -2.346217e+00]],
#
#        ...,
#
#        [[          nan,           nan, ..., -3.570658e+01, -3.579343e+01],
#         [          nan,           nan, ..., -3.562432e+01, -3.530675e+01],
#         ...,
#         [ 5.570114e+00,  6.080779e+00, ..., -9.975204e+00, -1.049582e+01],
#         [ 7.779984e+00,  9.118495e+00, ..., -9.086867e+00, -9.503722e+00]],
#
#        [[          nan,           nan, ..., -5.324289e+01, -5.294132e+01],
#         [          nan,           nan, ..., -5.280382e+01, -5.260341e+01],
#         ...,
#         [-2.930022e+00, -3.302589e+00, ..., -7.338402e+00, -7.779451e+00],
#         [-2.504123e+00, -2.658799e+00, ..., -7.718436e+00, -8.192510e+00]]],
#       dtype=float32)
# Coordinates:
#   * yt_ocean  (yt_ocean) float64 -70.0 -69.96 -69.92 ... 19.75 19.84 19.94
#   * xt_ocean  (xt_ocean) float64 -269.9 -269.8 -269.7 ... -180.2 -180.1 -180.0
#   * year      (year) int64 1993 1994 1995 1996 1997 ... 2013 2014 2015 2016 2017
# <xarray.DataArray 'net_sfc_heating' (yt_ocean: 1186, xt_ocean: 900)>
# array([[       nan,        nan,        nan, ..., -41.81436 , -41.75675 ,
#         -41.725567],
#        [       nan,        nan,        nan, ..., -41.154476, -41.079395,
#         -40.989296],
#        [       nan,        nan,        nan, ..., -40.44994 , -40.41743 ,
#         -40.30648 ],
#        ...,
#        [  2.847922,   3.462268,   3.953333, ...,  -5.083281,  -5.09287 ,
#          -5.024929],
#        [  5.035571,   5.843262,   6.191635, ...,  -4.831002,  -4.863539,
#          -4.79584 ],
#        [  7.808186,   8.288026,   8.305303, ...,  -4.730993,  -4.728376,
#          -4.581717]], dtype=float32)
# Coordinates:
#   * yt_ocean  (yt_ocean) float64 -70.0 -69.96 -69.92 ... 19.75 19.84 19.94
#   * xt_ocean  (xt_ocean) float64 -269.9 -269.8 -269.7 ... -180.2 -180.1 -180.0
# <xarray.DataArray 'tx_trans_int_z' (yt_ocean: 1422, xu_ocean: 900)>
# array([[      nan,       nan,       nan, ...,       nan,       nan,       nan],
#        [      nan,       nan,       nan, ...,       nan,       nan,       nan],
#        [      nan,       nan,       nan, ...,       nan,       nan,       nan],
#        ...,
#        [ 0.076519,  0.068872,  0.054922, ..., 14.725193, 14.716908, 14.724728],
#        [ 0.131667,  0.115432,  0.100643, ..., 14.807498, 14.81882 , 14.83269 ],
#        [ 0.196559,  0.185212,  0.1718  , ..., 14.910907, 14.931699, 14.946366]])
# Coordinates:
#   * yt_ocean  (yt_ocean) float64 -79.97 -79.93 -79.88 ... 19.75 19.84 19.94
#   * xu_ocean  (xu_ocean) float64 -270.0 -269.9 -269.8 ... -180.3 -180.2 -180.1
# <xarray.DataArray 'eta_t' (yt_ocean: 1186, xt_ocean: 900)>
# array([[      nan,       nan,       nan, ..., -1.565358, -1.565173, -1.564955],
#        [      nan,       nan,       nan, ..., -1.566537, -1.566422, -1.566225],
#        [      nan,       nan,       nan, ..., -1.567728, -1.567628, -1.567506],
#        ...,
#        [ 0.44571 ,  0.446493,  0.447229, ...,  0.656467,  0.655802,  0.655081],
#        [ 0.44895 ,  0.449695,  0.450425, ...,  0.65608 ,  0.655418,  0.654638],
#        [ 0.452808,  0.453604,  0.454285, ...,  0.655745,  0.65504 ,  0.65426 ]],
#       dtype=float32)
# Coordinates:
#   * yt_ocean  (yt_ocean) float64 -70.0 -69.96 -69.92 ... 19.75 19.84 19.94
#   * xt_ocean  (xt_ocean) float64 -269.9 -269.8 -269.7 ... -180.2 -180.1 -180.0
# <xarray.DataArray 'mld' (year: 25, yt_ocean: 1186, xt_ocean: 900)>
# array([[[      nan,       nan, ..., 65.98458 , 65.69503 ],
#         [      nan,       nan, ..., 66.77601 , 66.73548 ],
#         ...,
#         [12.505219, 10.508088, ..., 41.72129 , 41.448452],
#         [ 9.162   ,  9.010607, ..., 41.656876, 41.509068]],
#
#        [[      nan,       nan, ..., 63.5771  , 62.76357 ],
#         [      nan,       nan, ..., 64.30191 , 63.685734],
#         ...,
#         [ 9.810997,  9.401921, ..., 34.14394 , 34.23443 ],
#         [ 8.411724,  8.264621, ..., 34.321346, 34.062176]],
#
#        ...,
#
#        [[      nan,       nan, ..., 56.322357, 56.314896],
#         [      nan,       nan, ..., 57.56542 , 57.162216],
#         ...,
#         [14.01933 , 14.116376, ..., 37.85215 , 36.89277 ],
#         [12.983662, 11.860116, ..., 40.18825 , 38.547356]],
#
#        [[      nan,       nan, ..., 77.2051  , 76.80008 ],
#         [      nan,       nan, ..., 77.23325 , 76.80295 ],
#         ...,
#         [11.499719, 11.874261, ..., 41.46653 , 40.552807],
#         [11.365354, 11.525716, ..., 41.743023, 41.295013]]], dtype=float32)
# Coordinates:
#   * yt_ocean  (yt_ocean) float64 -70.0 -69.96 -69.92 ... 19.75 19.84 19.94
#   * xt_ocean  (xt_ocean) float64 -269.9 -269.8 -269.7 ... -180.2 -180.1 -180.0
#   * year      (year) int64 1993 1994 1995 1996 1997 ... 2013 2014 2015 2016 2017
# <xarray.DataArray 'mld' (yt_ocean: 1186, xt_ocean: 900)>
# array([[      nan,       nan,       nan, ..., 61.381702, 60.882763, 60.628902],
#        [      nan,       nan,       nan, ..., 63.62532 , 62.76394 , 61.89202 ],
#        [      nan,       nan,       nan, ..., 63.09296 , 63.436214, 63.42013 ],
#        ...,
#        [12.414756, 12.202954, 11.803449, ..., 41.150494, 41.31105 , 41.3405  ],
#        [11.560897, 11.216669, 11.012874, ..., 41.271996, 41.36892 , 41.30643 ],
#        [10.544531, 10.414433, 10.328472, ..., 41.401592, 41.479366, 41.22234 ]],
#       dtype=float32)
# Coordinates:
#   * yt_ocean  (yt_ocean) float64 -70.0 -69.96 -69.92 ... 19.75 19.84 19.94
#   * xt_ocean  (xt_ocean) float64 -269.9 -269.8 -269.7 ... -180.2 -180.1 -180.0
# <xarray.DataArray 'tas_10m' (year: 25, latitude: 161, longitude: 161)>
# array([[[257.59256, 257.59256, ..., 261.04608, 261.0913 ],
#         [258.21426, 258.21426, ..., 261.91476, 261.95865],
#         ...,
#         [300.1658 , 300.0461 , ..., 298.61917, 298.60165],
#         [300.0957 , 299.94522, ..., 298.50906, 298.4882 ]],
#
#        [[257.59256, 257.59256, ..., 260.8303 , 260.9211 ],
#         [258.21426, 258.21426, ..., 261.6275 , 261.7099 ],
#         ...,
#         [300.1004 , 299.9799 , ..., 298.9499 , 298.93292],
#         [300.02817, 299.87994, ..., 298.78818, 298.7662 ]],
#
#        ...,
#
#        [[257.59256, 257.59256, ..., 261.55838, 261.60956],
#         [258.21426, 258.21426, ..., 262.459  , 262.50974],
#         ...,
#         [300.8656 , 300.7565 , ..., 299.3125 , 299.2859 ],
#         [300.7536 , 300.61136, ..., 299.20712, 299.17462]],
#
#        [[257.59256, 257.59274, ..., 261.58215, 261.62183],
#         [258.21426, 258.21426, ..., 262.3877 , 262.42746],
#         ...,
#         [300.7819 , 300.69586, ..., 299.80405, 299.76782],
#         [300.68692, 300.5882 , ..., 299.672  , 299.638  ]]], dtype=float32)
# Coordinates:
#   * latitude   (latitude) float64 -69.92 -69.36 -68.8 ... 18.81 19.38 19.94
#   * longitude  (longitude) float64 90.0 90.56 91.12 91.69 ... 178.9 179.4 180.0
#   * year       (year) int64 1993 1994 1995 1996 1997 ... 2014 2015 2016 2017
# <xarray.DataArray 'tas_10m' (latitude: 161, longitude: 161)>
# array([[257.5935 , 257.59338, 257.59335, ..., 260.90454, 260.95184, 260.99738],
#        [258.2162 , 258.216  , 258.2159 , ..., 261.6693 , 261.7153 , 261.76   ],
#        [258.84113, 258.8402 , 258.83975, ..., 262.48434, 262.53546, 262.58435],
#        ...,
#        [300.436  , 300.35553, 300.3066 , ..., 299.34424, 299.3153 , 299.28534],
#        [300.3634 , 300.26022, 300.18112, ..., 299.22128, 299.19504, 299.16708],
#        [300.2843 , 300.15604, 300.02722, ..., 299.09235, 299.06653, 299.03802]],
#       dtype=float32)
# Coordinates:
#   * latitude   (latitude) float64 -69.92 -69.36 -68.8 ... 18.81 19.38 19.94
#   * longitude  (longitude) float64 90.0 90.56 91.12 91.69 ... 178.9 179.4 180.0
# <xarray.DataArray 'uas_10m' (year: 25, latitude: 161, longitude: 161)>
# array([[[-8.959103e+00, -9.185435e+00, ...,  3.678540e-01,  4.142455e-01],
#         [-9.538368e+00, -9.677067e+00, ...,  4.786964e-01,  5.926184e-01],
#         ...,
#         [ 1.544562e+00,  1.404381e+00, ..., -6.589673e+00, -6.613897e+00],
#         [ 1.447655e+00,  1.335200e+00, ..., -6.337334e+00, -6.354620e+00]],
#
#        [[-9.071602e+00, -9.295076e+00, ...,  8.775599e-03,  7.148299e-02],
#         [-9.747133e+00, -9.883302e+00, ...,  4.506692e-02,  1.761953e-01],
#         ...,
#         [ 1.602340e+00,  1.513393e+00, ..., -5.539237e+00, -5.557720e+00],
#         [ 1.451117e+00,  1.400476e+00, ..., -5.394783e+00, -5.400683e+00]],
#
#        ...,
#
#        [[-9.606175e+00, -9.829502e+00, ..., -2.832742e-01, -2.066557e-01],
#         [-1.021535e+01, -1.036444e+01, ..., -1.285230e-01, -2.850509e-03],
#         ...,
#         [ 1.460648e+00,  1.336522e+00, ..., -6.674020e+00, -6.686288e+00],
#         [ 1.267538e+00,  1.188947e+00, ..., -6.444159e+00, -6.439908e+00]],
#
#        [[-9.508239e+00, -9.714146e+00, ...,  7.360081e-02,  1.436461e-01],
#         [-1.007446e+01, -1.020228e+01, ...,  2.490653e-01,  3.800198e-01],
#         ...,
#         [ 1.238661e+00,  1.096876e+00, ..., -5.875345e+00, -5.921516e+00],
#         [ 1.122548e+00,  1.032702e+00, ..., -5.616139e+00, -5.646033e+00]]],
#       dtype=float32)
# Coordinates:
#   * latitude   (latitude) float64 -69.92 -69.36 -68.8 ... 18.81 19.38 19.94
#   * longitude  (longitude) float64 90.0 90.56 91.12 91.69 ... 178.9 179.4 180.0
#   * year       (year) int64 1993 1994 1995 1996 1997 ... 2014 2015 2016 2017
# <xarray.DataArray 'uas_10m' (latitude: 161, longitude: 161)>
# array([[ -9.595106,  -9.812053, -10.015181, ...,   0.391528,   0.449812,
#           0.50394 ],
#        [-10.210065, -10.346982, -10.479646, ...,   0.365705,   0.47838 ,
#           0.594569],
#        [-10.857368, -10.886484, -10.901853, ...,   0.483823,   0.6048  ,
#           0.723923],
#        ...,
#        [  1.365953,   1.370634,   1.387516, ...,  -6.113024,  -6.108974,
#          -6.118611],
#        [  1.470211,   1.385125,   1.293355, ...,  -5.915301,  -5.928113,
#          -5.949805],
#        [  1.321653,   1.277923,   1.211876, ...,  -5.694221,  -5.703646,
#          -5.711317]], dtype=float32)
# Coordinates:
#   * latitude   (latitude) float64 -69.92 -69.36 -68.8 ... 18.81 19.38 19.94
#   * longitude  (longitude) float64 90.0 90.56 91.12 91.69 ... 178.9 179.4 180.0
# <xarray.DataArray 'vas_10m' (year: 25, latitude: 161, longitude: 161)>
# array([[[ 3.651821,  3.731537, ...,  2.870504,  2.662094],
#         [ 4.940031,  4.981736, ...,  2.286523,  2.109486],
#         ...,
#         [ 1.568398,  1.361881, ..., -1.972805, -2.036986],
#         [ 1.728541,  1.521613, ..., -1.89851 , -1.947677]],
#
#        [[ 3.773924,  3.868824, ...,  3.466481,  3.235808],
#         [ 5.172908,  5.231553, ...,  2.751938,  2.538381],
#         ...,
#         [ 1.203737,  0.97777 , ..., -1.60026 , -1.62277 ],
#         [ 1.358551,  1.114633, ..., -1.575462, -1.59291 ]],
#
#        ...,
#
#        [[ 3.872682,  3.990711, ...,  2.516684,  2.330794],
#         [ 5.171262,  5.256763, ...,  1.874432,  1.706751],
#         ...,
#         [ 1.491145,  1.366104, ..., -2.210477, -2.231614],
#         [ 1.557764,  1.433358, ..., -2.154506, -2.16432 ]],
#
#        [[ 3.246724,  3.365044, ...,  2.682318,  2.491387],
#         [ 4.464511,  4.554462, ...,  2.103313,  1.935813],
#         ...,
#         [ 1.250876,  1.145742, ..., -1.083849, -1.128436],
#         [ 1.334309,  1.219432, ..., -1.048612, -1.082105]]], dtype=float32)
# Coordinates:
#   * latitude   (latitude) float64 -69.92 -69.36 -68.8 ... 18.81 19.38 19.94
#   * longitude  (longitude) float64 90.0 90.56 91.12 91.69 ... 178.9 179.4 180.0
#   * year       (year) int64 1993 1994 1995 1996 1997 ... 2014 2015 2016 2017
# <xarray.DataArray 'vas_10m' (latitude: 161, longitude: 161)>
# array([[ 3.626147,  3.731094,  3.84675 , ...,  3.433474,  3.260698,  3.085181],
#        [ 4.897665,  4.968302,  5.053366, ...,  2.902724,  2.742711,  2.581965],
#        [ 5.50374 ,  5.461158,  5.477779, ...,  2.316845,  2.204853,  2.095188],
#        ...,
#        [ 1.052376,  0.895619,  0.760403, ..., -1.449297, -1.447248, -1.472401],
#        [ 1.175922,  1.015928,  0.863457, ..., -1.431265, -1.425798, -1.453919],
#        [ 1.273431,  1.099236,  0.942108, ..., -1.348032, -1.390736, -1.406166]],
#       dtype=float32)
# Coordinates:
#   * latitude   (latitude) float64 -69.92 -69.36 -68.8 ... 18.81 19.38 19.94
#   * longitude  (longitude) float64 90.0 90.56 91.12 91.69 ... 178.9 179.4 180.0
# <xarray.DataArray 'psl' (year: 25, latitude: 161, longitude: 161)>
# array([[[100370.85 , 100418.88 , ...,  98174.53 ,  98160.84 ],
#         [ 99975.1  , 100025.98 , ...,  98155.1  ,  98143.68 ],
#         ...,
#         [100929.24 , 100936.516, ..., 101529.75 , 101530.77 ],
#         [100916.19 , 100928.375, ..., 101560.234, 101561.16 ]],
#
#        [[100794.22 , 100846.02 , ...,  98565.18 ,  98549.02 ],
#         [100395.57 , 100451.195, ...,  98538.62 ,  98525.49 ],
#         ...,
#         [100875.32 , 100881.625, ..., 101386.04 , 101388.02 ],
#         [100863.1  , 100874.42 , ..., 101413.34 , 101415.22 ]],
#
#        ...,
#
#        [[100576.68 , 100628.62 , ...,  98472.32 ,  98462.13 ],
#         [100171.3  , 100225.41 , ...,  98447.71 ,  98439.99 ],
#         ...,
#         [100865.99 , 100872.75 , ..., 101555.99 , 101557.305],
#         [100855.79 , 100867.16 , ..., 101589.05 , 101590.37 ]],
#
#        [[100696.5  , 100750.35 , ...,  98341.695,  98329.35 ],
#         [100295.79 , 100352.05 , ...,  98323.99 ,  98313.96 ],
#         ...,
#         [100864.22 , 100870.016, ..., 101475.13 , 101478.734],
#         [100855.22 , 100865.41 , ..., 101502.22 , 101505.76 ]]], dtype=float32)
# Coordinates:
#   * latitude   (latitude) float64 -69.92 -69.36 -68.8 ... 18.81 19.38 19.94
#   * longitude  (longitude) float64 90.0 90.56 91.12 91.69 ... 178.9 179.4 180.0
#   * year       (year) int64 1993 1994 1995 1996 1997 ... 2014 2015 2016 2017
# <xarray.DataArray 'psl' (latitude: 161, longitude: 161)>
# array([[100690.83, 100742.92, 100796.65, ...,  98469.28,  98452.99,  98436.78],
#        [100284.54, 100339.12, 100394.56, ...,  98448.71,  98434.37,  98420.08],
#        [ 99859.99,  99919.18,  99976.56, ...,  98430.66,  98419.28,  98408.22],
#        ...,
#        [100864.49, 100870.35, 100878.96, ..., 101433.03, 101436.12, 101438.15],
#        [100857.06, 100862.91, 100871.04, ..., 101460.78, 101463.92, 101466.73],
#        [100846.26, 100856.63, 100865.46, ..., 101488.73, 101492.02, 101494.75]],
#       dtype=float32)
# Coordinates:
#   * latitude   (latitude) float64 -69.92 -69.36 -68.8 ... 18.81 19.38 19.94
#   * longitude  (longitude) float64 90.0 90.56 91.12 91.69 ... 178.9 179.4 180.0

# %%
speed_anom = (u_10_anom**2 + v_10_anom**2)**(1/2)
print(speed_anom)

u_10_anom_norm = u_10_anom / (u_10_anom**2 + v_10_anom**2)**(1/4)
v_10_anom_norm = v_10_anom / (u_10_anom**2 + v_10_anom**2)**(1/4)

print(u_10_anom_norm)
# Out:
# <xarray.DataArray (year: 25, latitude: 161, longitude: 161)>
# array([[[0.636522, 0.626618, ..., 0.398709, 0.432491],
#         [0.673031, 0.67005 , ..., 0.456188, 0.472483],
#         ...,
#         [0.399457, 0.346488, ..., 0.858417, 0.883734],
#         [0.47223 , 0.426243, ..., 0.812032, 0.840876]],
#
#        [[0.543962, 0.535009, ..., 0.486682, 0.457939],
#         [0.538576, 0.533198, ..., 0.433411, 0.420638],
#         ...,
#         [0.135025, 0.133823, ..., 0.426217, 0.426898],
#         [0.15494 , 0.123516, ..., 0.359889, 0.362445]],
#
#        ...,
#
#        [[0.246783, 0.260203, ..., 1.044496, 1.036362],
#         [0.273649, 0.288989, ..., 1.059358, 1.059674],
#         ...,
#         [0.315368, 0.353533, ..., 1.082636, 1.071082],
#         [0.289436, 0.345766, ..., 1.063816, 1.051496]],
#
#        [[0.38924 , 0.378917, ..., 0.68997 , 0.694553],
#         [0.453884, 0.438407, ..., 0.679275, 0.68084 ],
#         ...,
#         [0.243379, 0.316132, ..., 0.345996, 0.32671 ],
#         [0.208204, 0.273094, ..., 0.353138, 0.330572]]], dtype=float32)
# Coordinates:
#   * latitude   (latitude) float64 -69.92 -69.36 -68.8 ... 18.81 19.38 19.94
#   * longitude  (longitude) float64 90.0 90.56 91.12 91.69 ... 178.9 179.4 180.0
#   * year       (year) int64 1993 1994 1995 1996 1997 ... 2014 2015 2016 2017
# <xarray.DataArray (year: 25, latitude: 161, longitude: 161)>
# array([[[ 7.971737e-01,  7.915916e-01, ..., -1.297962e-01, -1.363891e-01],
#         [ 8.187580e-01,  8.184012e-01, ...,  4.683358e-04, -2.837962e-03],
#         ...,
#         [ 1.176384e-01,  3.271250e-02, ..., -7.140362e-01, -7.064275e-01],
#         [ 1.833584e-01,  8.773014e-02, ..., -7.032163e-01, -7.015352e-01]],
#
#        [[ 7.097998e-01,  7.067899e-01, ..., -6.321958e-01, -6.390572e-01],
#         [ 6.308022e-01,  6.350006e-01, ..., -6.581907e-01, -6.450753e-01],
#         ...,
#         [ 3.595765e-01,  3.506326e-01, ...,  5.956552e-01,  6.000929e-01],
#         [ 3.289029e-01,  3.487070e-01, ...,  5.148506e-01,  5.159733e-01]],
#
#        ...,
#
#        [[-2.228240e-02, -3.420769e-02, ..., -7.173011e-01, -6.980187e-01],
#         [-1.011257e-02, -3.248413e-02, ..., -5.896551e-01, -5.803546e-01],
#         ...,
#         [-1.702964e-02, -8.174347e-02, ..., -7.168756e-01, -7.116258e-01],
#         [-1.005863e-01, -1.513150e-01, ..., -7.179582e-01, -7.105261e-01]],
#
#        [[ 1.392348e-01,  1.590530e-01, ..., -4.529146e-01, -4.323194e-01],
#         [ 2.012811e-01,  2.185352e-01, ..., -2.782333e-01, -2.600188e-01],
#         ...,
#         [-4.693567e-01, -5.126654e-01, ...,  8.970924e-02,  4.949106e-02],
#         [-4.363527e-01, -4.692471e-01, ...,  1.472549e-01,  1.135462e-01]]],
#       dtype=float32)
# Coordinates:
#   * latitude   (latitude) float64 -69.92 -69.36 -68.8 ... 18.81 19.38 19.94
#   * longitude  (longitude) float64 90.0 90.56 91.12 91.69 ... 178.9 179.4 180.0
#   * year       (year) int64 1993 1994 1995 1996 1997 ... 2014 2015 2016 2017

# %%
# %%time

lon_coarse = arange(lonW,lonE,0.25)
lat_coarse = arange(latS,latN,0.25)

lon_coarse_grid, lat_coarse_grid = np.meshgrid(lon_coarse,lat_coarse)

yt_ocean = temp.yt_ocean
xt_ocean = temp.xt_ocean

xt_ocean_grid, yt_ocean_grid = np.meshgrid(xt_ocean, yt_ocean)
xt_ocean_flat = np.transpose(xt_ocean_grid.flatten('F'))
yt_ocean_flat = yt_ocean_grid.flatten('F')
flat_list = [xt_ocean_flat, yt_ocean_flat]    
flat_list_points = np.transpose(flat_list)


for yi, y in enumerate(years):
    temp_flatten = temp.sel(year=y).stack(z=('xt_ocean', 'yt_ocean')).values
    
    if y == 1993:
        temp_coarse = scipy.interpolate.griddata(flat_list_points, temp_flatten, 
                                           (lon_coarse_grid, lat_coarse_grid), 
                                           method='nearest')
        
    else:
        temp_coarse = np.dstack((temp_coarse, 
                                    scipy.interpolate.griddata(flat_list_points, temp_flatten, 
                                           (lon_coarse_grid, lat_coarse_grid), 
                                           method='nearest')))
        
    print(str(temp_coarse.shape) + ' ' + str(y) + ' OK')
# Out:
# (361, 361) 1993 OK
# (361, 361, 2) 1994 OK
# (361, 361, 3) 1995 OK
# (361, 361, 4) 1996 OK
# (361, 361, 5) 1997 OK
# (361, 361, 6) 1998 OK
# distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 27% CPU time recently (threshold: 10%)
# (361, 361, 7) 1999 OK
# distributed.utils_perf - WARNING - full garbage collections took 24% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 24% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 24% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 24% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 27% CPU time recently (threshold: 10%)
# (361, 361, 8) 2000 OK
# distributed.utils_perf - WARNING - full garbage collections took 24% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 24% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 24% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 27% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 27% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 27% CPU time recently (threshold: 10%)
# (361, 361, 9) 2001 OK
# distributed.utils_perf - WARNING - full garbage collections took 24% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 24% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 27% CPU time recently (threshold: 10%)
# (361, 361, 10) 2002 OK
# distributed.utils_perf - WARNING - full garbage collections took 24% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 24% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 24% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 27% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 27% CPU time recently (threshold: 10%)
# (361, 361, 11) 2003 OK
# distributed.utils_perf - WARNING - full garbage collections took 25% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 25% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 25% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 29% CPU time recently (threshold: 10%)
# (361, 361, 12) 2004 OK
# distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 29% CPU time recently (threshold: 10%)
# (361, 361, 13) 2005 OK
# distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 29% CPU time recently (threshold: 10%)
# (361, 361, 14) 2006 OK
# distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 29% CPU time recently (threshold: 10%)
# (361, 361, 15) 2007 OK
# distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# (361, 361, 16) 2008 OK
# distributed.utils_perf - WARNING - full garbage collections took 27% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 27% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 30% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 30% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 30% CPU time recently (threshold: 10%)
# (361, 361, 17) 2009 OK
# distributed.utils_perf - WARNING - full garbage collections took 27% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 27% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 29% CPU time recently (threshold: 10%)
# (361, 361, 18) 2010 OK
# distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 29% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 30% CPU time recently (threshold: 10%)
# (361, 361, 19) 2011 OK
# distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 29% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 29% CPU time recently (threshold: 10%)
# (361, 361, 20) 2012 OK
# distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 30% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 30% CPU time recently (threshold: 10%)
# (361, 361, 21) 2013 OK
# distributed.utils_perf - WARNING - full garbage collections took 27% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 27% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 27% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 30% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 30% CPU time recently (threshold: 10%)
# (361, 361, 22) 2014 OK
# distributed.utils_perf - WARNING - full garbage collections took 27% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 27% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 27% CPU time recently (threshold: 10%)
# (361, 361, 23) 2015 OK
# distributed.utils_perf - WARNING - full garbage collections took 27% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# (361, 361, 24) 2016 OK
# distributed.utils_perf - WARNING - full garbage collections took 24% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 27% CPU time recently (threshold: 10%)
# (361, 361, 25) 2017 OK
# CPU times: user 2min 18s, sys: 5.24 s, total: 2min 23s
# Wall time: 2min 10s

# %%
# %%time

for yi, y in enumerate(years):
    net_sfc_heating_flatten = net_sfc_heating.sel(year=y).stack(z=('xt_ocean', 'yt_ocean')).values
    
    if y == 1993:
        net_sfc_heating_coarse = scipy.interpolate.griddata(flat_list_points, net_sfc_heating_flatten, 
                                           (lon_coarse_grid, lat_coarse_grid), 
                                           method='nearest')
        
    else:
        net_sfc_heating_coarse = np.dstack((net_sfc_heating_coarse, 
                                    scipy.interpolate.griddata(flat_list_points, net_sfc_heating_flatten, 
                                           (lon_coarse_grid, lat_coarse_grid), 
                                           method='nearest')))
        
    print(str(net_sfc_heating_coarse.shape) + ' ' + str(y) + ' OK')
# Out:
# distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# (361, 361) 1993 OK
# distributed.utils_perf - WARNING - full garbage collections took 23% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 29% CPU time recently (threshold: 10%)
# (361, 361, 2) 1994 OK
# distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 25% CPU time recently (threshold: 10%)
# (361, 361, 3) 1995 OK
# distributed.utils_perf - WARNING - full garbage collections took 25% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 25% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 25% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 25% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 25% CPU time recently (threshold: 10%)
# (361, 361, 4) 1996 OK
# distributed.utils_perf - WARNING - full garbage collections took 25% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 25% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 25% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 28% CPU time recently (threshold: 10%)
# (361, 361, 5) 1997 OK
# distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 29% CPU time recently (threshold: 10%)
# (361, 361, 6) 1998 OK
# distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 30% CPU time recently (threshold: 10%)
# (361, 361, 7) 1999 OK
# distributed.utils_perf - WARNING - full garbage collections took 27% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 27% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 30% CPU time recently (threshold: 10%)
# (361, 361, 8) 2000 OK
# distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 27% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 27% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 27% CPU time recently (threshold: 10%)
# (361, 361, 9) 2001 OK
# distributed.utils_perf - WARNING - full garbage collections took 24% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 29% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 29% CPU time recently (threshold: 10%)
# (361, 361, 10) 2002 OK
# distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 28% CPU time recently (threshold: 10%)
# (361, 361, 11) 2003 OK
# distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# (361, 361, 12) 2004 OK
# distributed.utils_perf - WARNING - full garbage collections took 25% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 25% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 25% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 25% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 24% CPU time recently (threshold: 10%)
# (361, 361, 13) 2005 OK
# distributed.utils_perf - WARNING - full garbage collections took 24% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 24% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 24% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 24% CPU time recently (threshold: 10%)
# (361, 361, 14) 2006 OK
# distributed.utils_perf - WARNING - full garbage collections took 24% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 24% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 24% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 24% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 27% CPU time recently (threshold: 10%)
# (361, 361, 15) 2007 OK
# distributed.utils_perf - WARNING - full garbage collections took 24% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 24% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 24% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 27% CPU time recently (threshold: 10%)
# (361, 361, 16) 2008 OK
# distributed.utils_perf - WARNING - full garbage collections took 24% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 24% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 25% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 25% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 25% CPU time recently (threshold: 10%)
# (361, 361, 17) 2009 OK
# distributed.utils_perf - WARNING - full garbage collections took 25% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 24% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 25% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 25% CPU time recently (threshold: 10%)
# (361, 361, 18) 2010 OK
# distributed.utils_perf - WARNING - full garbage collections took 25% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 25% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 25% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 28% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 28% CPU time recently (threshold: 10%)
# (361, 361, 19) 2011 OK
# distributed.utils_perf - WARNING - full garbage collections took 25% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 25% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 25% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 28% CPU time recently (threshold: 10%)
# (361, 361, 20) 2012 OK
# distributed.utils_perf - WARNING - full garbage collections took 25% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 25% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 25% CPU time recently (threshold: 10%)
# (361, 361, 21) 2013 OK
# distributed.utils_perf - WARNING - full garbage collections took 25% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 25% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 25% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 25% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# (361, 361, 22) 2014 OK
# distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# (361, 361, 23) 2015 OK
# distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# (361, 361, 24) 2016 OK
# distributed.utils_perf - WARNING - full garbage collections took 27% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 27% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 27% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 27% CPU time recently (threshold: 10%)
# (361, 361, 25) 2017 OK
# CPU times: user 2min 16s, sys: 4.11 s, total: 2min 20s
# Wall time: 2min 7s

# %%
# %%time

for yi, y in enumerate(years):
    mld_flatten = mld.sel(year=y).stack(z=('xt_ocean', 'yt_ocean')).values
    
    if y == 1993:
        mld_coarse = scipy.interpolate.griddata(flat_list_points, mld_flatten, 
                                           (lon_coarse_grid, lat_coarse_grid), 
                                           method='nearest')
        
    else:
        mld_coarse = np.dstack((mld_coarse, 
                                    scipy.interpolate.griddata(flat_list_points, mld_flatten, 
                                           (lon_coarse_grid, lat_coarse_grid), 
                                           method='nearest')))
        
    print(str(mld_coarse.shape) + ' ' + str(y) + ' OK')
# Out:
# distributed.utils_perf - WARNING - full garbage collections took 27% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 27% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 27% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 27% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# (361, 361) 1993 OK
# distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# (361, 361, 2) 1994 OK
# distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 29% CPU time recently (threshold: 10%)
# (361, 361, 3) 1995 OK
# distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 25% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 25% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 28% CPU time recently (threshold: 10%)
# (361, 361, 4) 1996 OK
# distributed.utils_perf - WARNING - full garbage collections took 25% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 25% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 25% CPU time recently (threshold: 10%)
# (361, 361, 5) 1997 OK
# distributed.utils_perf - WARNING - full garbage collections took 25% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 25% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 25% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 24% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 24% CPU time recently (threshold: 10%)
# (361, 361, 6) 1998 OK
# distributed.utils_perf - WARNING - full garbage collections took 24% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 24% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 24% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 24% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 27% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 27% CPU time recently (threshold: 10%)
# (361, 361, 7) 1999 OK
# distributed.utils_perf - WARNING - full garbage collections took 24% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 24% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 24% CPU time recently (threshold: 10%)
# (361, 361, 8) 2000 OK
# distributed.utils_perf - WARNING - full garbage collections took 25% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 25% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 25% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 25% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 28% CPU time recently (threshold: 10%)
# (361, 361, 9) 2001 OK
# distributed.utils_perf - WARNING - full garbage collections took 25% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 25% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 25% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 28% CPU time recently (threshold: 10%)
# (361, 361, 10) 2002 OK
# distributed.utils_perf - WARNING - full garbage collections took 25% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# (361, 361, 11) 2003 OK
# distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 25% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 29% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 29% CPU time recently (threshold: 10%)
# (361, 361, 12) 2004 OK
# distributed.utils_perf - WARNING - full garbage collections took 25% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 25% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 25% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 28% CPU time recently (threshold: 10%)
# (361, 361, 13) 2005 OK
# distributed.utils_perf - WARNING - full garbage collections took 25% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 25% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 25% CPU time recently (threshold: 10%)
# (361, 361, 14) 2006 OK
# distributed.utils_perf - WARNING - full garbage collections took 23% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 23% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 25% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 25% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 25% CPU time recently (threshold: 10%)
# (361, 361, 15) 2007 OK
# distributed.utils_perf - WARNING - full garbage collections took 25% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 25% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 25% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 25% CPU time recently (threshold: 10%)
# (361, 361, 16) 2008 OK
# distributed.utils_perf - WARNING - full garbage collections took 23% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 25% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# (361, 361, 17) 2009 OK
# distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 25% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 25% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 25% CPU time recently (threshold: 10%)
# (361, 361, 18) 2010 OK
# distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 25% CPU time recently (threshold: 10%)
# (361, 361, 19) 2011 OK
# distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# (361, 361, 20) 2012 OK
# distributed.utils_perf - WARNING - full garbage collections took 24% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 30% CPU time recently (threshold: 10%)
# (361, 361, 21) 2013 OK
# distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 27% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 30% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 30% CPU time recently (threshold: 10%)
# (361, 361, 22) 2014 OK
# distributed.utils_perf - WARNING - full garbage collections took 27% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 27% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 30% CPU time recently (threshold: 10%)
# (361, 361, 23) 2015 OK
# distributed.utils_perf - WARNING - full garbage collections took 27% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 27% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 27% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 27% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 30% CPU time recently (threshold: 10%)
# (361, 361, 24) 2016 OK
# distributed.utils_perf - WARNING - full garbage collections took 27% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 27% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 27% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 30% CPU time recently (threshold: 10%)
# (361, 361, 25) 2017 OK
# CPU times: user 2min 7s, sys: 3.9 s, total: 2min 11s
# Wall time: 2min

# %%
# %%time

yt_ocean = gyre_psi.yt_ocean
xu_ocean = gyre_psi.xu_ocean

xu_ocean_grid, yt_ocean_grid = np.meshgrid(xu_ocean, yt_ocean)
xu_ocean_flat = np.transpose(xu_ocean_grid.flatten('F'))
yt_ocean_flat = yt_ocean_grid.flatten('F')
flat_list = [xu_ocean_flat, yt_ocean_flat]    
flat_list_points = np.transpose(flat_list)

for yi, y in enumerate(years):
    gyre_psi_flatten = gyre_psi.sel(year=y).stack(z=('xu_ocean', 'yt_ocean')).values
    
    if y == 1993:
        gyre_psi_coarse = scipy.interpolate.griddata(flat_list_points, gyre_psi_flatten, 
                                           (lon_coarse_grid, lat_coarse_grid), 
                                           method='nearest')
        
    else:
        gyre_psi_coarse = np.dstack((gyre_psi_coarse, 
                                    scipy.interpolate.griddata(flat_list_points, gyre_psi_flatten, 
                                           (lon_coarse_grid, lat_coarse_grid), 
                                           method='nearest')))
        
    print(str(gyre_psi_coarse.shape) + ' ' + str(y) + ' OK')
# Out:
# distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 27% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 27% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 30% CPU time recently (threshold: 10%)
# (361, 361) 1993 OK
# distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 29% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 29% CPU time recently (threshold: 10%)
# (361, 361, 2) 1994 OK
# distributed.utils_perf - WARNING - full garbage collections took 25% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 25% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 24% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 27% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 27% CPU time recently (threshold: 10%)
# (361, 361, 3) 1995 OK
# distributed.utils_perf - WARNING - full garbage collections took 23% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 23% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 22% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 22% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 24% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 24% CPU time recently (threshold: 10%)
# (361, 361, 4) 1996 OK
# distributed.utils_perf - WARNING - full garbage collections took 21% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 23% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 23% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 23% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 23% CPU time recently (threshold: 10%)
# (361, 361, 5) 1997 OK
# distributed.utils_perf - WARNING - full garbage collections took 21% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 23% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 23% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 23% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 23% CPU time recently (threshold: 10%)
# (361, 361, 6) 1998 OK
# distributed.utils_perf - WARNING - full garbage collections took 22% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 22% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 22% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 22% CPU time recently (threshold: 10%)
# (361, 361, 7) 1999 OK
# distributed.utils_perf - WARNING - full garbage collections took 20% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 22% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 22% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 22% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 22% CPU time recently (threshold: 10%)
# (361, 361, 8) 2000 OK
# distributed.utils_perf - WARNING - full garbage collections took 22% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 22% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 22% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 23% CPU time recently (threshold: 10%)
# (361, 361, 9) 2001 OK
# distributed.utils_perf - WARNING - full garbage collections took 20% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 23% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 23% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 24% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 24% CPU time recently (threshold: 10%)
# (361, 361, 10) 2002 OK
# distributed.utils_perf - WARNING - full garbage collections took 21% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 21% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 24% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 24% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 24% CPU time recently (threshold: 10%)
# (361, 361, 11) 2003 OK
# distributed.utils_perf - WARNING - full garbage collections took 22% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 22% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 24% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 25% CPU time recently (threshold: 10%)
# (361, 361, 12) 2004 OK
# distributed.utils_perf - WARNING - full garbage collections took 22% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 22% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 22% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 24% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 24% CPU time recently (threshold: 10%)
# (361, 361, 13) 2005 OK
# distributed.utils_perf - WARNING - full garbage collections took 21% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 21% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 24% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 24% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 24% CPU time recently (threshold: 10%)
# (361, 361, 14) 2006 OK
# distributed.utils_perf - WARNING - full garbage collections took 21% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 21% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 24% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 24% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 24% CPU time recently (threshold: 10%)
# (361, 361, 15) 2007 OK
# distributed.utils_perf - WARNING - full garbage collections took 21% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 24% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 24% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 24% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 24% CPU time recently (threshold: 10%)
# (361, 361, 16) 2008 OK
# distributed.utils_perf - WARNING - full garbage collections took 22% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 24% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 24% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 24% CPU time recently (threshold: 10%)
# (361, 361, 17) 2009 OK
# distributed.utils_perf - WARNING - full garbage collections took 22% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 22% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 24% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 24% CPU time recently (threshold: 10%)
# (361, 361, 18) 2010 OK
# distributed.utils_perf - WARNING - full garbage collections took 22% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 21% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 24% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 24% CPU time recently (threshold: 10%)
# (361, 361, 19) 2011 OK
# distributed.utils_perf - WARNING - full garbage collections took 22% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 22% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 22% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 25% CPU time recently (threshold: 10%)
# (361, 361, 20) 2012 OK
# distributed.utils_perf - WARNING - full garbage collections took 22% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 22% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 22% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 22% CPU time recently (threshold: 10%)
# (361, 361, 21) 2013 OK
# distributed.utils_perf - WARNING - full garbage collections took 22% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 23% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 23% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 23% CPU time recently (threshold: 10%)
# (361, 361, 22) 2014 OK
# distributed.utils_perf - WARNING - full garbage collections took 20% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 23% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 23% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 23% CPU time recently (threshold: 10%)
# (361, 361, 23) 2015 OK
# distributed.utils_perf - WARNING - full garbage collections took 20% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 20% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 23% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 23% CPU time recently (threshold: 10%)
# (361, 361, 24) 2016 OK
# distributed.utils_perf - WARNING - full garbage collections took 20% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 20% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 23% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 23% CPU time recently (threshold: 10%)
# (361, 361, 25) 2017 OK
# CPU times: user 2min 53s, sys: 4.25 s, total: 2min 57s
# Wall time: 2min 40s

# %%
# %%time

yt_ocean = eta_t.yt_ocean
xt_ocean = eta_t.xt_ocean

xt_ocean_grid, yt_ocean_grid = np.meshgrid(xt_ocean, yt_ocean)
xt_ocean_flat = np.transpose(xt_ocean_grid.flatten('F'))
yt_ocean_flat = yt_ocean_grid.flatten('F')
flat_list = [xt_ocean_flat, yt_ocean_flat]    
flat_list_points = np.transpose(flat_list)

for yi, y in enumerate(years):
    eta_t_flatten = eta_t.sel(year=y).stack(z=('xt_ocean', 'yt_ocean')).values
    
    if y == 1993:
        eta_t_coarse = scipy.interpolate.griddata(flat_list_points, eta_t_flatten, 
                                           (lon_coarse_grid, lat_coarse_grid), 
                                           method='nearest')
        
    else:
        eta_t_coarse = np.dstack((eta_t_coarse, 
                                    scipy.interpolate.griddata(flat_list_points, eta_t_flatten, 
                                           (lon_coarse_grid, lat_coarse_grid), 
                                           method='nearest')))
        
    print(str(eta_t_coarse.shape) + ' ' + str(y) + ' OK')
# Out:
# distributed.utils_perf - WARNING - full garbage collections took 21% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 20% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 23% CPU time recently (threshold: 10%)
# (361, 361) 1993 OK
# distributed.utils_perf - WARNING - full garbage collections took 21% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 21% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 21% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 23% CPU time recently (threshold: 10%)
# (361, 361, 2) 1994 OK
# distributed.utils_perf - WARNING - full garbage collections took 22% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 22% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 22% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 24% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 25% CPU time recently (threshold: 10%)
# (361, 361, 3) 1995 OK
# distributed.utils_perf - WARNING - full garbage collections took 23% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 23% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 25% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 25% CPU time recently (threshold: 10%)
# (361, 361, 4) 1996 OK
# distributed.utils_perf - WARNING - full garbage collections took 23% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 23% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# (361, 361, 5) 1997 OK
# distributed.utils_perf - WARNING - full garbage collections took 23% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# (361, 361, 6) 1998 OK
# distributed.utils_perf - WARNING - full garbage collections took 24% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 27% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 27% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 27% CPU time recently (threshold: 10%)
# (361, 361, 7) 1999 OK
# distributed.utils_perf - WARNING - full garbage collections took 24% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 28% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 28% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 28% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 31% CPU time recently (threshold: 10%)
# (361, 361, 8) 2000 OK
# distributed.utils_perf - WARNING - full garbage collections took 28% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 28% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 28% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 30% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 30% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 30% CPU time recently (threshold: 10%)
# (361, 361, 9) 2001 OK
# distributed.utils_perf - WARNING - full garbage collections took 27% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 27% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 30% CPU time recently (threshold: 10%)
# (361, 361, 10) 2002 OK
# distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 30% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 30% CPU time recently (threshold: 10%)
# (361, 361, 11) 2003 OK
# distributed.utils_perf - WARNING - full garbage collections took 27% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 27% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 29% CPU time recently (threshold: 10%)
# (361, 361, 12) 2004 OK
# distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 29% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 29% CPU time recently (threshold: 10%)
# (361, 361, 13) 2005 OK
# distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 29% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 29% CPU time recently (threshold: 10%)
# (361, 361, 14) 2006 OK
# distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 25% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 28% CPU time recently (threshold: 10%)
# (361, 361, 15) 2007 OK
# distributed.utils_perf - WARNING - full garbage collections took 25% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 25% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 25% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 25% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 25% CPU time recently (threshold: 10%)
# (361, 361, 16) 2008 OK
# distributed.utils_perf - WARNING - full garbage collections took 25% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 25% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 25% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 28% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 28% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 29% CPU time recently (threshold: 10%)
# (361, 361, 17) 2009 OK
# distributed.utils_perf - WARNING - full garbage collections took 25% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 25% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 29% CPU time recently (threshold: 10%)
# (361, 361, 18) 2010 OK
# distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 29% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 29% CPU time recently (threshold: 10%)
# (361, 361, 19) 2011 OK
# distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 29% CPU time recently (threshold: 10%)
# (361, 361, 20) 2012 OK
# distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 29% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 29% CPU time recently (threshold: 10%)
# (361, 361, 21) 2013 OK
# distributed.utils_perf - WARNING - full garbage collections took 27% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 30% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 29% CPU time recently (threshold: 10%)
# (361, 361, 22) 2014 OK
# distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 27% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 27% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 30% CPU time recently (threshold: 10%)
# (361, 361, 23) 2015 OK
# distributed.utils_perf - WARNING - full garbage collections took 27% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 27% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 27% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 28% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 28% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 31% CPU time recently (threshold: 10%)
# (361, 361, 24) 2016 OK
# distributed.utils_perf - WARNING - full garbage collections took 28% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 28% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 31% CPU time recently (threshold: 10%)
# (361, 361, 25) 2017 OK
# CPU times: user 2min 15s, sys: 2.08 s, total: 2min 17s
# Wall time: 2min 4s

# %%
# %%time

# temp_trans = np.transpose(temp_coarse, (2,1,0))
# temp_slopes = xr.DataArray(np.zeros([lat_coarse.shape[0], lon_coarse.shape[0]]), dims=(
#     'yt_ocean', 'xt_ocean'), coords=[lat_coarse, lon_coarse], name='temp')
# for iid, i in enumerate(lat_coarse):
#     for jid, j in enumerate(lon_coarse):
#         temp_slopes[jid, iid], _, _, _, _ = \
#         stats.linregress(years, temp_trans[:, iid, jid])
#     print('lat_coarse ' + str(np.array(i)))
# print(temp_slopes)    

net_sfc_heating_trans = np.transpose(net_sfc_heating_coarse, (2,1,0))
net_sfc_heating_slopes = xr.DataArray(np.zeros([lat_coarse.shape[0], lon_coarse.shape[0]]), dims=(
    'yt_ocean', 'xt_ocean'), coords=[lat_coarse, lon_coarse], name='net_sfc_heating')
for iid, i in enumerate(lat_coarse):
    for jid, j in enumerate(lon_coarse):
        net_sfc_heating_slopes[jid, iid], _, _, _, _ = \
        stats.linregress(years, net_sfc_heating_trans[:, iid, jid])
    print('lat_coarse ' + str(np.array(i)))
print(net_sfc_heating_slopes)

gyre_psi_trans = np.transpose(gyre_psi_coarse, (2,1,0))
gyre_psi_slopes = xr.DataArray(np.zeros([lat_coarse.shape[0], lon_coarse.shape[0]]), dims=(
    'yt_ocean', 'xu_ocean'), coords=[lat_coarse, lon_coarse], name='gyre_psi')
for iid, i in enumerate(lat_coarse):
    for jid, j in enumerate(lon_coarse):
        gyre_psi_slopes[jid, iid], _, _, _, _ = \
        stats.linregress(years, gyre_psi_trans[:, iid, jid])
    print('lat_coarse ' + str(np.array(i)))
print(gyre_psi_slopes)

eta_t_trans = np.transpose(eta_t_coarse, (2,1,0))
eta_t_slopes = xr.DataArray(np.zeros([lat_coarse.shape[0], lon_coarse.shape[0]]), dims=(
    'yt_ocean', 'xt_ocean'), coords=[lat_coarse, lon_coarse], name='eta_t')
for iid, i in enumerate(lat_coarse):
    for jid, j in enumerate(lon_coarse):
        eta_t_slopes[jid, iid], _, _, _, _ = \
        stats.linregress(years, eta_t_trans[:, iid, jid])
    print('lat_coarse ' + str(np.array(i)))
print(eta_t_slopes)

longitude = t_10.longitude
latitude = t_10.latitude
t_10_slopes = xr.DataArray(np.zeros([latitude.shape[0], longitude.shape[0]]), dims=(
    'latitude', 'longitude'), coords=[latitude, longitude], name='tas_10m')
for iid, i in enumerate(latitude):
    for jid, j in enumerate(longitude):
        t_10_slopes[iid, jid], _, _, _, _ = \
        stats.linregress(years, t_10[:, iid, jid])
    print('latitude ' + str(np.array(i)))
print(t_10_slopes)

mld_trans = np.transpose(mld_coarse, (2,1,0))
mld_slopes = xr.DataArray(np.zeros([lat_coarse.shape[0], lon_coarse.shape[0]]), dims=(
    'yt_ocean', 'xt_ocean'), coords=[lat_coarse, lon_coarse], name='mld')
for iid, i in enumerate(lat_coarse):
    for jid, j in enumerate(lon_coarse):
        mld_slopes[jid, iid], _, _, _, _ = \
        stats.linregress(years, mld_trans[:, iid, jid])
    print('lat_coarse ' + str(np.array(i)))
print(mld_slopes)

slp_slopes = xr.DataArray(np.zeros([latitude.shape[0], longitude.shape[0]]), dims=(
    'latitude', 'longitude'), coords=[latitude, longitude], name='pls')
for iid, i in enumerate(latitude):
    for jid, j in enumerate(longitude):
        slp_slopes[iid, jid], _, _, _, _ = \
        stats.linregress(years, slp[:, iid, jid])
    print('latitude ' + str(np.array(i)))
print(slp_slopes)

u_10_slopes = xr.DataArray(np.zeros([latitude.shape[0], longitude.shape[0]]), dims=(
    'latitude', 'longitude'), coords=[latitude, longitude], name='uas_10m')
for iid, i in enumerate(latitude):
    for jid, j in enumerate(longitude):
        u_10_slopes[iid, jid], _, _, _, _ = \
        stats.linregress(years, u_10[:, iid, jid])
    print('latitude ' + str(np.array(i)))
print(u_10_slopes)

v_10_slopes = xr.DataArray(np.zeros([latitude.shape[0], longitude.shape[0]]), dims=(
    'latitude', 'longitude'), coords=[latitude, longitude], name='vas_10m')
for iid, i in enumerate(latitude):
    for jid, j in enumerate(longitude):
        v_10_slopes[iid, jid], _, _, _, _ = \
        stats.linregress(years, v_10[:, iid, jid])
    print('latitude ' + str(np.array(i)))
print(v_10_slopes)
# Out:
# lat_coarse -70.0
# lat_coarse -69.75
# lat_coarse -69.5
# lat_coarse -69.25
# lat_coarse -69.0
# lat_coarse -68.75
# lat_coarse -68.5
# lat_coarse -68.25
# lat_coarse -68.0
# lat_coarse -67.75
# lat_coarse -67.5
# lat_coarse -67.25
# lat_coarse -67.0
# lat_coarse -66.75
# lat_coarse -66.5
# lat_coarse -66.25
# lat_coarse -66.0
# lat_coarse -65.75
# lat_coarse -65.5
# lat_coarse -65.25
# lat_coarse -65.0
# lat_coarse -64.75
# lat_coarse -64.5
# lat_coarse -64.25
# lat_coarse -64.0
# lat_coarse -63.75
# lat_coarse -63.5
# lat_coarse -63.25
# lat_coarse -63.0
# lat_coarse -62.75
# lat_coarse -62.5
# lat_coarse -62.25
# lat_coarse -62.0
# lat_coarse -61.75
# lat_coarse -61.5
# lat_coarse -61.25
# lat_coarse -61.0
# lat_coarse -60.75
# lat_coarse -60.5
# lat_coarse -60.25
# lat_coarse -60.0
# lat_coarse -59.75
# lat_coarse -59.5
# lat_coarse -59.25
# lat_coarse -59.0
# lat_coarse -58.75
# lat_coarse -58.5
# lat_coarse -58.25
# lat_coarse -58.0
# lat_coarse -57.75
# lat_coarse -57.5
# lat_coarse -57.25
# lat_coarse -57.0
# lat_coarse -56.75
# lat_coarse -56.5
# lat_coarse -56.25
# lat_coarse -56.0
# lat_coarse -55.75
# lat_coarse -55.5
# lat_coarse -55.25
# lat_coarse -55.0
# lat_coarse -54.75
# lat_coarse -54.5
# lat_coarse -54.25
# lat_coarse -54.0
# lat_coarse -53.75
# lat_coarse -53.5
# lat_coarse -53.25
# lat_coarse -53.0
# lat_coarse -52.75
# lat_coarse -52.5
# lat_coarse -52.25
# lat_coarse -52.0
# lat_coarse -51.75
# lat_coarse -51.5
# lat_coarse -51.25
# lat_coarse -51.0
# lat_coarse -50.75
# lat_coarse -50.5
# lat_coarse -50.25
# lat_coarse -50.0
# lat_coarse -49.75
# lat_coarse -49.5
# lat_coarse -49.25
# lat_coarse -49.0
# lat_coarse -48.75
# lat_coarse -48.5
# lat_coarse -48.25
# lat_coarse -48.0
# lat_coarse -47.75
# lat_coarse -47.5
# lat_coarse -47.25
# lat_coarse -47.0
# lat_coarse -46.75
# lat_coarse -46.5
# lat_coarse -46.25
# lat_coarse -46.0
# lat_coarse -45.75
# lat_coarse -45.5
# lat_coarse -45.25
# lat_coarse -45.0
# lat_coarse -44.75
# lat_coarse -44.5
# lat_coarse -44.25
# lat_coarse -44.0
# lat_coarse -43.75
# lat_coarse -43.5
# lat_coarse -43.25
# lat_coarse -43.0
# lat_coarse -42.75
# lat_coarse -42.5
# lat_coarse -42.25
# lat_coarse -42.0
# lat_coarse -41.75
# lat_coarse -41.5
# lat_coarse -41.25
# lat_coarse -41.0
# lat_coarse -40.75
# lat_coarse -40.5
# lat_coarse -40.25
# lat_coarse -40.0
# lat_coarse -39.75
# lat_coarse -39.5
# lat_coarse -39.25
# lat_coarse -39.0
# lat_coarse -38.75
# lat_coarse -38.5
# lat_coarse -38.25
# lat_coarse -38.0
# lat_coarse -37.75
# lat_coarse -37.5
# lat_coarse -37.25
# lat_coarse -37.0
# lat_coarse -36.75
# lat_coarse -36.5
# lat_coarse -36.25
# lat_coarse -36.0
# lat_coarse -35.75
# lat_coarse -35.5
# lat_coarse -35.25
# lat_coarse -35.0
# lat_coarse -34.75
# lat_coarse -34.5
# lat_coarse -34.25
# lat_coarse -34.0
# lat_coarse -33.75
# lat_coarse -33.5
# lat_coarse -33.25
# lat_coarse -33.0
# lat_coarse -32.75
# lat_coarse -32.5
# lat_coarse -32.25
# lat_coarse -32.0
# lat_coarse -31.75
# lat_coarse -31.5
# lat_coarse -31.25
# lat_coarse -31.0
# lat_coarse -30.75
# lat_coarse -30.5
# lat_coarse -30.25
# lat_coarse -30.0
# lat_coarse -29.75
# lat_coarse -29.5
# lat_coarse -29.25
# lat_coarse -29.0
# lat_coarse -28.75
# lat_coarse -28.5
# lat_coarse -28.25
# lat_coarse -28.0
# lat_coarse -27.75
# lat_coarse -27.5
# lat_coarse -27.25
# lat_coarse -27.0
# lat_coarse -26.75
# lat_coarse -26.5
# lat_coarse -26.25
# lat_coarse -26.0
# lat_coarse -25.75
# lat_coarse -25.5
# lat_coarse -25.25
# lat_coarse -25.0
# lat_coarse -24.75
# lat_coarse -24.5
# lat_coarse -24.25
# lat_coarse -24.0
# lat_coarse -23.75
# lat_coarse -23.5
# lat_coarse -23.25
# lat_coarse -23.0
# lat_coarse -22.75
# lat_coarse -22.5
# lat_coarse -22.25
# lat_coarse -22.0
# lat_coarse -21.75
# lat_coarse -21.5
# lat_coarse -21.25
# lat_coarse -21.0
# lat_coarse -20.75
# lat_coarse -20.5
# lat_coarse -20.25
# lat_coarse -20.0
# lat_coarse -19.75
# lat_coarse -19.5
# lat_coarse -19.25
# lat_coarse -19.0
# lat_coarse -18.75
# lat_coarse -18.5
# lat_coarse -18.25
# lat_coarse -18.0
# lat_coarse -17.75
# lat_coarse -17.5
# lat_coarse -17.25
# lat_coarse -17.0
# lat_coarse -16.75
# lat_coarse -16.5
# lat_coarse -16.25
# lat_coarse -16.0
# lat_coarse -15.75
# lat_coarse -15.5
# lat_coarse -15.25
# lat_coarse -15.0
# lat_coarse -14.75
# lat_coarse -14.5
# lat_coarse -14.25
# lat_coarse -14.0
# lat_coarse -13.75
# lat_coarse -13.5
# lat_coarse -13.25
# lat_coarse -13.0
# lat_coarse -12.75
# lat_coarse -12.5
# lat_coarse -12.25
# lat_coarse -12.0
# lat_coarse -11.75
# lat_coarse -11.5
# lat_coarse -11.25
# lat_coarse -11.0
# lat_coarse -10.75
# lat_coarse -10.5
# lat_coarse -10.25
# lat_coarse -10.0
# lat_coarse -9.75
# lat_coarse -9.5
# lat_coarse -9.25
# lat_coarse -9.0
# lat_coarse -8.75
# lat_coarse -8.5
# lat_coarse -8.25
# lat_coarse -8.0
# lat_coarse -7.75
# lat_coarse -7.5
# lat_coarse -7.25
# lat_coarse -7.0
# lat_coarse -6.75
# lat_coarse -6.5
# lat_coarse -6.25
# lat_coarse -6.0
# lat_coarse -5.75
# lat_coarse -5.5
# lat_coarse -5.25
# lat_coarse -5.0
# lat_coarse -4.75
# lat_coarse -4.5
# lat_coarse -4.25
# lat_coarse -4.0
# lat_coarse -3.75
# lat_coarse -3.5
# lat_coarse -3.25
# lat_coarse -3.0
# lat_coarse -2.75
# lat_coarse -2.5
# lat_coarse -2.25
# lat_coarse -2.0
# lat_coarse -1.75
# lat_coarse -1.5
# lat_coarse -1.25
# lat_coarse -1.0
# lat_coarse -0.75
# lat_coarse -0.5
# lat_coarse -0.25
# lat_coarse 0.0
# lat_coarse 0.25
# lat_coarse 0.5
# lat_coarse 0.75
# lat_coarse 1.0
# lat_coarse 1.25
# lat_coarse 1.5
# lat_coarse 1.75
# lat_coarse 2.0
# lat_coarse 2.25
# lat_coarse 2.5
# lat_coarse 2.75
# lat_coarse 3.0
# lat_coarse 3.25
# lat_coarse 3.5
# lat_coarse 3.75
# lat_coarse 4.0
# lat_coarse 4.25
# lat_coarse 4.5
# lat_coarse 4.75
# lat_coarse 5.0
# lat_coarse 5.25
# lat_coarse 5.5
# lat_coarse 5.75
# lat_coarse 6.0
# lat_coarse 6.25
# lat_coarse 6.5
# lat_coarse 6.75
# lat_coarse 7.0
# lat_coarse 7.25
# lat_coarse 7.5
# lat_coarse 7.75
# lat_coarse 8.0
# lat_coarse 8.25
# lat_coarse 8.5
# lat_coarse 8.75
# lat_coarse 9.0
# lat_coarse 9.25
# lat_coarse 9.5
# lat_coarse 9.75
# lat_coarse 10.0
# lat_coarse 10.25
# lat_coarse 10.5
# lat_coarse 10.75
# lat_coarse 11.0
# lat_coarse 11.25
# lat_coarse 11.5
# lat_coarse 11.75
# lat_coarse 12.0
# lat_coarse 12.25
# lat_coarse 12.5
# lat_coarse 12.75
# lat_coarse 13.0
# lat_coarse 13.25
# lat_coarse 13.5
# lat_coarse 13.75
# lat_coarse 14.0
# lat_coarse 14.25
# lat_coarse 14.5
# lat_coarse 14.75
# lat_coarse 15.0
# lat_coarse 15.25
# lat_coarse 15.5
# lat_coarse 15.75
# lat_coarse 16.0
# lat_coarse 16.25
# lat_coarse 16.5
# lat_coarse 16.75
# lat_coarse 17.0
# lat_coarse 17.25
# lat_coarse 17.5
# lat_coarse 17.75
# lat_coarse 18.0
# lat_coarse 18.25
# lat_coarse 18.5
# lat_coarse 18.75
# lat_coarse 19.0
# lat_coarse 19.25
# lat_coarse 19.5
# lat_coarse 19.75
# lat_coarse 20.0
# <xarray.DataArray 'net_sfc_heating' (yt_ocean: 361, xt_ocean: 361)>
# array([[      nan,       nan,       nan, ..., -0.177053, -0.19549 , -0.196335],
#        [      nan,       nan,       nan, ..., -0.136183, -0.149424, -0.170994],
#        [      nan,       nan,       nan, ..., -0.183811, -0.194531, -0.192896],
#        ...,
#        [ 0.079387, -0.001517, -0.093884, ..., -0.210413, -0.210265, -0.204376],
#        [-0.02625 , -0.11968 , -0.167686, ..., -0.165949, -0.211025, -0.209199],
#        [-0.254237, -0.277588, -0.239522, ..., -0.165114, -0.203389, -0.222682]])
# Coordinates:
#   * yt_ocean  (yt_ocean) float64 -70.0 -69.75 -69.5 -69.25 ... 19.5 19.75 20.0
#   * xt_ocean  (xt_ocean) float64 -270.0 -269.8 -269.5 ... -180.5 -180.2 -180.0
# lat_coarse -70.0
# lat_coarse -69.75
# lat_coarse -69.5
# lat_coarse -69.25
# lat_coarse -69.0
# lat_coarse -68.75
# lat_coarse -68.5
# lat_coarse -68.25
# lat_coarse -68.0
# lat_coarse -67.75
# lat_coarse -67.5
# lat_coarse -67.25
# lat_coarse -67.0
# lat_coarse -66.75
# lat_coarse -66.5
# lat_coarse -66.25
# lat_coarse -66.0
# lat_coarse -65.75
# lat_coarse -65.5
# lat_coarse -65.25
# lat_coarse -65.0
# lat_coarse -64.75
# lat_coarse -64.5
# lat_coarse -64.25
# lat_coarse -64.0
# lat_coarse -63.75
# lat_coarse -63.5
# lat_coarse -63.25
# lat_coarse -63.0
# lat_coarse -62.75
# lat_coarse -62.5
# lat_coarse -62.25
# lat_coarse -62.0
# lat_coarse -61.75
# lat_coarse -61.5
# lat_coarse -61.25
# lat_coarse -61.0
# lat_coarse -60.75
# lat_coarse -60.5
# lat_coarse -60.25
# lat_coarse -60.0
# lat_coarse -59.75
# lat_coarse -59.5
# lat_coarse -59.25
# lat_coarse -59.0
# lat_coarse -58.75
# lat_coarse -58.5
# lat_coarse -58.25
# lat_coarse -58.0
# lat_coarse -57.75
# lat_coarse -57.5
# lat_coarse -57.25
# lat_coarse -57.0
# lat_coarse -56.75
# lat_coarse -56.5
# lat_coarse -56.25
# lat_coarse -56.0
# lat_coarse -55.75
# lat_coarse -55.5
# lat_coarse -55.25
# lat_coarse -55.0
# lat_coarse -54.75
# lat_coarse -54.5
# lat_coarse -54.25
# lat_coarse -54.0
# lat_coarse -53.75
# lat_coarse -53.5
# lat_coarse -53.25
# lat_coarse -53.0
# lat_coarse -52.75
# lat_coarse -52.5
# lat_coarse -52.25
# lat_coarse -52.0
# lat_coarse -51.75
# lat_coarse -51.5
# lat_coarse -51.25
# lat_coarse -51.0
# lat_coarse -50.75
# lat_coarse -50.5
# lat_coarse -50.25
# lat_coarse -50.0
# lat_coarse -49.75
# lat_coarse -49.5
# lat_coarse -49.25
# lat_coarse -49.0
# lat_coarse -48.75
# lat_coarse -48.5
# lat_coarse -48.25
# lat_coarse -48.0
# lat_coarse -47.75
# lat_coarse -47.5
# lat_coarse -47.25
# lat_coarse -47.0
# lat_coarse -46.75
# lat_coarse -46.5
# lat_coarse -46.25
# lat_coarse -46.0
# lat_coarse -45.75
# lat_coarse -45.5
# lat_coarse -45.25
# lat_coarse -45.0
# lat_coarse -44.75
# lat_coarse -44.5
# lat_coarse -44.25
# lat_coarse -44.0
# lat_coarse -43.75
# lat_coarse -43.5
# lat_coarse -43.25
# lat_coarse -43.0
# lat_coarse -42.75
# lat_coarse -42.5
# lat_coarse -42.25
# lat_coarse -42.0
# lat_coarse -41.75
# lat_coarse -41.5
# lat_coarse -41.25
# lat_coarse -41.0
# lat_coarse -40.75
# lat_coarse -40.5
# lat_coarse -40.25
# lat_coarse -40.0
# lat_coarse -39.75
# lat_coarse -39.5
# lat_coarse -39.25
# lat_coarse -39.0
# lat_coarse -38.75
# lat_coarse -38.5
# lat_coarse -38.25
# lat_coarse -38.0
# lat_coarse -37.75
# lat_coarse -37.5
# lat_coarse -37.25
# lat_coarse -37.0
# lat_coarse -36.75
# lat_coarse -36.5
# lat_coarse -36.25
# lat_coarse -36.0
# lat_coarse -35.75
# lat_coarse -35.5
# lat_coarse -35.25
# lat_coarse -35.0
# lat_coarse -34.75
# lat_coarse -34.5
# lat_coarse -34.25
# lat_coarse -34.0
# lat_coarse -33.75
# lat_coarse -33.5
# lat_coarse -33.25
# lat_coarse -33.0
# lat_coarse -32.75
# lat_coarse -32.5
# lat_coarse -32.25
# lat_coarse -32.0
# lat_coarse -31.75
# lat_coarse -31.5
# lat_coarse -31.25
# lat_coarse -31.0
# lat_coarse -30.75
# lat_coarse -30.5
# lat_coarse -30.25
# lat_coarse -30.0
# lat_coarse -29.75
# lat_coarse -29.5
# lat_coarse -29.25
# lat_coarse -29.0
# lat_coarse -28.75
# lat_coarse -28.5
# lat_coarse -28.25
# lat_coarse -28.0
# lat_coarse -27.75
# lat_coarse -27.5
# lat_coarse -27.25
# lat_coarse -27.0
# lat_coarse -26.75
# lat_coarse -26.5
# lat_coarse -26.25
# lat_coarse -26.0
# lat_coarse -25.75
# lat_coarse -25.5
# lat_coarse -25.25
# lat_coarse -25.0
# lat_coarse -24.75
# lat_coarse -24.5
# lat_coarse -24.25
# lat_coarse -24.0
# lat_coarse -23.75
# lat_coarse -23.5
# lat_coarse -23.25
# lat_coarse -23.0
# lat_coarse -22.75
# lat_coarse -22.5
# lat_coarse -22.25
# lat_coarse -22.0
# lat_coarse -21.75
# lat_coarse -21.5
# lat_coarse -21.25
# lat_coarse -21.0
# lat_coarse -20.75
# lat_coarse -20.5
# lat_coarse -20.25
# lat_coarse -20.0
# lat_coarse -19.75
# lat_coarse -19.5
# lat_coarse -19.25
# lat_coarse -19.0
# lat_coarse -18.75
# lat_coarse -18.5
# lat_coarse -18.25
# lat_coarse -18.0
# lat_coarse -17.75
# lat_coarse -17.5
# lat_coarse -17.25
# lat_coarse -17.0
# lat_coarse -16.75
# lat_coarse -16.5
# lat_coarse -16.25
# lat_coarse -16.0
# lat_coarse -15.75
# lat_coarse -15.5
# lat_coarse -15.25
# lat_coarse -15.0
# lat_coarse -14.75
# lat_coarse -14.5
# lat_coarse -14.25
# lat_coarse -14.0
# lat_coarse -13.75
# lat_coarse -13.5
# lat_coarse -13.25
# lat_coarse -13.0
# lat_coarse -12.75
# lat_coarse -12.5
# lat_coarse -12.25
# lat_coarse -12.0
# lat_coarse -11.75
# lat_coarse -11.5
# lat_coarse -11.25
# lat_coarse -11.0
# lat_coarse -10.75
# lat_coarse -10.5
# lat_coarse -10.25
# lat_coarse -10.0
# lat_coarse -9.75
# lat_coarse -9.5
# lat_coarse -9.25
# lat_coarse -9.0
# lat_coarse -8.75
# lat_coarse -8.5
# lat_coarse -8.25
# lat_coarse -8.0
# lat_coarse -7.75
# lat_coarse -7.5
# lat_coarse -7.25
# lat_coarse -7.0
# lat_coarse -6.75
# lat_coarse -6.5
# lat_coarse -6.25
# lat_coarse -6.0
# lat_coarse -5.75
# lat_coarse -5.5
# lat_coarse -5.25
# lat_coarse -5.0
# lat_coarse -4.75
# lat_coarse -4.5
# lat_coarse -4.25
# lat_coarse -4.0
# lat_coarse -3.75
# lat_coarse -3.5
# lat_coarse -3.25
# lat_coarse -3.0
# lat_coarse -2.75
# lat_coarse -2.5
# lat_coarse -2.25
# lat_coarse -2.0
# lat_coarse -1.75
# lat_coarse -1.5
# lat_coarse -1.25
# lat_coarse -1.0
# lat_coarse -0.75
# lat_coarse -0.5
# lat_coarse -0.25
# lat_coarse 0.0
# lat_coarse 0.25
# lat_coarse 0.5
# lat_coarse 0.75
# lat_coarse 1.0
# lat_coarse 1.25
# lat_coarse 1.5
# lat_coarse 1.75
# lat_coarse 2.0
# lat_coarse 2.25
# lat_coarse 2.5
# lat_coarse 2.75
# lat_coarse 3.0
# lat_coarse 3.25
# lat_coarse 3.5
# lat_coarse 3.75
# lat_coarse 4.0
# lat_coarse 4.25
# lat_coarse 4.5
# lat_coarse 4.75
# lat_coarse 5.0
# lat_coarse 5.25
# lat_coarse 5.5
# lat_coarse 5.75
# lat_coarse 6.0
# lat_coarse 6.25
# lat_coarse 6.5
# lat_coarse 6.75
# lat_coarse 7.0
# lat_coarse 7.25
# lat_coarse 7.5
# lat_coarse 7.75
# lat_coarse 8.0
# lat_coarse 8.25
# lat_coarse 8.5
# lat_coarse 8.75
# lat_coarse 9.0
# lat_coarse 9.25
# lat_coarse 9.5
# lat_coarse 9.75
# lat_coarse 10.0
# lat_coarse 10.25
# lat_coarse 10.5
# lat_coarse 10.75
# lat_coarse 11.0
# lat_coarse 11.25
# lat_coarse 11.5
# lat_coarse 11.75
# lat_coarse 12.0
# lat_coarse 12.25
# lat_coarse 12.5
# lat_coarse 12.75
# lat_coarse 13.0
# lat_coarse 13.25
# lat_coarse 13.5
# lat_coarse 13.75
# lat_coarse 14.0
# lat_coarse 14.25
# lat_coarse 14.5
# lat_coarse 14.75
# lat_coarse 15.0
# lat_coarse 15.25
# lat_coarse 15.5
# lat_coarse 15.75
# lat_coarse 16.0
# lat_coarse 16.25
# lat_coarse 16.5
# lat_coarse 16.75
# lat_coarse 17.0
# lat_coarse 17.25
# lat_coarse 17.5
# lat_coarse 17.75
# lat_coarse 18.0
# lat_coarse 18.25
# lat_coarse 18.5
# lat_coarse 18.75
# lat_coarse 19.0
# lat_coarse 19.25
# lat_coarse 19.5
# lat_coarse 19.75
# lat_coarse 20.0
# <xarray.DataArray 'gyre_psi' (yt_ocean: 361, xu_ocean: 361)>
# array([[      nan,       nan,       nan, ..., -0.007254, -0.005759, -0.005126],
#        [      nan,       nan,       nan, ..., -0.005726, -0.002908,  0.000127],
#        [      nan,       nan,       nan, ..., -0.003497,  0.00239 ,  0.007863],
#        ...,
#        [-0.015318, -0.015732, -0.015904, ..., -0.060379, -0.0594  , -0.058434],
#        [-0.017512, -0.017267, -0.015613, ..., -0.065358, -0.062393, -0.057022],
#        [-0.008823, -0.007654, -0.006256, ..., -0.071529, -0.067707, -0.060499]])
# Coordinates:
#   * yt_ocean  (yt_ocean) float64 -70.0 -69.75 -69.5 -69.25 ... 19.5 19.75 20.0
#   * xu_ocean  (xu_ocean) float64 -270.0 -269.8 -269.5 ... -180.5 -180.2 -180.0
# lat_coarse -70.0
# lat_coarse -69.75
# lat_coarse -69.5
# lat_coarse -69.25
# lat_coarse -69.0
# lat_coarse -68.75
# lat_coarse -68.5
# lat_coarse -68.25
# lat_coarse -68.0
# lat_coarse -67.75
# lat_coarse -67.5
# lat_coarse -67.25
# lat_coarse -67.0
# lat_coarse -66.75
# lat_coarse -66.5
# lat_coarse -66.25
# lat_coarse -66.0
# lat_coarse -65.75
# lat_coarse -65.5
# lat_coarse -65.25
# lat_coarse -65.0
# lat_coarse -64.75
# lat_coarse -64.5
# lat_coarse -64.25
# lat_coarse -64.0
# lat_coarse -63.75
# lat_coarse -63.5
# lat_coarse -63.25
# lat_coarse -63.0
# lat_coarse -62.75
# lat_coarse -62.5
# lat_coarse -62.25
# lat_coarse -62.0
# lat_coarse -61.75
# lat_coarse -61.5
# lat_coarse -61.25
# lat_coarse -61.0
# lat_coarse -60.75
# lat_coarse -60.5
# lat_coarse -60.25
# lat_coarse -60.0
# lat_coarse -59.75
# lat_coarse -59.5
# lat_coarse -59.25
# lat_coarse -59.0
# lat_coarse -58.75
# lat_coarse -58.5
# lat_coarse -58.25
# lat_coarse -58.0
# lat_coarse -57.75
# lat_coarse -57.5
# lat_coarse -57.25
# lat_coarse -57.0
# lat_coarse -56.75
# lat_coarse -56.5
# lat_coarse -56.25
# lat_coarse -56.0
# lat_coarse -55.75
# lat_coarse -55.5
# lat_coarse -55.25
# lat_coarse -55.0
# lat_coarse -54.75
# lat_coarse -54.5
# lat_coarse -54.25
# lat_coarse -54.0
# lat_coarse -53.75
# lat_coarse -53.5
# lat_coarse -53.25
# lat_coarse -53.0
# lat_coarse -52.75
# lat_coarse -52.5
# lat_coarse -52.25
# lat_coarse -52.0
# lat_coarse -51.75
# lat_coarse -51.5
# lat_coarse -51.25
# lat_coarse -51.0
# lat_coarse -50.75
# lat_coarse -50.5
# lat_coarse -50.25
# lat_coarse -50.0
# lat_coarse -49.75
# lat_coarse -49.5
# lat_coarse -49.25
# lat_coarse -49.0
# lat_coarse -48.75
# lat_coarse -48.5
# lat_coarse -48.25
# lat_coarse -48.0
# lat_coarse -47.75
# lat_coarse -47.5
# lat_coarse -47.25
# lat_coarse -47.0
# lat_coarse -46.75
# lat_coarse -46.5
# lat_coarse -46.25
# lat_coarse -46.0
# lat_coarse -45.75
# lat_coarse -45.5
# lat_coarse -45.25
# lat_coarse -45.0
# lat_coarse -44.75
# lat_coarse -44.5
# lat_coarse -44.25
# lat_coarse -44.0
# lat_coarse -43.75
# lat_coarse -43.5
# lat_coarse -43.25
# lat_coarse -43.0
# lat_coarse -42.75
# lat_coarse -42.5
# lat_coarse -42.25
# lat_coarse -42.0
# lat_coarse -41.75
# lat_coarse -41.5
# lat_coarse -41.25
# lat_coarse -41.0
# lat_coarse -40.75
# lat_coarse -40.5
# lat_coarse -40.25
# lat_coarse -40.0
# lat_coarse -39.75
# lat_coarse -39.5
# lat_coarse -39.25
# lat_coarse -39.0
# lat_coarse -38.75
# lat_coarse -38.5
# lat_coarse -38.25
# lat_coarse -38.0
# lat_coarse -37.75
# lat_coarse -37.5
# lat_coarse -37.25
# lat_coarse -37.0
# lat_coarse -36.75
# lat_coarse -36.5
# lat_coarse -36.25
# lat_coarse -36.0
# lat_coarse -35.75
# lat_coarse -35.5
# lat_coarse -35.25
# lat_coarse -35.0
# lat_coarse -34.75
# lat_coarse -34.5
# lat_coarse -34.25
# lat_coarse -34.0
# lat_coarse -33.75
# lat_coarse -33.5
# lat_coarse -33.25
# lat_coarse -33.0
# lat_coarse -32.75
# lat_coarse -32.5
# lat_coarse -32.25
# lat_coarse -32.0
# lat_coarse -31.75
# lat_coarse -31.5
# lat_coarse -31.25
# lat_coarse -31.0
# lat_coarse -30.75
# lat_coarse -30.5
# lat_coarse -30.25
# lat_coarse -30.0
# lat_coarse -29.75
# lat_coarse -29.5
# lat_coarse -29.25
# lat_coarse -29.0
# lat_coarse -28.75
# lat_coarse -28.5
# lat_coarse -28.25
# lat_coarse -28.0
# lat_coarse -27.75
# lat_coarse -27.5
# lat_coarse -27.25
# lat_coarse -27.0
# lat_coarse -26.75
# lat_coarse -26.5
# lat_coarse -26.25
# lat_coarse -26.0
# lat_coarse -25.75
# lat_coarse -25.5
# lat_coarse -25.25
# lat_coarse -25.0
# lat_coarse -24.75
# lat_coarse -24.5
# lat_coarse -24.25
# lat_coarse -24.0
# lat_coarse -23.75
# lat_coarse -23.5
# lat_coarse -23.25
# lat_coarse -23.0
# lat_coarse -22.75
# lat_coarse -22.5
# lat_coarse -22.25
# lat_coarse -22.0
# lat_coarse -21.75
# lat_coarse -21.5
# lat_coarse -21.25
# lat_coarse -21.0
# lat_coarse -20.75
# lat_coarse -20.5
# lat_coarse -20.25
# lat_coarse -20.0
# lat_coarse -19.75
# lat_coarse -19.5
# lat_coarse -19.25
# lat_coarse -19.0
# lat_coarse -18.75
# lat_coarse -18.5
# lat_coarse -18.25
# lat_coarse -18.0
# lat_coarse -17.75
# lat_coarse -17.5
# lat_coarse -17.25
# lat_coarse -17.0
# lat_coarse -16.75
# lat_coarse -16.5
# lat_coarse -16.25
# lat_coarse -16.0
# lat_coarse -15.75
# lat_coarse -15.5
# lat_coarse -15.25
# lat_coarse -15.0
# lat_coarse -14.75
# lat_coarse -14.5
# lat_coarse -14.25
# lat_coarse -14.0
# lat_coarse -13.75
# lat_coarse -13.5
# lat_coarse -13.25
# lat_coarse -13.0
# lat_coarse -12.75
# lat_coarse -12.5
# lat_coarse -12.25
# lat_coarse -12.0
# lat_coarse -11.75
# lat_coarse -11.5
# lat_coarse -11.25
# lat_coarse -11.0
# lat_coarse -10.75
# lat_coarse -10.5
# lat_coarse -10.25
# lat_coarse -10.0
# lat_coarse -9.75
# lat_coarse -9.5
# lat_coarse -9.25
# lat_coarse -9.0
# lat_coarse -8.75
# lat_coarse -8.5
# lat_coarse -8.25
# lat_coarse -8.0
# lat_coarse -7.75
# lat_coarse -7.5
# lat_coarse -7.25
# lat_coarse -7.0
# lat_coarse -6.75
# lat_coarse -6.5
# lat_coarse -6.25
# lat_coarse -6.0
# lat_coarse -5.75
# lat_coarse -5.5
# lat_coarse -5.25
# lat_coarse -5.0
# lat_coarse -4.75
# lat_coarse -4.5
# lat_coarse -4.25
# lat_coarse -4.0
# lat_coarse -3.75
# lat_coarse -3.5
# lat_coarse -3.25
# lat_coarse -3.0
# lat_coarse -2.75
# lat_coarse -2.5
# lat_coarse -2.25
# lat_coarse -2.0
# lat_coarse -1.75
# lat_coarse -1.5
# lat_coarse -1.25
# lat_coarse -1.0
# lat_coarse -0.75
# lat_coarse -0.5
# lat_coarse -0.25
# lat_coarse 0.0
# lat_coarse 0.25
# lat_coarse 0.5
# lat_coarse 0.75
# lat_coarse 1.0
# lat_coarse 1.25
# lat_coarse 1.5
# lat_coarse 1.75
# lat_coarse 2.0
# lat_coarse 2.25
# lat_coarse 2.5
# lat_coarse 2.75
# lat_coarse 3.0
# lat_coarse 3.25
# lat_coarse 3.5
# lat_coarse 3.75
# lat_coarse 4.0
# lat_coarse 4.25
# lat_coarse 4.5
# lat_coarse 4.75
# lat_coarse 5.0
# lat_coarse 5.25
# lat_coarse 5.5
# lat_coarse 5.75
# lat_coarse 6.0
# lat_coarse 6.25
# lat_coarse 6.5
# lat_coarse 6.75
# lat_coarse 7.0
# lat_coarse 7.25
# lat_coarse 7.5
# lat_coarse 7.75
# lat_coarse 8.0
# lat_coarse 8.25
# lat_coarse 8.5
# lat_coarse 8.75
# lat_coarse 9.0
# lat_coarse 9.25
# lat_coarse 9.5
# lat_coarse 9.75
# lat_coarse 10.0
# lat_coarse 10.25
# lat_coarse 10.5
# lat_coarse 10.75
# lat_coarse 11.0
# lat_coarse 11.25
# lat_coarse 11.5
# lat_coarse 11.75
# lat_coarse 12.0
# lat_coarse 12.25
# lat_coarse 12.5
# lat_coarse 12.75
# lat_coarse 13.0
# lat_coarse 13.25
# lat_coarse 13.5
# lat_coarse 13.75
# lat_coarse 14.0
# lat_coarse 14.25
# lat_coarse 14.5
# lat_coarse 14.75
# lat_coarse 15.0
# lat_coarse 15.25
# lat_coarse 15.5
# lat_coarse 15.75
# lat_coarse 16.0
# lat_coarse 16.25
# lat_coarse 16.5
# lat_coarse 16.75
# lat_coarse 17.0
# lat_coarse 17.25
# lat_coarse 17.5
# lat_coarse 17.75
# lat_coarse 18.0
# distributed.utils_perf - WARNING - full garbage collections took 31% CPU time recently (threshold: 10%)
# lat_coarse 18.25
# lat_coarse 18.5
# lat_coarse 18.75
# lat_coarse 19.0
# lat_coarse 19.25
# lat_coarse 19.5
# lat_coarse 19.75
# lat_coarse 20.0
# <xarray.DataArray 'eta_t' (yt_ocean: 361, xt_ocean: 361)>
# array([[      nan,       nan,       nan, ..., -0.001278, -0.001365, -0.001405],
#        [      nan,       nan,       nan, ..., -0.001289, -0.001346, -0.001365],
#        [      nan,       nan,       nan, ..., -0.001195, -0.001225, -0.001247],
#        ...,
#        [ 0.002127,  0.002095,  0.00205 , ...,  0.000333,  0.000393,  0.000444],
#        [ 0.001877,  0.001847,  0.001836, ...,  0.000451,  0.000504,  0.000539],
#        [ 0.001646,  0.00166 ,  0.001697, ...,  0.000522,  0.000574,  0.000605]])
# Coordinates:
#   * yt_ocean  (yt_ocean) float64 -70.0 -69.75 -69.5 -69.25 ... 19.5 19.75 20.0
#   * xt_ocean  (xt_ocean) float64 -270.0 -269.8 -269.5 ... -180.5 -180.2 -180.0
# latitude -69.9218061359604
# latitude -69.3601893179717
# latitude -68.7985722135654
# latitude -68.2369548449477
# latitude -67.6753372320917
# latitude -67.1137193930113
# latitude -66.5521013439961
# latitude -65.9904830998127
# latitude -65.4288646738789
# latitude -64.8672460784143
# latitude -64.3056273245713
# latitude -63.7440084225492
# latitude -63.1823893816941
# latitude -62.6207702105861
# latitude -62.0591509171167
# latitude -61.4975315085564
# latitude -60.9359119916146
# latitude -60.374292372493
# latitude -59.8126726569327
# latitude -59.2510528502565
# latitude -58.6894329574061
# latitude -58.1278129829758
# latitude -57.5661929312427
# latitude -57.0045728061936
# latitude -56.4429526115493
# latitude -55.8813323507866
# latitude -55.3197120271579
# latitude -54.7580916437092
# latitude -54.1964712032965
# latitude -53.6348507085999
# latitude -53.0732301621377
# latitude -52.5116095662779
# latitude -51.9499889232498
# latitude -51.3883682351539
# latitude -50.826747503971
# latitude -50.2651267315709
# latitude -49.70350591972
# latitude -49.1418850700887
# latitude -48.5802641842574
# latitude -48.018643263723
# latitude -47.4570223099043
# latitude -46.895401324147
# latitude -46.3337803077285
# latitude -45.7721592618623
# latitude -45.2105381877018
# latitude -44.6489170863444
# latitude -44.0872959588346
# latitude -43.5256748061674
# latitude -42.9640536292911
# latitude -42.4024324291106
# latitude -41.840811206489
# latitude -41.2791899622508
# latitude -40.7175686971841
# latitude -40.1559474120422
# latitude -39.5943261075457
# latitude -39.0327047843849
# latitude -38.4710834432205
# latitude -37.909462084686
# latitude -37.3478407093888
# latitude -36.7862193179117
# latitude -36.2245979108143
# latitude -35.6629764886338
# latitude -35.1013550518869
# latitude -34.53973360107
# latitude -33.9781121366611
# latitude -33.4164906591199
# latitude -32.8548691688896
# latitude -32.2932476663967
# latitude -31.7316261520529
# latitude -31.170004626255
# latitude -30.6083830893861
# latitude -30.046761541816
# latitude -29.4851399839021
# latitude -28.9235184159896
# latitude -28.3618968384127
# latitude -27.8002752514945
# latitude -27.2386536555477
# latitude -26.6770320508754
# latitude -26.1154104377713
# latitude -25.55378881652
# latitude -24.9921671873976
# latitude -24.4305455506723
# latitude -23.8689239066043
# latitude -23.3073022554465
# latitude -22.7456805974447
# latitude -22.184058932838
# latitude -21.6224372618593
# latitude -21.0608155847349
# latitude -20.4991939016857
# latitude -19.9375722129269
# latitude -19.3759505186682
# latitude -18.8143288191145
# latitude -18.2527071144658
# latitude -17.6910854049175
# latitude -17.1294636906605
# latitude -16.5678419718816
# latitude -16.0062202487636
# latitude -15.4445985214858
# latitude -14.8829767902235
# latitude -14.3213550551487
# latitude -13.7597333164304
# latitude -13.1981115742342
# latitude -12.6364898287229
# latitude -12.0748680800568
# latitude -11.5132463283931
# latitude -10.9516245738869
# latitude -10.3900028166909
# latitude -9.8283810569556
# latitude -9.26675929482938
# latitude -8.70513753045879
# latitude -8.14351576398856
# latitude -7.58189399556175
# latitude -7.02027222531985
# latitude -6.45865045340296
# latitude -5.89702867994979
# latitude -5.33540690509796
# latitude -4.77378512898387
# latitude -4.21216335174302
# latitude -3.65054157350999
# latitude -3.08891979441865
# latitude -2.52729801460213
# latitude -1.96567623419308
# latitude -1.40405445332361
# latitude -0.842432672125539
# latitude -0.280810890730407
# latitude 0.280810890730407
# latitude 0.842432672125539
# latitude 1.40405445332361
# latitude 1.96567623419308
# latitude 2.52729801460213
# latitude 3.08891979441865
# latitude 3.65054157350999
# latitude 4.21216335174302
# latitude 4.77378512898387
# latitude 5.33540690509796
# latitude 5.89702867994979
# latitude 6.45865045340296
# latitude 7.02027222531985
# latitude 7.58189399556175
# latitude 8.14351576398856
# latitude 8.70513753045879
# latitude 9.26675929482938
# latitude 9.8283810569556
# latitude 10.3900028166909
# latitude 10.9516245738869
# latitude 11.5132463283931
# latitude 12.0748680800568
# latitude 12.6364898287229
# latitude 13.1981115742342
# latitude 13.7597333164304
# latitude 14.3213550551487
# latitude 14.8829767902235
# latitude 15.4445985214858
# latitude 16.0062202487636
# latitude 16.5678419718816
# latitude 17.1294636906605
# latitude 17.6910854049175
# latitude 18.2527071144658
# latitude 18.8143288191145
# latitude 19.3759505186682
# latitude 19.9375722129269
# <xarray.DataArray 'tas_10m' (latitude: 161, longitude: 161)>
# array([[3.882775e-05, 2.734845e-05, 2.535306e-05, ..., 8.906109e-03,
#         8.560908e-03, 8.045889e-03],
#        [3.366324e-05, 2.718412e-05, 3.037673e-05, ..., 8.464942e-03,
#         8.078332e-03, 7.509413e-03],
#        [7.068341e-05, 6.751427e-05, 5.911020e-05, ..., 6.988549e-03,
#         6.788588e-03, 6.407612e-03],
#        ...,
#        [1.832165e-02, 1.909750e-02, 1.937955e-02, ..., 2.210672e-02,
#         2.206066e-02, 2.168257e-02],
#        [1.853185e-02, 1.886076e-02, 1.932040e-02, ..., 2.250808e-02,
#         2.240232e-02, 2.215694e-02],
#        [1.798321e-02, 1.853588e-02, 1.864373e-02, ..., 2.287994e-02,
#         2.245899e-02, 2.217163e-02]])
# Coordinates:
#   * latitude   (latitude) float64 -69.92 -69.36 -68.8 ... 18.81 19.38 19.94
#   * longitude  (longitude) float64 90.0 90.56 91.12 91.69 ... 178.9 179.4 180.0
# lat_coarse -70.0
# lat_coarse -69.75
# lat_coarse -69.5
# lat_coarse -69.25
# lat_coarse -69.0
# lat_coarse -68.75
# lat_coarse -68.5
# lat_coarse -68.25
# lat_coarse -68.0
# lat_coarse -67.75
# lat_coarse -67.5
# lat_coarse -67.25
# lat_coarse -67.0
# lat_coarse -66.75
# lat_coarse -66.5
# lat_coarse -66.25
# lat_coarse -66.0
# lat_coarse -65.75
# lat_coarse -65.5
# lat_coarse -65.25
# lat_coarse -65.0
# lat_coarse -64.75
# lat_coarse -64.5
# lat_coarse -64.25
# lat_coarse -64.0
# lat_coarse -63.75
# lat_coarse -63.5
# lat_coarse -63.25
# lat_coarse -63.0
# lat_coarse -62.75
# lat_coarse -62.5
# lat_coarse -62.25
# lat_coarse -62.0
# lat_coarse -61.75
# lat_coarse -61.5
# lat_coarse -61.25
# lat_coarse -61.0
# lat_coarse -60.75
# lat_coarse -60.5
# lat_coarse -60.25
# lat_coarse -60.0
# lat_coarse -59.75
# lat_coarse -59.5
# lat_coarse -59.25
# lat_coarse -59.0
# lat_coarse -58.75
# lat_coarse -58.5
# lat_coarse -58.25
# lat_coarse -58.0
# lat_coarse -57.75
# lat_coarse -57.5
# lat_coarse -57.25
# lat_coarse -57.0
# lat_coarse -56.75
# lat_coarse -56.5
# lat_coarse -56.25
# lat_coarse -56.0
# lat_coarse -55.75
# lat_coarse -55.5
# lat_coarse -55.25
# lat_coarse -55.0
# lat_coarse -54.75
# lat_coarse -54.5
# lat_coarse -54.25
# lat_coarse -54.0
# lat_coarse -53.75
# lat_coarse -53.5
# lat_coarse -53.25
# lat_coarse -53.0
# lat_coarse -52.75
# lat_coarse -52.5
# lat_coarse -52.25
# lat_coarse -52.0
# lat_coarse -51.75
# lat_coarse -51.5
# lat_coarse -51.25
# lat_coarse -51.0
# lat_coarse -50.75
# lat_coarse -50.5
# lat_coarse -50.25
# lat_coarse -50.0
# lat_coarse -49.75
# lat_coarse -49.5
# lat_coarse -49.25
# lat_coarse -49.0
# lat_coarse -48.75
# lat_coarse -48.5
# lat_coarse -48.25
# lat_coarse -48.0
# lat_coarse -47.75
# lat_coarse -47.5
# lat_coarse -47.25
# lat_coarse -47.0
# lat_coarse -46.75
# lat_coarse -46.5
# lat_coarse -46.25
# lat_coarse -46.0
# lat_coarse -45.75
# lat_coarse -45.5
# lat_coarse -45.25
# lat_coarse -45.0
# lat_coarse -44.75
# lat_coarse -44.5
# lat_coarse -44.25
# lat_coarse -44.0
# lat_coarse -43.75
# lat_coarse -43.5
# lat_coarse -43.25
# lat_coarse -43.0
# lat_coarse -42.75
# lat_coarse -42.5
# lat_coarse -42.25
# lat_coarse -42.0
# lat_coarse -41.75
# lat_coarse -41.5
# lat_coarse -41.25
# lat_coarse -41.0
# lat_coarse -40.75
# lat_coarse -40.5
# lat_coarse -40.25
# lat_coarse -40.0
# lat_coarse -39.75
# lat_coarse -39.5
# lat_coarse -39.25
# lat_coarse -39.0
# lat_coarse -38.75
# lat_coarse -38.5
# lat_coarse -38.25
# lat_coarse -38.0
# lat_coarse -37.75
# lat_coarse -37.5
# lat_coarse -37.25
# lat_coarse -37.0
# lat_coarse -36.75
# lat_coarse -36.5
# lat_coarse -36.25
# lat_coarse -36.0
# lat_coarse -35.75
# lat_coarse -35.5
# lat_coarse -35.25
# lat_coarse -35.0
# lat_coarse -34.75
# lat_coarse -34.5
# lat_coarse -34.25
# lat_coarse -34.0
# lat_coarse -33.75
# lat_coarse -33.5
# lat_coarse -33.25
# lat_coarse -33.0
# lat_coarse -32.75
# lat_coarse -32.5
# lat_coarse -32.25
# lat_coarse -32.0
# lat_coarse -31.75
# lat_coarse -31.5
# lat_coarse -31.25
# lat_coarse -31.0
# lat_coarse -30.75
# lat_coarse -30.5
# lat_coarse -30.25
# lat_coarse -30.0
# lat_coarse -29.75
# lat_coarse -29.5
# lat_coarse -29.25
# lat_coarse -29.0
# lat_coarse -28.75
# lat_coarse -28.5
# lat_coarse -28.25
# lat_coarse -28.0
# lat_coarse -27.75
# lat_coarse -27.5
# lat_coarse -27.25
# lat_coarse -27.0
# lat_coarse -26.75
# lat_coarse -26.5
# lat_coarse -26.25
# lat_coarse -26.0
# lat_coarse -25.75
# lat_coarse -25.5
# lat_coarse -25.25
# lat_coarse -25.0
# lat_coarse -24.75
# lat_coarse -24.5
# lat_coarse -24.25
# lat_coarse -24.0
# lat_coarse -23.75
# lat_coarse -23.5
# lat_coarse -23.25
# lat_coarse -23.0
# lat_coarse -22.75
# lat_coarse -22.5
# lat_coarse -22.25
# lat_coarse -22.0
# lat_coarse -21.75
# lat_coarse -21.5
# lat_coarse -21.25
# lat_coarse -21.0
# lat_coarse -20.75
# lat_coarse -20.5
# lat_coarse -20.25
# lat_coarse -20.0
# lat_coarse -19.75
# lat_coarse -19.5
# lat_coarse -19.25
# lat_coarse -19.0
# lat_coarse -18.75
# lat_coarse -18.5
# lat_coarse -18.25
# lat_coarse -18.0
# lat_coarse -17.75
# lat_coarse -17.5
# lat_coarse -17.25
# lat_coarse -17.0
# lat_coarse -16.75
# lat_coarse -16.5
# lat_coarse -16.25
# lat_coarse -16.0
# lat_coarse -15.75
# lat_coarse -15.5
# lat_coarse -15.25
# lat_coarse -15.0
# lat_coarse -14.75
# lat_coarse -14.5
# lat_coarse -14.25
# lat_coarse -14.0
# lat_coarse -13.75
# lat_coarse -13.5
# lat_coarse -13.25
# lat_coarse -13.0
# lat_coarse -12.75
# lat_coarse -12.5
# lat_coarse -12.25
# lat_coarse -12.0
# lat_coarse -11.75
# lat_coarse -11.5
# lat_coarse -11.25
# lat_coarse -11.0
# lat_coarse -10.75
# lat_coarse -10.5
# lat_coarse -10.25
# lat_coarse -10.0
# lat_coarse -9.75
# lat_coarse -9.5
# lat_coarse -9.25
# lat_coarse -9.0
# lat_coarse -8.75
# lat_coarse -8.5
# lat_coarse -8.25
# lat_coarse -8.0
# lat_coarse -7.75
# lat_coarse -7.5
# lat_coarse -7.25
# lat_coarse -7.0
# lat_coarse -6.75
# lat_coarse -6.5
# lat_coarse -6.25
# lat_coarse -6.0
# lat_coarse -5.75
# lat_coarse -5.5
# lat_coarse -5.25
# lat_coarse -5.0
# lat_coarse -4.75
# lat_coarse -4.5
# lat_coarse -4.25
# lat_coarse -4.0
# lat_coarse -3.75
# lat_coarse -3.5
# lat_coarse -3.25
# lat_coarse -3.0
# lat_coarse -2.75
# lat_coarse -2.5
# lat_coarse -2.25
# lat_coarse -2.0
# lat_coarse -1.75
# lat_coarse -1.5
# lat_coarse -1.25
# lat_coarse -1.0
# lat_coarse -0.75
# lat_coarse -0.5
# lat_coarse -0.25
# lat_coarse 0.0
# lat_coarse 0.25
# lat_coarse 0.5
# lat_coarse 0.75
# lat_coarse 1.0
# lat_coarse 1.25
# lat_coarse 1.5
# lat_coarse 1.75
# lat_coarse 2.0
# lat_coarse 2.25
# lat_coarse 2.5
# lat_coarse 2.75
# lat_coarse 3.0
# lat_coarse 3.25
# lat_coarse 3.5
# lat_coarse 3.75
# lat_coarse 4.0
# lat_coarse 4.25
# lat_coarse 4.5
# lat_coarse 4.75
# lat_coarse 5.0
# lat_coarse 5.25
# lat_coarse 5.5
# lat_coarse 5.75
# lat_coarse 6.0
# lat_coarse 6.25
# lat_coarse 6.5
# lat_coarse 6.75
# lat_coarse 7.0
# lat_coarse 7.25
# lat_coarse 7.5
# lat_coarse 7.75
# lat_coarse 8.0
# lat_coarse 8.25
# lat_coarse 8.5
# lat_coarse 8.75
# lat_coarse 9.0
# lat_coarse 9.25
# lat_coarse 9.5
# lat_coarse 9.75
# lat_coarse 10.0
# lat_coarse 10.25
# lat_coarse 10.5
# lat_coarse 10.75
# lat_coarse 11.0
# lat_coarse 11.25
# lat_coarse 11.5
# lat_coarse 11.75
# lat_coarse 12.0
# lat_coarse 12.25
# lat_coarse 12.5
# lat_coarse 12.75
# lat_coarse 13.0
# lat_coarse 13.25
# lat_coarse 13.5
# lat_coarse 13.75
# lat_coarse 14.0
# lat_coarse 14.25
# lat_coarse 14.5
# lat_coarse 14.75
# lat_coarse 15.0
# lat_coarse 15.25
# lat_coarse 15.5
# lat_coarse 15.75
# lat_coarse 16.0
# lat_coarse 16.25
# lat_coarse 16.5
# lat_coarse 16.75
# lat_coarse 17.0
# lat_coarse 17.25
# lat_coarse 17.5
# lat_coarse 17.75
# lat_coarse 18.0
# lat_coarse 18.25
# lat_coarse 18.5
# lat_coarse 18.75
# lat_coarse 19.0
# lat_coarse 19.25
# lat_coarse 19.5
# lat_coarse 19.75
# lat_coarse 20.0
# <xarray.DataArray 'mld' (yt_ocean: 361, xt_ocean: 361)>
# array([[      nan,       nan,       nan, ..., -0.194413, -0.169992, -0.129209],
#        [      nan,       nan,       nan, ..., -0.200773, -0.183882, -0.157764],
#        [      nan,       nan,       nan, ..., -0.285866, -0.230529, -0.146866],
#        ...,
#        [-0.062341, -0.060679, -0.02874 , ...,  0.029389,  0.065263,  0.062352],
#        [-0.035031, -0.015482, -0.012586, ...,  0.086464,  0.060302,  0.055384],
#        [ 0.027148,  0.012875,  0.008342, ...,  0.113592,  0.127476,  0.114955]])
# Coordinates:
#   * yt_ocean  (yt_ocean) float64 -70.0 -69.75 -69.5 -69.25 ... 19.5 19.75 20.0
#   * xt_ocean  (xt_ocean) float64 -270.0 -269.8 -269.5 ... -180.5 -180.2 -180.0
# latitude -69.9218061359604
# latitude -69.3601893179717
# latitude -68.7985722135654
# latitude -68.2369548449477
# latitude -67.6753372320917
# latitude -67.1137193930113
# latitude -66.5521013439961
# latitude -65.9904830998127
# latitude -65.4288646738789
# latitude -64.8672460784143
# latitude -64.3056273245713
# latitude -63.7440084225492
# latitude -63.1823893816941
# latitude -62.6207702105861
# latitude -62.0591509171167
# latitude -61.4975315085564
# latitude -60.9359119916146
# latitude -60.374292372493
# latitude -59.8126726569327
# latitude -59.2510528502565
# latitude -58.6894329574061
# latitude -58.1278129829758
# latitude -57.5661929312427
# latitude -57.0045728061936
# latitude -56.4429526115493
# latitude -55.8813323507866
# latitude -55.3197120271579
# latitude -54.7580916437092
# latitude -54.1964712032965
# latitude -53.6348507085999
# latitude -53.0732301621377
# latitude -52.5116095662779
# latitude -51.9499889232498
# latitude -51.3883682351539
# latitude -50.826747503971
# latitude -50.2651267315709
# latitude -49.70350591972
# latitude -49.1418850700887
# latitude -48.5802641842574
# latitude -48.018643263723
# latitude -47.4570223099043
# latitude -46.895401324147
# latitude -46.3337803077285
# latitude -45.7721592618623
# latitude -45.2105381877018
# latitude -44.6489170863444
# latitude -44.0872959588346
# latitude -43.5256748061674
# latitude -42.9640536292911
# latitude -42.4024324291106
# latitude -41.840811206489
# latitude -41.2791899622508
# latitude -40.7175686971841
# latitude -40.1559474120422
# latitude -39.5943261075457
# latitude -39.0327047843849
# latitude -38.4710834432205
# latitude -37.909462084686
# latitude -37.3478407093888
# latitude -36.7862193179117
# latitude -36.2245979108143
# latitude -35.6629764886338
# latitude -35.1013550518869
# latitude -34.53973360107
# latitude -33.9781121366611
# latitude -33.4164906591199
# latitude -32.8548691688896
# latitude -32.2932476663967
# latitude -31.7316261520529
# latitude -31.170004626255
# latitude -30.6083830893861
# latitude -30.046761541816
# latitude -29.4851399839021
# latitude -28.9235184159896
# latitude -28.3618968384127
# latitude -27.8002752514945
# latitude -27.2386536555477
# latitude -26.6770320508754
# latitude -26.1154104377713
# latitude -25.55378881652
# latitude -24.9921671873976
# latitude -24.4305455506723
# latitude -23.8689239066043
# latitude -23.3073022554465
# latitude -22.7456805974447
# latitude -22.184058932838
# latitude -21.6224372618593
# latitude -21.0608155847349
# latitude -20.4991939016857
# latitude -19.9375722129269
# latitude -19.3759505186682
# latitude -18.8143288191145
# latitude -18.2527071144658
# latitude -17.6910854049175
# latitude -17.1294636906605
# latitude -16.5678419718816
# latitude -16.0062202487636
# latitude -15.4445985214858
# latitude -14.8829767902235
# latitude -14.3213550551487
# latitude -13.7597333164304
# latitude -13.1981115742342
# latitude -12.6364898287229
# latitude -12.0748680800568
# latitude -11.5132463283931
# latitude -10.9516245738869
# latitude -10.3900028166909
# latitude -9.8283810569556
# latitude -9.26675929482938
# latitude -8.70513753045879
# latitude -8.14351576398856
# latitude -7.58189399556175
# latitude -7.02027222531985
# latitude -6.45865045340296
# latitude -5.89702867994979
# latitude -5.33540690509796
# latitude -4.77378512898387
# latitude -4.21216335174302
# latitude -3.65054157350999
# latitude -3.08891979441865
# latitude -2.52729801460213
# latitude -1.96567623419308
# latitude -1.40405445332361
# latitude -0.842432672125539
# latitude -0.280810890730407
# latitude 0.280810890730407
# latitude 0.842432672125539
# latitude 1.40405445332361
# latitude 1.96567623419308
# latitude 2.52729801460213
# latitude 3.08891979441865
# latitude 3.65054157350999
# latitude 4.21216335174302
# latitude 4.77378512898387
# latitude 5.33540690509796
# latitude 5.89702867994979
# latitude 6.45865045340296
# latitude 7.02027222531985
# latitude 7.58189399556175
# latitude 8.14351576398856
# latitude 8.70513753045879
# latitude 9.26675929482938
# latitude 9.8283810569556
# latitude 10.3900028166909
# latitude 10.9516245738869
# latitude 11.5132463283931
# latitude 12.0748680800568
# latitude 12.6364898287229
# latitude 13.1981115742342
# latitude 13.7597333164304
# latitude 14.3213550551487
# latitude 14.8829767902235
# latitude 15.4445985214858
# latitude 16.0062202487636
# latitude 16.5678419718816
# latitude 17.1294636906605
# latitude 17.6910854049175
# latitude 18.2527071144658
# latitude 18.8143288191145
# latitude 19.3759505186682
# latitude 19.9375722129269
# <xarray.DataArray 'pls' (latitude: 161, longitude: 161)>
# array([[ 3.332620e+00,  3.311202e+00,  3.284423e+00, ...,  1.033750e+00,
#          1.192049e+00,  1.349351e+00],
#        [ 3.218353e+00,  3.167837e+00,  3.115294e+00, ...,  1.179681e+00,
#          1.332728e+00,  1.485493e+00],
#        [ 3.137085e+00,  3.092374e+00,  3.040661e+00, ...,  1.306118e+00,
#          1.451496e+00,  1.594663e+00],
#        ...,
#        [-1.287794e+00, -1.281340e+00, -1.256466e+00, ..., -1.589543e-02,
#          2.878606e-03,  2.610577e-02],
#        [-1.262218e+00, -1.255980e+00, -1.243011e+00, ...,  2.781851e-02,
#          5.068510e-02,  7.327524e-02],
#        [-1.214736e+00, -1.217981e+00, -1.209123e+00, ...,  7.959736e-02,
#          1.061478e-01,  1.308474e-01]])
# Coordinates:
#   * latitude   (latitude) float64 -69.92 -69.36 -68.8 ... 18.81 19.38 19.94
#   * longitude  (longitude) float64 90.0 90.56 91.12 91.69 ... 178.9 179.4 180.0
# latitude -69.9218061359604
# latitude -69.3601893179717
# latitude -68.7985722135654
# latitude -68.2369548449477
# latitude -67.6753372320917
# latitude -67.1137193930113
# latitude -66.5521013439961
# latitude -65.9904830998127
# latitude -65.4288646738789
# latitude -64.8672460784143
# latitude -64.3056273245713
# latitude -63.7440084225492
# latitude -63.1823893816941
# latitude -62.6207702105861
# latitude -62.0591509171167
# latitude -61.4975315085564
# latitude -60.9359119916146
# latitude -60.374292372493
# latitude -59.8126726569327
# latitude -59.2510528502565
# latitude -58.6894329574061
# latitude -58.1278129829758
# latitude -57.5661929312427
# latitude -57.0045728061936
# latitude -56.4429526115493
# latitude -55.8813323507866
# latitude -55.3197120271579
# latitude -54.7580916437092
# latitude -54.1964712032965
# latitude -53.6348507085999
# latitude -53.0732301621377
# latitude -52.5116095662779
# latitude -51.9499889232498
# latitude -51.3883682351539
# latitude -50.826747503971
# latitude -50.2651267315709
# latitude -49.70350591972
# latitude -49.1418850700887
# latitude -48.5802641842574
# latitude -48.018643263723
# latitude -47.4570223099043
# latitude -46.895401324147
# latitude -46.3337803077285
# latitude -45.7721592618623
# latitude -45.2105381877018
# latitude -44.6489170863444
# latitude -44.0872959588346
# latitude -43.5256748061674
# latitude -42.9640536292911
# latitude -42.4024324291106
# latitude -41.840811206489
# latitude -41.2791899622508
# latitude -40.7175686971841
# latitude -40.1559474120422
# latitude -39.5943261075457
# latitude -39.0327047843849
# latitude -38.4710834432205
# latitude -37.909462084686
# latitude -37.3478407093888
# latitude -36.7862193179117
# latitude -36.2245979108143
# latitude -35.6629764886338
# latitude -35.1013550518869
# latitude -34.53973360107
# latitude -33.9781121366611
# latitude -33.4164906591199
# latitude -32.8548691688896
# latitude -32.2932476663967
# latitude -31.7316261520529
# latitude -31.170004626255
# latitude -30.6083830893861
# latitude -30.046761541816
# latitude -29.4851399839021
# latitude -28.9235184159896
# latitude -28.3618968384127
# latitude -27.8002752514945
# latitude -27.2386536555477
# latitude -26.6770320508754
# latitude -26.1154104377713
# latitude -25.55378881652
# latitude -24.9921671873976
# latitude -24.4305455506723
# latitude -23.8689239066043
# latitude -23.3073022554465
# latitude -22.7456805974447
# latitude -22.184058932838
# latitude -21.6224372618593
# latitude -21.0608155847349
# latitude -20.4991939016857
# latitude -19.9375722129269
# latitude -19.3759505186682
# latitude -18.8143288191145
# latitude -18.2527071144658
# latitude -17.6910854049175
# latitude -17.1294636906605
# latitude -16.5678419718816
# latitude -16.0062202487636
# latitude -15.4445985214858
# latitude -14.8829767902235
# latitude -14.3213550551487
# latitude -13.7597333164304
# latitude -13.1981115742342
# latitude -12.6364898287229
# latitude -12.0748680800568
# latitude -11.5132463283931
# latitude -10.9516245738869
# latitude -10.3900028166909
# latitude -9.8283810569556
# latitude -9.26675929482938
# latitude -8.70513753045879
# latitude -8.14351576398856
# latitude -7.58189399556175
# latitude -7.02027222531985
# latitude -6.45865045340296
# latitude -5.89702867994979
# latitude -5.33540690509796
# latitude -4.77378512898387
# latitude -4.21216335174302
# latitude -3.65054157350999
# latitude -3.08891979441865
# latitude -2.52729801460213
# latitude -1.96567623419308
# latitude -1.40405445332361
# latitude -0.842432672125539
# latitude -0.280810890730407
# latitude 0.280810890730407
# latitude 0.842432672125539
# latitude 1.40405445332361
# latitude 1.96567623419308
# latitude 2.52729801460213
# latitude 3.08891979441865
# latitude 3.65054157350999
# latitude 4.21216335174302
# latitude 4.77378512898387
# latitude 5.33540690509796
# latitude 5.89702867994979
# latitude 6.45865045340296
# latitude 7.02027222531985
# latitude 7.58189399556175
# latitude 8.14351576398856
# latitude 8.70513753045879
# latitude 9.26675929482938
# latitude 9.8283810569556
# latitude 10.3900028166909
# latitude 10.9516245738869
# latitude 11.5132463283931
# latitude 12.0748680800568
# latitude 12.6364898287229
# latitude 13.1981115742342
# latitude 13.7597333164304
# latitude 14.3213550551487
# latitude 14.8829767902235
# latitude 15.4445985214858
# latitude 16.0062202487636
# latitude 16.5678419718816
# latitude 17.1294636906605
# latitude 17.6910854049175
# latitude 18.2527071144658
# latitude 18.8143288191145
# latitude 19.3759505186682
# latitude 19.9375722129269
# <xarray.DataArray 'uas_10m' (latitude: 161, longitude: 161)>
# array([[-0.00659 , -0.006055, -0.005507, ..., -0.00467 , -0.004643, -0.004611],
#        [-0.005126, -0.005053, -0.004963, ..., -0.002005, -0.002536, -0.003094],
#        [-0.003212, -0.003324, -0.003481, ..., -0.002507, -0.00332 , -0.004158],
#        ...,
#        [-0.005076, -0.005989, -0.007176, ..., -0.011038, -0.011797, -0.012412],
#        [-0.006841, -0.007638, -0.008801, ..., -0.01155 , -0.011833, -0.012105],
#        [-0.009118, -0.009788, -0.011145, ..., -0.012201, -0.012199, -0.012214]])
# Coordinates:
#   * latitude   (latitude) float64 -69.92 -69.36 -68.8 ... 18.81 19.38 19.94
#   * longitude  (longitude) float64 90.0 90.56 91.12 91.69 ... 178.9 179.4 180.0
# latitude -69.9218061359604
# latitude -69.3601893179717
# latitude -68.7985722135654
# latitude -68.2369548449477
# latitude -67.6753372320917
# latitude -67.1137193930113
# latitude -66.5521013439961
# latitude -65.9904830998127
# latitude -65.4288646738789
# latitude -64.8672460784143
# latitude -64.3056273245713
# latitude -63.7440084225492
# latitude -63.1823893816941
# latitude -62.6207702105861
# latitude -62.0591509171167
# latitude -61.4975315085564
# latitude -60.9359119916146
# latitude -60.374292372493
# latitude -59.8126726569327
# latitude -59.2510528502565
# latitude -58.6894329574061
# latitude -58.1278129829758
# latitude -57.5661929312427
# latitude -57.0045728061936
# latitude -56.4429526115493
# latitude -55.8813323507866
# latitude -55.3197120271579
# latitude -54.7580916437092
# latitude -54.1964712032965
# latitude -53.6348507085999
# latitude -53.0732301621377
# latitude -52.5116095662779
# latitude -51.9499889232498
# latitude -51.3883682351539
# latitude -50.826747503971
# latitude -50.2651267315709
# latitude -49.70350591972
# latitude -49.1418850700887
# latitude -48.5802641842574
# latitude -48.018643263723
# latitude -47.4570223099043
# latitude -46.895401324147
# latitude -46.3337803077285
# latitude -45.7721592618623
# latitude -45.2105381877018
# latitude -44.6489170863444
# latitude -44.0872959588346
# latitude -43.5256748061674
# latitude -42.9640536292911
# latitude -42.4024324291106
# latitude -41.840811206489
# latitude -41.2791899622508
# latitude -40.7175686971841
# latitude -40.1559474120422
# latitude -39.5943261075457
# latitude -39.0327047843849
# latitude -38.4710834432205
# latitude -37.909462084686
# latitude -37.3478407093888
# latitude -36.7862193179117
# latitude -36.2245979108143
# latitude -35.6629764886338
# latitude -35.1013550518869
# latitude -34.53973360107
# latitude -33.9781121366611
# latitude -33.4164906591199
# latitude -32.8548691688896
# latitude -32.2932476663967
# latitude -31.7316261520529
# latitude -31.170004626255
# latitude -30.6083830893861
# latitude -30.046761541816
# latitude -29.4851399839021
# latitude -28.9235184159896
# latitude -28.3618968384127
# latitude -27.8002752514945
# latitude -27.2386536555477
# latitude -26.6770320508754
# latitude -26.1154104377713
# latitude -25.55378881652
# latitude -24.9921671873976
# latitude -24.4305455506723
# latitude -23.8689239066043
# latitude -23.3073022554465
# latitude -22.7456805974447
# latitude -22.184058932838
# latitude -21.6224372618593
# latitude -21.0608155847349
# latitude -20.4991939016857
# latitude -19.9375722129269
# latitude -19.3759505186682
# latitude -18.8143288191145
# latitude -18.2527071144658
# latitude -17.6910854049175
# latitude -17.1294636906605
# latitude -16.5678419718816
# latitude -16.0062202487636
# latitude -15.4445985214858
# latitude -14.8829767902235
# latitude -14.3213550551487
# latitude -13.7597333164304
# latitude -13.1981115742342
# latitude -12.6364898287229
# latitude -12.0748680800568
# latitude -11.5132463283931
# latitude -10.9516245738869
# latitude -10.3900028166909
# latitude -9.8283810569556
# latitude -9.26675929482938
# latitude -8.70513753045879
# latitude -8.14351576398856
# latitude -7.58189399556175
# latitude -7.02027222531985
# latitude -6.45865045340296
# latitude -5.89702867994979
# latitude -5.33540690509796
# latitude -4.77378512898387
# latitude -4.21216335174302
# latitude -3.65054157350999
# latitude -3.08891979441865
# latitude -2.52729801460213
# latitude -1.96567623419308
# latitude -1.40405445332361
# latitude -0.842432672125539
# latitude -0.280810890730407
# latitude 0.280810890730407
# latitude 0.842432672125539
# latitude 1.40405445332361
# latitude 1.96567623419308
# latitude 2.52729801460213
# latitude 3.08891979441865
# latitude 3.65054157350999
# latitude 4.21216335174302
# latitude 4.77378512898387
# latitude 5.33540690509796
# latitude 5.89702867994979
# latitude 6.45865045340296
# latitude 7.02027222531985
# latitude 7.58189399556175
# latitude 8.14351576398856
# latitude 8.70513753045879
# latitude 9.26675929482938
# latitude 9.8283810569556
# latitude 10.3900028166909
# latitude 10.9516245738869
# latitude 11.5132463283931
# latitude 12.0748680800568
# latitude 12.6364898287229
# latitude 13.1981115742342
# latitude 13.7597333164304
# latitude 14.3213550551487
# latitude 14.8829767902235
# latitude 15.4445985214858
# latitude 16.0062202487636
# latitude 16.5678419718816
# latitude 17.1294636906605
# latitude 17.6910854049175
# latitude 18.2527071144658
# latitude 18.8143288191145
# latitude 19.3759505186682
# latitude 19.9375722129269
# <xarray.DataArray 'vas_10m' (latitude: 161, longitude: 161)>
# array([[ 5.230784e-03,  6.322058e-03,  7.383058e-03, ..., -3.111588e-02,
#         -3.045018e-02, -2.980279e-02],
#        [ 4.900563e-03,  6.037096e-03,  7.146289e-03, ..., -2.892713e-02,
#         -2.824033e-02, -2.757177e-02],
#        [ 4.441716e-03,  5.551187e-03,  6.612039e-03, ..., -2.523972e-02,
#         -2.463535e-02, -2.402023e-02],
#        ...,
#        [ 1.479751e-04,  2.816801e-03,  6.414565e-03, ...,  3.376868e-03,
#          3.756459e-03,  4.051445e-03],
#        [-9.086271e-04,  1.852267e-03,  5.405803e-03, ...,  2.185606e-03,
#          2.825742e-03,  3.635591e-03],
#        [-2.582135e-03, -5.940598e-05,  3.368894e-03, ...,  1.148074e-03,
#          1.620509e-03,  2.570394e-03]])
# Coordinates:
#   * latitude   (latitude) float64 -69.92 -69.36 -68.8 ... 18.81 19.38 19.94
#   * longitude  (longitude) float64 90.0 90.56 91.12 91.69 ... 178.9 179.4 180.0
# CPU times: user 16min 45s, sys: 1min 38s, total: 18min 24s
# Wall time: 16min 23s

# %%
NOSYNC = 'NOSYNC/' # where to save figs we don't want to sync
if not os.path.exists(NOSYNC):
    os.makedirs(NOSYNC)
def savefigure(fname):
    plt.savefig(os.path.join(fig_dir, fig_name[0:4]+fname+'.png'),dpi=150, bbox_inches="tight")  # comment out to disable saving
    #plt.savefig(os.path.join(figdir, fname+'.pdf'),dpi=300, bbox_inches="tight")  # comment out to disable saving
    return   


# General plotting stuff
plot_labels=['(a) ','(b) ','(c) ','(d)']
land_50m= cft.NaturalEarthFeature('physical', 'land', '110m',
                                    edgecolor='black',
                                    facecolor='',
                                    linewidth=1)
fig = plt.figure() 
fig.set_size_inches(18,12)
matplotlib.rcParams.update({'font.size': 12}) 
col = 4
row = 2

for y_num in years:
    y = str(y_num)

    fig.suptitle(r'ACCESS-OM2-01 $\bf{' + y + '}$ $-$ long-term mean', 
                 x=0.54, y=0.93)

    ax = plt.subplot2grid((row, col), (0, 0), rowspan=1, colspan=1, 
                          projection=ccrs.PlateCarree(central_longitude=0))
    cmap = plt.get_cmap('RdBu_r')
    levels = arange(-1,1,0.2)
    ax.add_feature(land_50m)
    ax.set_extent([lonW+360, lonE+360, latS, latN], crs=ccrs.PlateCarree())
    p = t_10_anom.sel(
        year=y_num).plot(add_colorbar=True, cmap=cmap, levels=levels, extend='both', 
                                cbar_kwargs={'orientation':'horizontal'})
    plt.title('Surface air temperature ($^{\circ}C$)')
    ax.gridlines(draw_labels=False, linewidth=0.5, linestyle='-')
    
    ax = plt.subplot2grid((row, col), (1, 0), rowspan=1, colspan=1, 
                          projection=ccrs.PlateCarree(central_longitude=0))
    cmap = plt.get_cmap('RdBu_r')
    levels = arange(-150,150,25)
    ax.add_feature(land_50m)
    ax.set_extent([lonW+360, lonE+360, latS, latN], crs=ccrs.PlateCarree())
    p = slp_anom.sel(
        year=y_num).plot(add_colorbar=True, cmap=cmap, levels=levels, extend='both', 
                                cbar_kwargs={'orientation':'horizontal'})
    plt.title('Sea level pressure ($Pa$)')
    ax.gridlines(draw_labels=False, linewidth=0.5, linestyle='-')
    
    ax = plt.subplot2grid((row, col), (1, 1), rowspan=1, colspan=1, 
                          projection=ccrs.PlateCarree(central_longitude=0))
    cmap = plt.get_cmap('rainbow')
    levels = arange(0,2,0.2)
    ax.add_feature(land_50m)
    ax.set_extent([lonW+360, lonE+360, latS, latN], crs=ccrs.PlateCarree())
    p = speed_anom.sel(
        year=y_num).plot(add_colorbar=True, cmap=cmap, levels=levels, extend='both', 
                                cbar_kwargs={'orientation':'horizontal'})
    n = 6
    plt.quiver(u_10_anom_norm.longitude[0:161:n], 
               u_10_anom_norm.latitude[0:161:n], 
               u_10_anom_norm.sel(year=y_num)[0:161:n,0:161:n], 
               v_10_anom_norm.sel(year=y_num)[0:161:n,0:161:n],
               width=0.005, scale=25)
    plt.title('10 $m$ winds ($m\ s^{-1}$)')
    ax.gridlines(draw_labels=False, linewidth=0.5, linestyle='-')
    
    ax = plt.subplot2grid((row, col), (0, 1), rowspan=1, colspan=1, 
                          projection=ccrs.PlateCarree(central_longitude=0))
    cmap = plt.get_cmap('RdBu_r')
    levels = arange(-1,1,0.2)
    ax.add_feature(land_50m)
    ax.set_extent([lonW+360, lonE+360, latS, latN], crs=ccrs.PlateCarree())
    p = temp_anom.sel(
        year=y_num).plot(add_colorbar=True, cmap=cmap, levels=levels, extend='both', 
                                cbar_kwargs={'orientation':'horizontal'})
    plt.title('Sea surface temperature ($^{\circ}C$)')
    ax.gridlines(draw_labels=False, linewidth=0.5, linestyle='-')
    
    ax = plt.subplot2grid((row, col), (0, 2), rowspan=1, colspan=1, 
                          projection=ccrs.PlateCarree(central_longitude=0))
    cmap = plt.get_cmap('RdBu_r')
    levels = arange(-50,50,10)
    ax.add_feature(land_50m)
    ax.set_extent([lonW+360, lonE+360, latS, latN], crs=ccrs.PlateCarree())
    p = net_sfc_heating_anom.sel(
        year=y_num).plot(add_colorbar=True, cmap=cmap, levels=levels, extend='both', 
                                cbar_kwargs={'orientation':'horizontal'})
    plt.title('Net surface heating ($W\ m^{-2}$)')
    ax.gridlines(draw_labels=False, linewidth=0.5, linestyle='-')
    
    ax = plt.subplot2grid((row, col), (1, 2), rowspan=1, colspan=1, 
                          projection=ccrs.PlateCarree(central_longitude=0))
    cmap = plt.get_cmap('RdBu_r')
    levels = arange(-50,50,10)
    ax.add_feature(land_50m)
    ax.set_extent([lonW+360, lonE+360, latS, latN], crs=ccrs.PlateCarree())
    p = mld_anom.sel(
        year=y_num).plot(add_colorbar=True, cmap=cmap, levels=levels, extend='both', 
                                cbar_kwargs={'orientation':'horizontal'})
    plt.title('Mixed layer depth ($m$)')
    ax.gridlines(draw_labels=False, linewidth=0.5, linestyle='-')
    
    ax = plt.subplot2grid((row, col), (0, 3), rowspan=1, colspan=1, 
                          projection=ccrs.PlateCarree(central_longitude=0))
    cmap = plt.get_cmap('RdBu_r')
    levels = arange(-5,5,1)
    ax.add_feature(land_50m)
    ax.set_extent([lonW+360, lonE+360, latS, latN], crs=ccrs.PlateCarree())
    p = gyre_psi_anom.sel(
        year=y_num).plot(add_colorbar=True, cmap=cmap, levels=levels, extend='both', 
                                cbar_kwargs={'orientation':'horizontal'})
    plt.title('Barotropic streamfunction ($Sv$)')
    ax.gridlines(draw_labels=False, linewidth=0.5, linestyle='-')
    
    ax = plt.subplot2grid((row, col), (1, 3), rowspan=1, colspan=1, 
                          projection=ccrs.PlateCarree(central_longitude=0))
    cmap = plt.get_cmap('RdBu_r')
    levels = arange(-0.1,0.1,0.02)
    ax.add_feature(land_50m)
    ax.set_extent([lonW+360, lonE+360, latS, latN], crs=ccrs.PlateCarree())
    p = eta_t_anom.sel(
        year=y_num).plot(add_colorbar=True, cmap=cmap, levels=levels, extend='both', 
                                cbar_kwargs={'orientation':'horizontal'})
    plt.title('Sea surface height ($m$)')
    ax.gridlines(draw_labels=False, linewidth=0.5, linestyle='-')

    savefigure(y)
    
    print(y + ' OK')
# Out:
# 1993 OK
# 1994 OK
# 1995 OK
# 1996 OK
# 1997 OK
# 1998 OK
# 1999 OK
# 2000 OK
# 2001 OK
# 2002 OK
# 2003 OK
# 2004 OK
# 2005 OK
# 2006 OK
# 2007 OK
# 2008 OK
# 2009 OK
# 2010 OK
# 2011 OK
# 2012 OK
# 2013 OK
# 2014 OK
# 2015 OK
# 2016 OK
# 2017 OK

# %%
gyre_psi_mean.plot(vmax=50)

# %%
NOSYNC = 'NOSYNC/' # where to save figs we don't want to sync
if not os.path.exists(NOSYNC):
    os.makedirs(NOSYNC)
def savefigure(fname):
    plt.savefig(os.path.join(fig_dir, fig_name[0:4]+fname+'.png'),dpi=300, bbox_inches="tight")  # comment out to disable saving
    #plt.savefig(os.path.join(figdir, fname+'.pdf'),dpi=300, bbox_inches="tight")  # comment out to disable saving
    return   


# General plotting stuff
plot_labels=['(a) ','(b) ','(c) ','(d)']
land_50m= cft.NaturalEarthFeature('physical', 'land', '110m',
                                    edgecolor='black',
                                    facecolor='',
                                    linewidth=1)
fig = plt.figure() 
fig.set_size_inches(18,12)
matplotlib.rcParams.update({'font.size': 10}) 
col = 4
row = 2

fig.suptitle(r'ACCESS-OM2-01 1993 to 2017 linear trends', 
             x=0.54, y=0.93)

ax = plt.subplot2grid((row, col), (0, 0), rowspan=1, colspan=1, 
                      projection=ccrs.PlateCarree(central_longitude=0))
cmap = plt.get_cmap('RdBu_r')
levels = arange(-1,1,0.2)
ax.add_feature(land_50m)
ax.set_extent([lonW+360, lonE+360, latS, latN], crs=ccrs.PlateCarree())
t_10_plot = t_10_slopes * 25
p = t_10_plot.plot(add_colorbar=True, cmap=cmap, levels=levels, extend='both', 
                            cbar_kwargs={'orientation':'horizontal'})
plt.title('Surface air temperature ($^{\circ}C\ \cdot\ 25yrs^{-1}$)')
ax.gridlines(draw_labels=False, linewidth=0.5, linestyle='-')


ax = plt.subplot2grid((row, col), (1, 0), rowspan=1, colspan=1, 
                      projection=ccrs.PlateCarree(central_longitude=0))
cmap = plt.get_cmap('RdBu_r')
levels = arange(-100,100,20)
ax.add_feature(land_50m)
ax.set_extent([lonW+360, lonE+360, latS, latN], crs=ccrs.PlateCarree())
slp_plot = slp_slopes * 25
p = slp_plot.plot(add_colorbar=True, cmap=cmap, levels=levels, extend='both', 
                            cbar_kwargs={'orientation':'horizontal'})
plt.title('Sea level pressure ($Pa\ \cdot\ 25yrs^{-1}$)')
ax.gridlines(draw_labels=False, linewidth=0.5, linestyle='-')

ax = plt.subplot2grid((row, col), (1, 1), rowspan=1, colspan=1, 
                      projection=ccrs.PlateCarree(central_longitude=0))
cmap = plt.get_cmap('rainbow')
levels = arange(0,1,0.1)
ax.add_feature(land_50m)
ax.set_extent([lonW+360, lonE+360, latS, latN], crs=ccrs.PlateCarree())
speed_slopes = (u_10_slopes**2 + v_10_slopes**2)**(1/2)
speed_plot = speed_slopes * 25
p = speed_plot.plot(add_colorbar=True, cmap=cmap, levels=levels, extend='max', 
                            cbar_kwargs={'orientation':'horizontal'})
u_10_slopes_norm = u_10_slopes / (u_10_slopes**2 + v_10_slopes**2)**(1/4)
v_10_slopes_norm = v_10_slopes / (u_10_slopes**2 + v_10_slopes**2)**(1/4)
u_10_plot = u_10_slopes * 25
v_10_plot = v_10_slopes * 25
n = 6
plt.quiver(u_10_anom_norm.longitude[0:161:n], 
           u_10_anom_norm.latitude[0:161:n], 
           u_10_plot[0:161:n,0:161:n], 
           v_10_plot[0:161:n,0:161:n],
           width=0.005, scale=25*0.9)
plt.title('10 $m$ winds ($m\ s^{-1}\ \cdot\ 25yrs^{-1}$)')
ax.gridlines(draw_labels=False, linewidth=0.5, linestyle='-')

ax = plt.subplot2grid((row, col), (0, 1), rowspan=1, colspan=1, 
                      projection=ccrs.PlateCarree(central_longitude=0))
cmap = plt.get_cmap('RdBu_r')
levels = arange(-1,1,0.2)
ax.add_feature(land_50m)
ax.set_extent([lonW+360, lonE+360, latS, latN], crs=ccrs.PlateCarree())
temp_plot = temp_slopes * 25
p = temp_plot.plot(add_colorbar=True, cmap=cmap, levels=levels, extend='both', 
                            cbar_kwargs={'orientation':'horizontal'})
plt.title('Sea surface temperature ($^{\circ}C\ \cdot\ 25yrs^{-1}$)')
ax.gridlines(draw_labels=False, linewidth=0.5, linestyle='-')

ax = plt.subplot2grid((row, col), (0, 2), rowspan=1, colspan=1, 
                      projection=ccrs.PlateCarree(central_longitude=0))
cmap = plt.get_cmap('RdBu_r')
levels = arange(-50,50,10)
ax.add_feature(land_50m)
ax.set_extent([lonW+360, lonE+360, latS, latN], crs=ccrs.PlateCarree())
net_sfc_heating_plot = net_sfc_heating_slopes * 25
p = net_sfc_heating_plot.plot(add_colorbar=True, cmap=cmap, levels=levels, extend='both', 
                            cbar_kwargs={'orientation':'horizontal'})
plt.title('Net surface heating ($W\ m^{-2}\ \cdot\ 25yrs^{-1}$)')
ax.gridlines(draw_labels=False, linewidth=0.5, linestyle='-')

ax = plt.subplot2grid((row, col), (1, 2), rowspan=1, colspan=1, 
                      projection=ccrs.PlateCarree(central_longitude=0))
cmap = plt.get_cmap('RdBu_r')
levels = arange(-50,50,10)
ax.add_feature(land_50m)
ax.set_extent([lonW+360, lonE+360, latS, latN], crs=ccrs.PlateCarree())
mld_plot = mld_slopes * 25
p = mld_plot.plot(add_colorbar=True, cmap=cmap, levels=levels, extend='both', 
                            cbar_kwargs={'orientation':'horizontal'})
plt.title('Mixed layer depth ($m\ \cdot\ 25yrs^{-1}$)')
ax.gridlines(draw_labels=False, linewidth=0.5, linestyle='-')

ax = plt.subplot2grid((row, col), (0, 3), rowspan=1, colspan=1, 
                      projection=ccrs.PlateCarree(central_longitude=0))
cmap = plt.get_cmap('RdBu_r')
levels = arange(-5,5,1)
ax.add_feature(land_50m)
ax.set_extent([lonW+360, lonE+360, latS, latN], crs=ccrs.PlateCarree())
gyre_psi_plot = gyre_psi_slopes * 25
p = gyre_psi_plot.plot(add_colorbar=True, cmap=cmap, levels=levels, extend='both', 
                            cbar_kwargs={'orientation':'horizontal'})
plt.title('Barotropic streamfunction ($Sv\ \cdot\ 25yrs^{-1}$)')
ax.gridlines(draw_labels=False, linewidth=0.5, linestyle='-')

ax = plt.subplot2grid((row, col), (1, 3), rowspan=1, colspan=1, 
                      projection=ccrs.PlateCarree(central_longitude=0))
cmap = plt.get_cmap('RdBu_r')
levels = arange(-0.1,0.1,0.02)
ax.add_feature(land_50m)
ax.set_extent([lonW+360, lonE+360, latS, latN], crs=ccrs.PlateCarree())
eta_t_plot = eta_t_slopes * 25
p = eta_t_plot.plot(add_colorbar=True, cmap=cmap, levels=levels, extend='both', 
                            cbar_kwargs={'orientation':'horizontal'})
plt.title('Sea surface height ($m\ \cdot\ 25yrs^{-1}$)')
ax.gridlines(draw_labels=False, linewidth=0.5, linestyle='-')

savefigure('linear_trends')

# %%
# use common start and end dates for all runs
RYF_directory = '01deg_jra55v13_ryf8485_spinup6'
tstart_RYF = '1947-01-01 00:00:00'
tend_RYF = '1948-01-01 00:00:00'

print('tstart = ', tstart_RYF)
print('tend = ', tend_RYF)

latS = -70
latN = 20
lonW = 90-360
lonE = 180-360
time_units = exptdata.exptdict[ekey]['time_units']
n_files = exptdata.exptdict[ekey]['n_files']
offset = exptdata.exptdict[ekey]['offset']
print(time_units)
print(n_files)
print(offset)
# Out:
# tstart =  1947-01-01
# tend =  1948-01-01
# days since 0001-01-01
# None
# None

# %%
print(RYF_directory)
temp_RYF_month = cc.get_nc_variable(RYF_directory,'ocean.nc','temp',
                                   time_units=time_units,
                                   n=n_files,offset=offset).\
                            sel(time=slice(
    '1946-01-01 00:00:00','1947-01-01 00:00:00')).\
                            sel(yt_ocean=slice(latS,latN)).\
                            sel(xt_ocean=slice(lonW,lonE)).\
                            sel(st_ocean=0,method='nearest')

# temp_RYF_month.load()
print(temp_RYF_month)
# Out:
# 01deg_jra55v13_ryf8485_spinup6
# Using database sqlite:////g/data3/hh5/tmp/cosima/cosima-cookbook/cosima-cookbook.db
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-18.10/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_slice_bound(self, label, side, kind)
#    4240             try:
# -> 4241                 return self._searchsorted_monotonic(label, side)
#    4242             except ValueError:
#
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-18.10/lib/python3.6/site-packages/pandas/core/indexes/base.py in _searchsorted_monotonic(self, label, side)
#    4199
# -> 4200         raise ValueError('index must be monotonic increasing or decreasing')
#    4201
#
# ValueError: index must be monotonic increasing or decreasing
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-6338ad69afe8> in <module>
#       4                                    n=n_files,offset=offset).\
#       5                             sel(time=slice(
# ----> 6     '1946-01-01 00:00:00','1947-01-01 00:00:00')).\
#       7                             sel(yt_ocean=slice(latS,latN)).\
#       8                             sel(xt_ocean=slice(lonW,lonE)).\
#
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-18.10/lib/python3.6/site-packages/xarray/core/dataarray.py in sel(self, indexers, method, tolerance, drop, **indexers_kwargs)
#     847         ds = self._to_temp_dataset().sel(
#     848             indexers=indexers, drop=drop, method=method, tolerance=tolerance,
# --> 849             **indexers_kwargs)
#     850         return self._from_temp_dataset(ds)
#     851
#
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-18.10/lib/python3.6/site-packages/xarray/core/dataset.py in sel(self, indexers, method, tolerance, drop, **indexers_kwargs)
#    1608         indexers = either_dict_or_kwargs(indexers, indexers_kwargs, 'sel')
#    1609         pos_indexers, new_indexes = remap_label_indexers(
# -> 1610             self, indexers=indexers, method=method, tolerance=tolerance)
#    1611         result = self.isel(indexers=pos_indexers, drop=drop)
#    1612         return result._replace_indexes(new_indexes)
#
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-18.10/lib/python3.6/site-packages/xarray/core/coordinates.py in remap_label_indexers(obj, indexers, method, tolerance, **indexers_kwargs)
#     353
#     354     pos_indexers, new_indexes = indexing.remap_label_indexers(
# --> 355         obj, v_indexers, method=method, tolerance=tolerance
#     356     )
#     357     # attach indexer's coordinate to pos_indexers
#
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-18.10/lib/python3.6/site-packages/xarray/core/indexing.py in remap_label_indexers(data_obj, indexers, method, tolerance)
#     256         else:
#     257             idxr, new_idx = convert_label_indexer(index, label,
# --> 258                                                   dim, method, tolerance)
#     259             pos_indexers[dim] = idxr
#     260             if new_idx is not None:
#
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-18.10/lib/python3.6/site-packages/xarray/core/indexing.py in convert_label_indexer(index, label, index_name, method, tolerance)
#     141         indexer = index.slice_indexer(_sanitize_slice_element(label.start),
#     142                                       _sanitize_slice_element(label.stop),
# --> 143                                       _sanitize_slice_element(label.step))
#     144         if not isinstance(indexer, slice):
#     145             # unlike pandas, in xarray we never want to silently convert a
#
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-18.10/lib/python3.6/site-packages/pandas/core/indexes/base.py in slice_indexer(self, start, end, step, kind)
#    4105         """
#    4106         start_slice, end_slice = self.slice_locs(start, end, step=step,
# -> 4107                                                  kind=kind)
#    4108
#    4109         # return a slice
#
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-18.10/lib/python3.6/site-packages/pandas/core/indexes/base.py in slice_locs(self, start, end, step, kind)
#    4306         start_slice = None
#    4307         if start is not None:
# -> 4308             start_slice = self.get_slice_bound(start, 'left', kind)
#    4309         if start_slice is None:
#    4310             start_slice = 0
#
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-18.10/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_slice_bound(self, label, side, kind)
#    4242             except ValueError:
#    4243                 # raise the original KeyError
# -> 4244                 raise err
#    4245
#    4246         if isinstance(slc, np.ndarray):
#
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-18.10/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_slice_bound(self, label, side, kind)
#    4236         # we need to look up the label
#    4237         try:
# -> 4238             slc = self._get_loc_only_exact_matches(label)
#    4239         except KeyError as err:
#    4240             try:
#
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-18.10/lib/python3.6/site-packages/pandas/core/indexes/base.py in _get_loc_only_exact_matches(self, key)
#    4205         get_slice_bound.
#    4206         """
# -> 4207         return self.get_loc(key)
#    4208
#    4209     def get_slice_bound(self, label, side, kind):
#
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-18.10/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
# -> 3080                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    3081
#    3082         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '1946-01-01 00:00:00'

# %%
print(pd.to_datetime(exptdata.clim_tstart))
# Out:
# 1993-01-01 00:00:00
